# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dish_df = pd.read_csv("dish_df.csv")
restaurant_dish_df = pd.read_csv("restaurant_dish_df.csv")
unique_opening_hours_df = pd.read_csv("unique_opening_hours_df.csv")
price_info_df = pd.read_csv("price_info_df.csv")
jkt_data_full = pd.read_csv("jkt_datas_fix.csv")

# %%
plt.figure(figsize=(12, 8))

sns.barplot(x='resto_id', y='avg_price', data=price_info_df)
plt.xlabel('Restaurant ID')
plt.ylabel('Average Price')
plt.title('Average Price Comparison')
plt.show()

# %%
avg_price_over_time = jkt_data_full.groupby('resto_id')['avg_price'].mean().reset_index()


plt.figure(figsize=(12, 8))


sns.lineplot(x='resto_id', y='avg_price', data=avg_price_over_time)
plt.xlabel('Restaurant ID')
plt.ylabel('Average Price')
plt.title('Average Price Trend')


plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(x='rating', data=jkt_datas)
plt.title('Rating Distribution')
plt.show()

# %%
plt.figure(figsize=(12, 8))

sns.scatterplot(x='rating', y='avg_price', data=jkt_data_full)
plt.title('Correlation between Price and Rating')
plt.xlabel('Rating')
plt.ylabel('Average Price')
plt.show()

# %%
plt.figure(figsize=(12, 8))

sns.histplot(data=jkt_data_full, x='avg_price', kde=True)
plt.title('Distribution of Average Prices')
plt.xlabel('Average Price')
plt.ylabel('Count')
plt.show()

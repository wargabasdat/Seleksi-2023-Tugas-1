# %% [markdown]
# #### References
# * https://www.youtube.com/watch?v=C5AOZZWxvIY&ab_channel=GunturBudi
# * https://stackoverflow.com/questions/58474049/how-to-scrape-websites-that-have-loaders
# * https://www.kaggle.com/code/farhanmalik371/bag-of-words-attempt
# * https://www.selenium.dev/documentation/webdriver/getting_started/first_script/#2-take-action-on-browser
# * https://www.youtube.com/watch?v=UOsRrxMKJYk&ab_channel=ThePyCoach

# %% [markdown]
# ### Web Scraping Gramedia.com

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
from random import randint

# %% [markdown]
# #### Scraping the href-links

# %%
# Setup Options
chrome_options = Options()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# Gramedia.com URLs
url = "https://www.gramedia.com/categories/buku/komik?page="

# NOTE
# There are 50 pages of book with comic & graphic novel category
# but to demonstrate the datascrape, this program will only scrape
# the first 6 pages (120 books).

# Array of href of each book in the list of book
hrefArray = []

# Initiate WebDriver Session
driver = webdriver.Chrome(options=chrome_options)
    
# Opens The Website in Chrome
driver.get(url + str(1))

# Fetching each book href link accross 50 pages
for p in range(6):

    # Waiting the page to load for 10-15 seconds
    time.sleep(randint(10,15))
    
    # Get the elements of the website that contains the href link
    products = driver.find_elements("xpath", "//gm-product-list/div/a")
    
    # Put those link inside an array
    for product in products:
        hrefArray.append(product.get_attribute('href'))
    
    # Next Page
    nextButton = driver.find_element("xpath", '//i[@class="ion-ios-arrow-forward"]')
    nextButton.click()

driver.quit()

print("Num href-links fetched: " + str(len(hrefArray)))
# Out:
# Num href-links fetched: 120

# %% [markdown]
# #### Scraping book data by looping the href-links

# %%
# Function to Reformat Months in Published Date
def reformat(date):
    dateTemp = date.split(" ")
    if (dateTemp[1] == "Mei"):
        dateTemp[1] = "May"
    elif (dateTemp[1] == "Agu"):
        dateTemp[1] = "Aug"
    elif (dateTemp[1] == "Agt"):
        dateTemp[1] = "Aug"
    elif (dateTemp[1] == "Okt"):
        dateTemp[1] = "Oct"
    elif (dateTemp[1] == "Des"):
        dateTemp[1] = "Dec"
    return dateTemp[0] + " " + dateTemp[1] + " " + dateTemp[2]

# Function to Equalize the length of the array of data if an error occurred
def equalize(numProcess):
    global author, title, basePrice, description, pageNum, publisher, publishDate, weight, isbn, width, language, length
    
    if (len(author) !=  numProcess):
        author.pop(len(author) - 1)
    if (len(title) != numProcess):
        title.pop(len(title) - 1)
    if (len(basePrice) != numProcess):
        basePrice.pop(len(basePrice) - 1)
    if (len(description) != numProcess):
        description.pop(len(description) - 1)
    if (len(pageNum) != numProcess):
        pageNum.pop(len(pageNum) - 1)
    if (len(publisher) != numProcess):
        publisher.pop(len(publisher) - 1)
    if (len(publishDate) != numProcess):
        publishDate.pop(len(publishDate) - 1)
    if (len(weight) != numProcess):
        weight.pop(len(weight) - 1)
    if (len(isbn) != numProcess):
        isbn.pop(len(isbn) - 1)
    if (len(width) != numProcess):
        width.pop(len(width) - 1)
    if (len(language) != numProcess):
        language.pop(len(language) - 1)
    if (len(length) != numProcess):
        length.pop(len(length) - 1)

# %%
from bs4 import BeautifulSoup as bsp
import requests
import pandas as pd
from datetime import datetime
import traceback

# Arrays to contain the data
author = []
title = []
basePrice = []
description = []
pageNum = []
publisher = []
publishDate = []
weight = []
isbn = []
width = []
language = []
length = []

# %%
# Processing IDX
i = 0
# The purpose of this IDX is that if an exception occurred,
# the pre-processing won't restart from the first href.
# It'll instead start from where it crashed.

# %%
# Create New Session
driver = webdriver.Chrome(options=chrome_options)

# Scrap the book data from the href
for numProcess in range(i, len(hrefArray)):
    
    print("Process #" + str(numProcess + 1) + ":", end=" ")
    
    # Open & wait the page to load
    driver.get(hrefArray[numProcess])
    time.sleep(randint(8,12))
    
    # Get the HTML
    html = driver.page_source
    
    # Change html into Soup Class
    soup = bsp(html, "lxml")
    # print(soup.prettify())
    
    try:
        # Find Author
        authorName = soup.find("span", "title-author")
        author.append(authorName.get_text().strip())
        # print(authorName.get_text(), end=" # ")

        # Find Title
        bookTitle = soup.find("div", "book-title")
        title.append(bookTitle.get_text().strip())
        # print(bookTitle.get_text())

        # Find Base Price (Price Before Discount)
        bookPrice = soup.find("div", "price-promo")
        if (bookPrice is None):
            bookPrice = soup.find("div", "price-from")
        basePrice.append(int(bookPrice.get_text().replace("Rp","").replace(".","").replace(" ","")))

        # Find Description
        prodDesc = soup.find("div", "product-desc")
        bookDesc = prodDesc.find_all("div", "")
        description.append(bookDesc[len(bookDesc) - 1].get_text().strip())

        # Find Book Details
        bookDetail = soup.find("div", "detail-section")
        details = bookDetail.find_all("p")
        pageNum.append(int(float(details[0].get_text())))
        publisher.append(details[1].get_text())

        weight.append(float(details[3].get_text().replace("kg","").replace(" ","")))
        isbn.append(int(details[4].get_text()))
        width.append(float(details[5].get_text().replace("cm","").replace(" ","")))
        if (len(details) == 8):
            language.append(details[6].get_text().capitalize())
            length.append(float(details[7].get_text().replace("cm","").replace(" ","")))
        else:
            language.append("N/A")
            length.append(float(0.0))

        date = details[2].get_text().strip()
        publishDate.append(datetime.strptime(reformat(date), '%d %b %Y').strftime('%Y-%m-%d'))
        
        i += 1
        print("Success!")
    except Exception as e:
        if (numProcess == 41):
            hrefArray.pop(41)
            print("No Data", end = " ")
        print("Error!")
        equalize(i)
        traceback.print_exc()
        break
        

# Close The Browser
driver.quit()
# Out:
# Process #42: Success!
# Process #43: Success!
# Process #44: Success!
# Process #45: Success!
# Process #46: Success!
# Process #47: Success!
# Process #48: Success!
# Process #49: Success!
# Process #50: Success!
# Process #51: Success!
# Process #52: Success!
# Process #53: Success!
# Process #54: Success!
# Process #55: Success!
# Process #56: Success!
# Process #57: Success!
# Process #58: Success!
# Process #59: Success!
# Process #60: Success!
# Process #61: Success!
# Process #62: Success!
# Process #63: Success!
# Process #64: Success!
# Process #65: Success!
# Process #66: Success!
# Process #67: Success!
# Process #68: Success!
# Process #69: Success!
# Process #70: Success!
# Process #71: Success!
# Process #72: Success!
# Process #73: Success!
# Process #74: Success!
# Process #75: Success!
# Process #76: Success!
# Process #77: Success!
# Process #78: Success!
# Process #79: Success!
# Process #80: Success!
# Process #81: Success!
# Process #82: Success!
# Process #83: Success!
# Process #84: Success!
# Process #85: Success!
# Process #86: Success!
# Process #87: Success!
# Process #88: Success!
# Process #89: Success!
# Process #90: Success!
# Process #91: Success!
# Process #92: Success!
# Process #93: Success!
# Process #94: Success!
# Process #95: Success!
# Process #96: Success!
# Process #97: Success!
# Process #98: Success!
# Process #99: Success!
# Process #100: Success!
# Process #101: Success!
# Process #102: Success!
# Process #103: Success!
# Process #104: Success!
# Process #105: Success!
# Process #106: Success!
# Process #107: Success!
# Process #108: Success!
# Process #109: Success!
# Process #110: Success!
# Process #111: Success!
# Process #112: Success!
# Process #113: Success!
# Process #114: Success!
# Process #115: Success!
# Process #116: Success!
# Process #117: Success!
# Process #118: Success!
# Process #119: Success!

# %%
# Check Number of Process with The Num of Datum
print(i)
print(len(isbn))
print(len(author))
print(len(title))
print(len(basePrice))
print(len(description))
print(len(pageNum))
print(len(publisher))
print(len(publishDate))
print(len(weight))
print(len(length))
print(len(language))
# Out:
# 119
# 119
# 119
# 119
# 119
# 119
# 119
# 119
# 119
# 119
# 119
# 119

# %% [markdown]
# ### Creating Dataframe
# #### in accordance with the Relational Table

# %%
# 1
# Create a unique ID for each author
uniqueAuthorSet = set(author.copy())
uniqueAuthorList = list(uniqueAuthorSet)
uniqueAID = []
for i in range (len(uniqueAuthorList)):
    uniqueAID.append("AU" + str(i + 1).zfill(4))

# Create an array to fill author description column
dummy = ['by 18221171' for i in range (len(uniqueAuthorList))]
    
# Create Dictionary to make Author Relation
authDict = {'authorID':uniqueAID,
            'authorName':uniqueAuthorList,
            'description':dummy}

# Create the dataframe from dictionary
authDF = pd.DataFrame(authDict,columns = ['authorID','authorName','description'])

# Show Table
authDF
# Out:
#     authorID                                         authorName  description
# 0     AU0001                                       TSUTOMO SATO  by 18221171
# 1     AU0002                                       Ojiro Makoto  by 18221171
# 2     AU0003                                         Faza Meonk  by 18221171
# 3     AU0004                      RYOHGO NARITA/SHINTA FUJIMOTO  by 18221171
# 4     AU0005  TAPPEI NAGATSUKI/MAKOTO FUGETSU/SHINICHIROU OT...  by 18221171
# ..       ...                                                ...          ...
# 99    AU0100                                        Yearim dang  by 18221171
# 100   AU0101                                           Pionicon  by 18221171
# 101   AU0102                                           Kei Koga  by 18221171
# 102   AU0103                                          Ryo Azuki  by 18221171
# 103   AU0104                                      Joji Morikawa  by 18221171
#
# [104 rows x 3 columns]

# %%
# 2
# Create a unique ID for each publisher
uniquePublisherSet = set(publisher.copy())
uniquePublisherList = list(uniquePublisherSet)
uniquePID = []
for i in range (len(uniquePublisherList)):
    uniquePID.append("PB" + str(i + 1).zfill(4))

# Create an array to fill other columns description column
dummy = ['by 18221171' for i in range (len(uniquePublisherList))]
    
# Create Dictionary to make Author Relation
publDict = {'publisherID':uniquePID,
            'publisherName':uniquePublisherList,
            'address':dummy,
            'phone':dummy}

# Create the dataframe from dictionary
publDF = pd.DataFrame(publDict,columns = ['publisherID','publisherName','address','phone'])

# Show Table
publDF
# Out:
#    publisherID                 publisherName      address        phone
# 0       PB0001                   Sinar angsa  by 18221171  by 18221171
# 1       PB0002         Elex Media Komputindo  by 18221171  by 18221171
# 2       PB0003                    Romancious  by 18221171  by 18221171
# 3       PB0004                        bukune  by 18221171  by 18221171
# 4       PB0005          Salsabila Al-kautsar  by 18221171  by 18221171
# 5       PB0006                     Salsabila  by 18221171  by 18221171
# 6       PB0007            Aria Media Mandiri  by 18221171  by 18221171
# 7       PB0008           Bhuana Ilmu Populer  by 18221171  by 18221171
# 8       PB0009                  Akad x Tekad  by 18221171  by 18221171
# 9       PB0010                      Loveable  by 18221171  by 18221171
# 10      PB0011               Al-Kautsar Kids  by 18221171  by 18221171
# 11      PB0012                  Akad x Skuad  by 18221171  by 18221171
# 12      PB0013                        Bukune  by 18221171  by 18221171
# 13      PB0014                     Ump Press  by 18221171  by 18221171
# 14      PB0015                          m&c!  by 18221171  by 18221171
# 15      PB0016                    GagasMedia  by 18221171  by 18221171
# 16      PB0017  Kepustakaan Populer Gramedia  by 18221171  by 18221171
# 17      PB0018        Gramedia Pustaka Utama  by 18221171  by 18221171
# 18      PB0019        Noura Books Publishing  by 18221171  by 18221171
# 19      PB0020                        Falcon  by 18221171  by 18221171
# 20      PB0021              Gema Insani Pers  by 18221171  by 18221171
# 21      PB0022                     Mediakita  by 18221171  by 18221171

# %%
# 3
# Create an array containing authorID for the book relation
authorsID = []
for a in author:
    authorsID.append("AU" + str(uniqueAuthorList.index(a) + 1).zfill(4))
    
# Create an array containing publisherID for the book relation
publisherID = []
for p in publisher:
    publisherID.append("PB" + str(uniquePublisherList.index(p) + 1).zfill(4))


# Creating Dictionary to make Dataframe
prodDict = {'isbn':isbn, 
            'authorID':authorsID,
            'title':title, 
            'basePrice':basePrice, 
            'description':description, 
            'pageNum':pageNum, 
            'publisherID':publisherID, 
            'publishDate':publishDate,
            'weight':weight,
            'width':width,
            'length':length,
            'language':language}

# print(len(isbn))
# print(len(authorsID))
# print(len(title))
# print(len(basePrice))
# print(len(description))
# print(len(pageNum))
# print(len(publisherID))
# print(len(publishDate))
# print(len(weight))
# print(len(length))
# print(len(language))

# Create the dataframes from dictionary
bookDF = pd.DataFrame(prodDict,columns = ['isbn','authorID','title','basePrice','description','pageNum','publisherID','publishDate','weight','width','length','language'])

# Show Table
bookDF
# Out:
#               isbn authorID                                           title  \
# 0    9786232423763   AU0038                                      One by One
# 1    9786022204763   AU0101                         Si Juki Anak Kos London
# 2    9786024554811   AU0045                       World Ghost Stories Eropa
# 3    9786238019106   AU0026                      Muhammad Membangun Madinah
# 4    9786230311147   AU0046                  Mice Cartoon - Indonesia Seru!
# ..             ...      ...                                             ...
# 114  9786230046926   AU0094                                      Radiant 04
# 115  9786026714794   AU0003                        Si Juki Anak Kosan Vol 3
# 116  9786235729503   AU0021  My Wife`s My Lecturer, My Husband`s My Student
# 117  9786230310423   AU0068                        AKASHA : Chainsaw Man 02
# 118  9786230308116   AU0009    AKASHA : Wotakoi : Love is Hard for Otaku 09
#
#      basePrice                                        description  pageNum  \
# 0       129000  Snoop, aplikasi musik baru yang berhasil merai...      444
# 1        82500  Si Juki Anak Kos London\r\n\r\n\r\n\r\nJuki di...      180
# 2       125000  "Di Eropa, banyak sekali cerita hantu yang ber...      192
# 3       135000  Perjalanan hidup manusia agung, Rasul Muhammad...      289
# 4        85000  Setiap hari Minggu kebanyakan orang tidak pern...      152
# ..         ...                                                ...      ...
# 114      45000  Radiant (bahasa Jepang: ラディアン Hepburn: Radian)...      184
# 115      84000  Wah, si Juki dan kawan-kawan kembali dengan ki...      190
# 116      85000  Semua orang memiliki kisahnya sendiri-sendiri....      174
# 117      48000  Di antara jenis buku lainnya, komik memang dis...      192
# 118      40000  Kabakura dan Koyanagi menikah!? Apakah pasanga...      136
#
#     publisherID publishDate  weight  width  length   language
# 0        PB0019  2023-04-24   0.410   14.0    21.0  Indonesia
# 1        PB0013  2022-12-26   0.180   14.0    20.0  Indonesia
# 2        PB0008  2018-04-08   0.200   17.0    22.0  Indonesia
# 3        PB0006  2023-06-23   0.240   13.0    20.0  Indonesia
# 4        PB0015  2023-06-19   0.200   14.8    21.0  Indonesia
# ..          ...         ...     ...    ...     ...        ...
# 114      PB0002  2023-03-31   0.150   12.0    18.0  Indonesia
# 115      PB0020  2023-03-30   0.220   14.0    20.0  Indonesia
# 116      PB0014  2023-03-29   0.155   14.0    20.0  Indonesia
# 117      PB0015  2023-04-07   0.150   13.0    19.0  Indonesia
# 118      PB0015  2022-10-08   0.105   13.0    18.0  Indonesia
#
# [119 rows x 12 columns]

# %% [markdown]
# ### Dumping into JSON

# %%
from json import loads, dumps

# book.json
result = bookDF.to_json(orient="table")
parsed = loads(result)
print(dumps(parsed, indent=4))

bookDF.to_json(r'C:\Users\StepHomie\Documents\Hans St\Code\Jupyter\Seleksi-2023-Tugas-1\Data Scraping\data\book.json', orient="table", indent=4)
# Out:
# {
#     "schema": {
#         "fields": [
#             {
#                 "name": "index",
#                 "type": "integer"
#             },
#             {
#                 "name": "isbn",
#                 "type": "integer"
#             },
#             {
#                 "name": "authorID",
#                 "type": "string"
#             },
#             {
#                 "name": "title",
#                 "type": "string"
#             },
#             {
#                 "name": "basePrice",
#                 "type": "integer"
#             },
#             {
#                 "name": "description",
#                 "type": "string"
#             },
#             {
#                 "name": "pageNum",
#                 "type": "integer"
#             },
#             {
#                 "name": "publisherID",
#                 "type": "string"
#             },
#             {
#                 "name": "publishDate",
#                 "type": "string"
#             },
#             {
#                 "name": "weight",
#                 "type": "number"
#             },
#             {
#                 "name": "width",
#                 "type": "number"
#             },
#             {
#                 "name": "length",
#                 "type": "number"
#             },
#             {
#                 "name": "language",
#                 "type": "string"
#             }
#         ],
#         "primaryKey": [
#             "index"
#         ],
#         "pandas_version": "1.4.0"
#     },
#     "data": [
#         {
#             "index": 0,
#             "isbn": 9786232423763,
#             "authorID": "AU0038",
#             "title": "One by One",
#             "basePrice": 129000,
#             "description": "Snoop, aplikasi musik baru yang berhasil meraih seratus juta pengguna. Yang memungkinkan orang untuk mengintip apa yang tengah didengarkan orang lain secara real time.\r\n \r\nBerada di puncak kesuksesan, tim inti Snoop melakukan retret ke sebuah pondok ski di Pegunungan Alpen. Di sana, rahasia perusahaan terkuak. Situasi tidak baik-baik saja. Posisi semua orang terancam. Perdebatan memanas. Dan, satu orang memutuskan bertindak, menyingkirkan semua penghalang.\r\n \r\nDi tengah badai salju yang melanda, ketika mereka terjebak, tanpa listrik dan sinyal, korban mulai berjatuhan.\r\n \r\nSatu\r\ndemi\r\nsatu \u2026.",
#             "pageNum": 444,
#             "publisherID": "PB0019",
#             "publishDate": "2023-04-24",
#             "weight": 0.41,
#             "width": 14.0,
#             "length": 21.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 1,
#             "isbn": 9786022204763,
#             "authorID": "AU0101",
#             "title": "Si Juki Anak Kos London",
#             "basePrice": 82500,
#             "description": "Si Juki Anak Kos London\r\n\r\n\r\n\r\nJuki diterima sebagai mahasiswa pertukaran pelajar ke London, Inggris. Heran? Jelas. Gimana bisa anak selengean itu bisa ke luar negeri? ternyata bisa, dong! Hebatnya lagi, dia bisa hidup hemat di sana\u2014kalo tidak mau dibilang pelit.\r\n\r\nAKHIRNYA SI JUKI KULIAH DI LONDON!\r\n\r\nKebayang gak, gimana kalo Juki yang pelit harus hidup di salah satu kota termahal dun\u00eda-London, Iya, Juki dan Coro yang ke Inggris untuk program pertukaran pelajar harus banyak berpikir untuk hidup seasyik mungkin dengan dana sem\u00ednim-minimnya. Seru dan ada aja\r\n\r\nakalnya!\r\n\r\nKayaknya, justru masyarakat Union Jack yang bisa banyak belajar dari Juki, deh... bahwa hidup bisa 'wah' dengan harga murah!\r\n\r\nKebayang gak, gimana kalo Juki yang pelit harus hidup di salah satu kota termahal dunia---London. Iya, Juki dan Coro yang ke Inggris untuk program pertukaran pelajar harus banyak berpikir untuk hidup seasyik mungkin dengan dana seminim-minimnya. Seru dan ada aja akalnya!\r\n\r\nKayaknya, justru masyarakat Union Jack yang bisa banyak belajar dari Juki, deh... bahwa hidup bisa \"wah\" dengan harga murah.\r\n\r\nJuki diterima sebagai mahasiswa pertukaran pelajar ke London, Inggris. Heran? Jelas. Gimana bisa anak selengean itu bisa ke luar negeri? ternyata bisa, dong! Hebatnya lagi, dia bisa hidup hemat di sana\u2014kalo tidak mau dibilang pelit.",
#             "pageNum": 180,
#             "publisherID": "PB0013",
#             "publishDate": "2022-12-26",
#             "weight": 0.18,
#             "width": 14.0,
#             "length": 20.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 2,
#             "isbn": 9786024554811,
#             "authorID": "AU0045",
#             "title": "World Ghost Stories Eropa",
#             "basePrice": 125000,
#             "description": "\"Di Eropa, banyak sekali cerita hantu yang berkembang di sana. Selain itu, ada banyak tempat dan legenda yang tak kalah menyeramkan di sana. Tokoh hantu terkenal pun banyak yang berasal dari Eropa. Di antaranya, raksasa Frankenstein yang besar dan mengerikan, drakula pengisap darah manusia, dan lain-lain. \r\n\r\n\r\n\r\nBeberapa kisah atau cerita hantu di Eropa pun sering keluar dalam film atau dongeng.\r\nKomik ini terdiri dari dua bentuk cerita, yaitu berbentuk dongeng dan komik. Dengan gaya bahasa penulisan yang seru, komik ini pasti membuat pembaca bergidik ngeri.  \"",
#             "pageNum": 192,
#             "publisherID": "PB0008",
#             "publishDate": "2018-04-08",
#             "weight": 0.2,
#             "width": 17.0,
#             "length": 22.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 3,
#             "isbn": 9786238019106,
#             "authorID": "AU0026",
#             "title": "Muhammad Membangun Madinah",
#             "basePrice": 135000,
#             "description": "Perjalanan hidup manusia agung, Rasul Muhammad tidak pernah usang untuk ditulis, didokumentasikan, dicermati, dibahas, ditafsirkan, bahkan diperdebatkan. Kisah hidupnya adalah khazanah eksplorasi dari sejumlah karakter yang layak dijadikan inspirasi dan teladan bagi umat manusia.\r\n\r\nSejarah perjalanan Rasul Muhammad adalah napak tilas peradaban tentang arus kehidupan sebuah masyarakat yang ditakdirkan menghuni gurun tandus di sepanjang barat daya Laut Merah. la tentakel geologis, kultur budaya, tatanan sosial, dan struktur ekonomi yang berhulu pada sang Khalilullah Ibrahim. Ia adalah fenomena psikologis yang kelak menempa salah satu generasinya untuk menghadapi pergulatan panjang dalam mengemban risalah dan nubuwah.\r\n\r\nLebih dari itu, prosesi kelahiran, masa muda, dan seluruh aspek hidupnya yang diwarnai agitasi, peperangan, problem politik, dan pendirian daulah adalah perayaan semesta yang menjadikan sosoknya abadi dan terus hidup dalam perjalanan sejarah umat manusia. Di mana seorang Muslim berpijak, di sana namanya disebut.\r\n\r\nDengan karakter ke-llahian, kebijakan, dan pandangan politiknya, Rasul Muhammad menasbihkan dirinya sebagai sosok penting dalam pencaturan dunia. Kehadirannya menciptakan arus hubungan timur dan barat, menafikan sel-sel genetika, geografis, dan budaya. Kedatangannya menyusun ulang agama-agama sebelumnya, dan mengakhirinya dengan teologi tauhid yang menyamakan visi dalam diktum ke-Tuhanan. Kombinasi antara agama, politik, budaya, dan ekonomi yang tercipta dalam waktu singkat telah membawa Rasul Muhammad menjadi penyumbang terbesar bagi berdirinya kolonisasi dunia baru yang nyaris tergilas oleh milenium kegelapan.\r\n\r\nRasul Muhammad adalah seorang utusan Tuhan sekaligus figur genius pembangun peradaban baru yang ditegakkan dengam maklumat cinta dalam kehidupan bersosial, berbudaya, beragama, dan bernegara.\r\n\r\nRasul Muhammad adalah fenomena terbesar dalam sejarah. Seorang revolusioner yang memberikan harapan, perlindungan, dan janji pertolongan bagi umat manusia. Seorang penebar rahmat bagi semesta alam, dan Al-Amin yang lahir di bumi yang tandus.",
#             "pageNum": 289,
#             "publisherID": "PB0006",
#             "publishDate": "2023-06-23",
#             "weight": 0.24,
#             "width": 13.0,
#             "length": 20.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 4,
#             "isbn": 9786230311147,
#             "authorID": "AU0046",
#             "title": "Mice Cartoon - Indonesia Seru!",
#             "basePrice": 85000,
#             "description": "Setiap hari Minggu kebanyakan orang tidak pernah kekurangan bacaan. Kompas Edisi Minggu dengan beberapa kolom Seni selalu menunggu di beranda, ditemani kopi pagi dan sinar matahari yang belum terik. Dengan 3500 rupiah saja, kita seperti diajak membaca sejumlah buku dengan variasi tema yang dirangkum melalui satu bacaan. Mengakhiri pembaca, tak terasa terdampar di bagian komik kartun. Mice cartoon belum terkalahkan dalam serial komik. Humornya menggelitik. kita diajak menikmati nuansa baru sajian sarkasme nomor wahid.\r\n\r\nSinopsis Buku:\r\nIndonesia Seru! merupakan kumpulan komik strip Mice Cartoon yang sebelumnya pernah ditayangkan di sebuah media digital. Komik strip berwarna ini menceritakan kisah-kisah yang menampilkan potret kehidupan masyarakat Indonesia yang beragam dan tentunya seru!\r\n\r\nSelling point:\r\n1. Kartun Mice yang sudah terkenal\r\n2. Membahas kisah-kisah potret kehidupan masyarakat Indonesia secara kocak\r\n3. Terdapat sketsa pembuatan kartun, sehingga pembaca bisa melihat proses di balik buku\r\n\r\nProfil Penulis:\r\nMuhammad Misrad, adalah seorang kartunis. Pada awalnya bersama dengan Benny Rachmadi, alumni Desain Grafis, Fakultas Seni Rupa, Institut Kesenian Jakarta ini membuat strip komik Benny & Mice yang berisi kritik-kritik sosial. Kartunis yang akrab disapa Mice dikenal juga bekerja sebagai dosen dengan mengajar di IKJ. Sejak bulan Juli 2010, Mice hanya menggambar sendirian di koran Kompas dengan kartunnya yang berjudul Mice Cartoon. Mice hadir dengan kemampuannya memotret kehidupan Kota Jakarta dengan penuh ironi, satire, aneh, jelimet, dan membuat tawa.",
#             "pageNum": 152,
#             "publisherID": "PB0015",
#             "publishDate": "2023-06-19",
#             "weight": 0.2,
#             "width": 14.8,
#             "length": 21.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 5,
#             "isbn": 9786230033520,
#             "authorID": "AU0049",
#             "title": "Why? Game Science - Sains Permainan",
#             "basePrice": 119000,
#             "description": "Bermain game secara berlebihan memang mengakibatkan banyak dampak negatif untuk kita, seperti penglihatan dapat memburuk, skoliosis karena mempertahankan postur yang salah, sindrom leher kura-kura karena terlalu lama mencondongkan kepala ke depan, dan penyakit-penyakit lainnya. Penyakit-penyakit tersebut lebih mudah mempengaruhi anak-anak dan remaja yang masih dalam masa pertumbuhan. \r\nDi sekitar kita pun pasti ada orang-orang yang kecanduan bermain game hingga tidur terlalu larut atau bahkan tidak tidur sama sekali. Bermain game memang menyenangkan dan terkadang membuat kita lupa waktu, tapi bermain tanpa mengendalikan diri juga dapat merugikan kita. \r\nTerkadang, kita terlalu asyik bermain game hingga kehilangan waktu berharga untuk berdiskusi dan bersosialisasi dengan orang-orang yang kita sayangi. Selain itu, tidak jarang juga kita telat makan atau bahkan tidak makan sama sekali karena bermain game.\r\nKarena itu, pengendalian diri saat bermain game sangatlah penting. Kita harus membatasi diri kita dengan menentukan batas waktu dalam bermain game agar kita tetap mendapatkan kesenangan dan tidak kehilangan relasi di dunia nyata. Kalau dinyatakan seperti itu, game terkesan hanya memberikan kita kesenangan dan lebih banyak dampak buruknya. \r\nSebenarnya, terdapat game yang bermanfaat atau lebih dikenal dengan istilah game fungsional. Game fungsional memanfaatkan sifat positif dari game, yakni memberikan kesenangan, dan menambahkan tujuan khusus seperti pendidikan, pelatihan, pengobatan, dan sebagainya.\r\nPenerbit Elex Media Komputindo telah menerbitkan buku \u2018Why? Game Science \u2013 Sains Permainan\u2019. Buku ini adalah judul terbaru dari seri komik pendidikan \u2018Why?\u2019, yang merupakan salah satu seri komik pendidikan dengan penjualan terbaik di Indonesia dan Korea Selatan. \r\nDi dalam buku ini, terdapat Omji yang sangat menyukai game dan Komji yang lebih suka berkebun daripada bermain game. Omji akan menceritakan segala hal terkait game, mulai dari sejarah, perkembangan, dan kontribusinya dalam perkembangan teknologi pada Komji agar dia tertarik untuk bermain game. \r\nSelain itu, disajikan juga dampak negatif, dampak positif, serta saran untuk anak-anak agar tidak bermain game secara berlebihan, tapi masih bisa merasakan kesenangan. Buku ini disajikan dalam bentuk komik dengan cerita yang menarik dan bahasa yang ringan agar anak-anak dan remaja dapat memahami isinya dengan mudah.\r\nDetail;\r\nJumlah Halaman\r\n160\r\nPenerbit\r\nElex Media Komputindo\r\nTanggal Terbit\r\n10 Jul 2022\r\nBerat\r\n0.385 kg\r\nISBN\r\n9786230033520\r\nLebar\r\n18.0 cm\r\nBahasa\r\nIndonesia\r\nPanjang\r\n24.0cm",
#             "pageNum": 160,
#             "publisherID": "PB0002",
#             "publishDate": "2022-07-09",
#             "weight": 0.385,
#             "width": 18.0,
#             "length": 0.0,
#             "language": "N/A"
#         },
#         {
#             "index": 6,
#             "isbn": 9786230310539,
#             "authorID": "AU0069",
#             "title": "The Apothecary Diaries 09",
#             "basePrice": 45000,
#             "description": "Di antara jenis buku lainnya, komik memang disukai oleh semua kalangan mulai dari anak kecil hingga orang dewasa. Alasan komik lebih disukai oleh banyak orang karena disajikan dengan penuh dengan gambar dan cerita yang mengasyikan sehingga mampu menghilangkan rasa bosan di kala waktu senggang.\r\n\r\nKomik seringkali dijadikan sebagai koleksi dan diburu oleh penggemarnya karena serinya yang cukup terkenal dan kepopulerannya terus berlanjut sampai saat ini. Dalam memilih jenis komik, ada baiknya perhatikan terlebih dahulu ringkasan cerita komik di sampul bagian belakang sehingga sesuai dengan preferensi pribadi pembaca.\r\n\r\nM&C! Publishing adalah penerbit di bawah Divisi Ritel dan Penerbitan Grup Kompas Gramedia, perusahaan penerbitan terbesar di Indonesia. Grup Kompas Gramedia memulai usaha dengan fokus di media cetak. Dalam perkembangannya, perusahaan telah berkembang menjadi kelompok usaha dengan berbagai divisi. Di bidang informasi, grup ini juga merambah ke media elektronik dan multimedia. M&C! Penerbitan telah menerbitkan berbagai judul dan jenis buku: komik, komik pendidikan, buku anak-anak, novel, buku nonfiksi. Salah Satunya seperti komik \u201dThe Apothecary Diaries 09\u201d.\r\n\r\nSinopsis Buku:\r\nKandungan Giokyo-hi kian membesar, Maomao kembali diingatkan oleh insiden percobaan pembunuhan majikannya kala kehamilan pertamanya. Apalagi setelah kematian seorang selir yang diikuti kegaduhan di harem. Sementara itu, Jinshi kembali minta bantuan Maomao untuk mengambil hati utusan dari negeri asing.",
#             "pageNum": 184,
#             "publisherID": "PB0015",
#             "publishDate": "2023-06-19",
#             "weight": 0.05,
#             "width": 0.09,
#             "length": 11.04,
#             "language": "Indonesia"
#         },
#         {
#             "index": 7,
#             "isbn": 9786230310843,
#             "authorID": "AU0035",
#             "title": "Full Bloom Cheekiness 18",
#             "basePrice": 32000,
#             "description": "Akhirnya Yuki bertemu dengan ayah Naruse!!  Hitomi, kakak perempuan Naruse yang menyukai Yuki, meminta gadis itu datang ke upacara pernikahannya di Hawaii!! Selamat menikmati episode Hawaii yang penuh dengan romantisme dan kasih sayang keluarga!",
#             "pageNum": 192,
#             "publisherID": "PB0015",
#             "publishDate": "2023-06-19",
#             "weight": 0.05,
#             "width": 0.09,
#             "length": 11.04,
#             "language": "Indonesia"
#         },
#         {
#             "index": 8,
#             "isbn": 9786230047879,
#             "authorID": "AU0097",
#             "title": "Level Comic: Tokyo Revengers 09",
#             "basePrice": 40000,
#             "description": "Di antara jenis buku lainnya, komik memang disukai oleh semua kalangan mulai dari anak kecil hingga orang dewasa. Alasan komik lebih disukai oleh banyak orang karena disajikan dengan penuh dengan gambar dan cerita yang mengasyikan sehingga mampu menghilangkan rasa bosan di kala waktu senggang. Komik seringkali dijadikan sebagai koleksi dan diburu oleh penggemarnya karena serinya yang cukup terkenal dan kepopulerannya terus berlanjut sampai saat ini. Dalam memilih jenis komik, ada baiknya perhatikan terlebih dahulu ringkasan cerita komik di sampul bagian belakang sehingga sesuai dengan preferensi pribadi pembaca. Tokyo Revengers adalah karya Ken Wakui yang dirilis di Jepang pada tahun 2017 lalu dan sampai saat ini, sirkulasinya sudah mencapai lebih dari lima puluh juta eksemplar. Pada tahun 2020, komik ini berhasil memenangkan Kodansha Manga Award kategori komik remaja cowok. Komik ini sudah terjual lebih dari 40 juta eksemplar di Jepang. Menjadi pemenang Kodansha Manga Award kategori komik remaja pria tahun 2020. Animasinya sudah ditonton lebih dari 10 juta views di Youtube Muse Indonesia. Live Action movie-nya tayang Oktober 2021. Sinopsis Buku: Bentrokan besar Toman VS. Valhalla, berakhir dengan kemenangan Toman. Takemichi sekali lagi kembali ke masa kini dan\u2026 dia telah menjadi elite petinggi Toman!! Dalam pertemuan para petinggi, orang-orang bekas Black Dragon yang tak dikenalnya berulah. Kemudian, Kisaki pun hadir. Dan, apa kebenaran mengejutkan yang akan diungkapkan oleh Naoto!?",
#             "pageNum": 200,
#             "publisherID": "PB0002",
#             "publishDate": "2023-06-13",
#             "weight": 0.12,
#             "width": 12.0,
#             "length": 18.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 9,
#             "isbn": 9786230311079,
#             "authorID": "AU0068",
#             "title": "Akasha : Chainsaw Man 03",
#             "basePrice": 48000,
#             "description": "Di antara jenis buku lainnya, komik memang disukai oleh semua kalangan mulai dari anak kecil hingga orang dewasa. Alasan komik lebih disukai oleh banyak orang karena disajikan dengan penuh dengan gambar dan cerita yang mengasyikan sehingga mampu menghilangkan rasa bosan di kala waktu senggang.\r\n\r\nKomik seringkali dijadikan sebagai koleksi dan diburu oleh penggemarnya karena serinya yang cukup terkenal dan kepopulerannya terus berlanjut sampai saat ini. Dalam memilih jenis komik, ada baiknya perhatikan terlebih dahulu ringkasan cerita komik di sampul bagian belakang sehingga sesuai dengan preferensi pribadi pembaca.\r\n\r\nM&C! Publishing adalah penerbit di bawah Divisi Ritel dan Penerbitan Grup Kompas Gramedia, perusahaan penerbitan terbesar di Indonesia. Grup Kompas Gramedia memulai usaha dengan fokus di media cetak. Dalam perkembangannya, perusahaan telah berkembang menjadi kelompok usaha dengan berbagai divisi. Di bidang informasi, grup ini juga merambah ke media elektronik dan multimedia. M&C! Penerbitan telah menerbitkan berbagai judul dan jenis buku: komik, komik pendidikan, buku anak-anak, novel, buku nonfiksi. Salah Satunya seperti komik \u201dAKASHA : Chainsaw Man 03\u201d.\r\n\r\nSinopsis Buku:\r\nAda devil misterius yang memblokade ruang dan menuntut agar Denji dibunuh! Anggota Divisi Khusus 4 yang terpojok mulai mengalami perpecahan. Meski berada dalam situasi genting, Denji masih belum menyerah untuk mendapatkan hadiah ciuman.\r\nStrategi nekat apakah yang akan dia lakukan?",
#             "pageNum": 192,
#             "publisherID": "PB0015",
#             "publishDate": "2023-06-16",
#             "weight": 0.05,
#             "width": 1.01,
#             "length": 13.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 10,
#             "isbn": 9786230048197,
#             "authorID": "AU0059",
#             "title": "Level Comic: Just The Two of Us 03",
#             "basePrice": 45000,
#             "description": "-",
#             "pageNum": 192,
#             "publisherID": "PB0002",
#             "publishDate": "2023-06-13",
#             "weight": 0.13,
#             "width": 12.0,
#             "length": 18.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 11,
#             "isbn": 9786230309731,
#             "authorID": "AU0091",
#             "title": "Akasha : Gyo Complete Edition - 2 In 1",
#             "basePrice": 89000,
#             "description": "Di antara jenis buku lainnya, komik memang disukai oleh semua kalangan mulai dari anak kecil hingga orang dewasa. Alasan komik lebih disukai oleh banyak orang karena disajikan dengan penuh dengan gambar dan cerita yang mengasyikan sehingga mampu menghilangkan rasa bosan di kala waktu senggang.\r\n\r\nKomik seringkali dijadikan sebagai koleksi dan diburu oleh penggemarnya karena serinya yang cukup terkenal dan kepopulerannya terus berlanjut sampai saat ini. Dalam memilih jenis komik, ada baiknya perhatikan terlebih dahulu ringkasan cerita komik di sampul bagian belakang sehingga sesuai dengan preferensi pribadi pembaca.\r\n\r\nM&C! Publishing adalah penerbit di bawah Divisi Ritel dan Penerbitan Grup Kompas Gramedia, perusahaan penerbitan terbesar di Indonesia. Grup Kompas Gramedia memulai usaha dengan fokus di media cetak. Dalam perkembangannya, perusahaan telah berkembang menjadi kelompok usaha dengan berbagai divisi. Di bidang informasi, grup ini juga merambah ke media elektronik dan multimedia. M&C! Penerbitan telah menerbitkan berbagai judul dan jenis buku: komik, komik pendidikan, buku anak-anak, novel, buku nonfiksi. Salah Satunya seperti komik \u201dAkasha : Gyo Complete Edition - 2 In 1\u201d.\r\n\r\nSinopsis Buku:\r\nSeekor makhluk aneh berupa \u201cikan berkaki\u201d yang bisa berjalan di daratan muncul di Okinawa.\r\nKemunculannya menjadi awal dari serangkaian serangan monster ikan yang meneror seluruh penjuru Jepang!\r\nInilah komik horor karya sang maestro Ito Junji yang hadir dalam versi edisi lengkap 2 in 1.",
#             "pageNum": 400,
#             "publisherID": "PB0015",
#             "publishDate": "2023-06-19",
#             "weight": 0.05,
#             "width": 1.09,
#             "length": 13.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 12,
#             "isbn": 9786230047244,
#             "authorID": "AU0086",
#             "title": "Level Comic: Zom 100 vol 01",
#             "basePrice": 50000,
#             "description": "-",
#             "pageNum": 160,
#             "publisherID": "PB0002",
#             "publishDate": "2023-06-13",
#             "weight": 0.135,
#             "width": 13.0,
#             "length": 18.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 13,
#             "isbn": 9786230048135,
#             "authorID": "AU0006",
#             "title": "C.M.B 43",
#             "basePrice": 32000,
#             "description": "-",
#             "pageNum": 200,
#             "publisherID": "PB0002",
#             "publishDate": "2023-06-13",
#             "weight": 0.105,
#             "width": 11.4,
#             "length": 17.2,
#             "language": "Indonesia"
#         },
#         {
#             "index": 14,
#             "isbn": 9786230047992,
#             "authorID": "AU0011",
#             "title": "Blue Lock 09",
#             "basePrice": 45000,
#             "description": "-",
#             "pageNum": 192,
#             "publisherID": "PB0002",
#             "publishDate": "2023-06-13",
#             "weight": 0.135,
#             "width": 12.0,
#             "length": 18.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 15,
#             "isbn": 9786230310737,
#             "authorID": "AU0102",
#             "title": "Akasha : Trace, Recollections Of A Forensic Researcher 11",
#             "basePrice": 34000,
#             "description": "Di antara jenis buku lainnya, komik memang disukai oleh semua kalangan mulai dari anak kecil hingga orang dewasa. Alasan komik lebih disukai oleh banyak orang karena disajikan dengan penuh dengan gambar dan cerita yang mengasyikan sehingga mampu menghilangkan rasa bosan di kala waktu senggang.\r\n\r\nKomik seringkali dijadikan sebagai koleksi dan diburu oleh penggemarnya karena serinya yang cukup terkenal dan kepopulerannya terus berlanjut sampai saat ini. Dalam memilih jenis komik, ada baiknya perhatikan terlebih dahulu ringkasan cerita komik di sampul bagian belakang sehingga sesuai dengan preferensi pribadi pembaca.\r\n\r\nM&C! Publishing adalah penerbit di bawah Divisi Ritel dan Penerbitan Grup Kompas Gramedia, perusahaan penerbitan terbesar di Indonesia. Grup Kompas Gramedia memulai usaha dengan fokus di media cetak. Dalam perkembangannya, perusahaan telah berkembang menjadi kelompok usaha dengan berbagai divisi. Di bidang informasi, grup ini juga merambah ke media elektronik dan multimedia. M&C! Penerbitan telah menerbitkan berbagai judul dan jenis buku: komik, komik pendidikan, buku anak-anak, novel, buku nonfiksi. Salah Satunya seperti komik \u201dAkasha : Trace, Recollections Of A Forensic Researcher 11\u201d.\r\n\r\nSinopsis Buku:\r\nSesosok mayat ditemukan di tanah milik Hiroki Dan yang tengah buron. Identitas mayat dipastikan sebagai guru yang menutupi kasus perundungan yang menghebohkan publik. Apakah ini \u201cpenghakiman\u201d yang dilakukan oleh Dan? Kebenaran yang mengejutkan pun terungkap\u2026",
#             "pageNum": 184,
#             "publisherID": "PB0015",
#             "publishDate": "2023-06-05",
#             "weight": 0.12,
#             "width": 13.0,
#             "length": 18.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 16,
#             "isbn": 9786230310683,
#             "authorID": "AU0027",
#             "title": "Akasha : City Hunter - Complete Edition 15",
#             "basePrice": 65000,
#             "description": "Di antara jenis buku lainnya, komik memang disukai oleh semua kalangan mulai dari anak kecil hingga orang dewasa. Alasan komik lebih disukai oleh banyak orang karena disajikan dengan penuh dengan gambar dan cerita yang mengasyikan sehingga mampu menghilangkan rasa bosan di kala waktu senggang.\r\n\r\nKomik seringkali dijadikan sebagai koleksi dan diburu oleh penggemarnya karena serinya yang cukup terkenal dan kepopulerannya terus berlanjut sampai saat ini. Dalam memilih jenis komik, ada baiknya perhatikan terlebih dahulu ringkasan cerita komik di sampul bagian belakang sehingga sesuai dengan preferensi pribadi pembaca.\r\n\r\nM&C! Publishing adalah penerbit di bawah Divisi Ritel dan Penerbitan Grup Kompas Gramedia, perusahaan penerbitan terbesar di Indonesia. Grup Kompas Gramedia memulai usaha dengan fokus di media cetak. Dalam perkembangannya, perusahaan telah berkembang menjadi kelompok usaha dengan berbagai divisi. Di bidang informasi, grup ini juga merambah ke media elektronik dan multimedia. M&C! Penerbitan telah menerbitkan berbagai judul dan jenis buku: komik, komik pendidikan, buku anak-anak, novel, buku nonfiksi. Salah Satunya seperti komik \u201dAKASHA : City Hunter - Complete Edition 15\u201d.\r\n\r\nSInopsis Buku:\r\nYoko, seorang reporter, berusaha menyelidiki City Hunter. Identitas Ryo pun terancam dibongkar!\r\nDalam kisah selanjutnya, Ryo dan Kaori mendapat tugas mengawal aktor bernama Keiichi Kashiwagi, saksi suatu kasus kriminal. Kaori pun sepertinya tertarik dengan ketampanannya. Namun, siapakah sebenarnya aktor tampan itu?",
#             "pageNum": 232,
#             "publisherID": "PB0015",
#             "publishDate": "2023-06-05",
#             "weight": 0.135,
#             "width": 13.0,
#             "length": 19.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 17,
#             "isbn": 9786230034312,
#             "authorID": "AU0067",
#             "title": "Level Comic (LC): Jojo`s Bizarre Adventure 03 - Part 1 Phantom Blood",
#             "basePrice": 80000,
#             "description": "JoJo's Bizarre Adventure adalah manga inovatif yang terkenal dengan karakternya yang aneh, humor yang liar, dan pertempuran yang hingar bingar. Sebuah kisah multigenerasi dari keluarga Joestar yang heroik dan pertempuran tanpa akhir mereka melawan kejahatan! Di akhir Arc Darah Phantom, Jonathan Joestar dan mentornya Zeppelli melanjutkan pengejaran mereka terhadap vampir jahat, Dio! \r\n\r\nTetapi untuk mendapatkannya, mereka harus terlebih dahulu menghadapi antek-antek pembunuhnya! Dalam pertempuran demi pertempuran berdarah, JoJo dan Zeppelli didorong ke batas mereka dan melampaui!\r\nJonathan alias Jojo adalah putra tunggal keluarga bangsawan Inggris, Joestar. Dia bercita-cita menjadi pria terhormat dan menjalani kehidupan yang terkekang. Namun, kehidupannya berubah 180 oleh kemunculan seorang aggressor, Dio Brando. Di sisi Dio yang menjebak Jojo di setiap kesempatan, sebuah topeng batu diam mengawasi dengan aura mengerikan. Cerita seru dan menarik, telah diterbitkan di berbagai negara.\r\n\r\nSinopsis\r\n\r\nJojo mengalami kesulitan saat bertarung di Chain Neck Death Match melawan Tarkus, ksatria legendaris yang disihir oleh Dio. Yang menolong Jojo adalah Zeppeli yang mengetahui takdirnya! Bersama permintaan terakhir dari banyak orang, keberanian, dan harapan menuju masa depan di dalam hatinya, Jojo pun menantang Dio di pertarungan final!\r\n\r\nKomik ini direkomendasikan untuk pembaca yang menyukai genre petualangan.\r\n\r\nInformasi lain :\r\nJudul: LC: JOJO`S BIZARRE ADVENTURE 03 - PART 1 PHANTOM BLOOD\r\nRating: yang diperuntukan untuk pembaca berusia  tahun ke atas.\r\nCerita & Ilustrasi: Hirohiko Araki\r\nProduction: Elex Media Komputindo\r\nTebal: 304 halaman\r\nFormat: Soft Cover\r\nTanggal Terbit: 6 Oktober 2022\r\nISBN : 9786230034312\r\nBerat : 0.225 kg\r\nDimensi : 18 x 13 cm",
#             "pageNum": 304,
#             "publisherID": "PB0002",
#             "publishDate": "2022-10-05",
#             "weight": 0.225,
#             "width": 13.0,
#             "length": 18.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 18,
#             "isbn": 9786230047985,
#             "authorID": "AU0024",
#             "title": "Level Comic: Aku no Hana-Kembang Jahanam 02",
#             "basePrice": 50000,
#             "description": "Di antara jenis buku lainnya, komik memang disukai oleh semua kalangan mulai dari anak kecil hingga orang dewasa. Alasan komik lebih disukai oleh banyak orang karena disajikan dengan penuh dengan gambar dan cerita yang mengasyikan sehingga mampu menghilangkan rasa bosan di kala waktu senggang.\r\n\r\nKomik seringkali dijadikan sebagai koleksi dan diburu oleh penggemarnya karena serinya yang cukup terkenal dan kepopulerannya terus berlanjut sampai saat ini. Dalam memilih jenis komik, ada baiknya perhatikan terlebih dahulu ringkasan cerita komik di sampul bagian belakang sehingga sesuai dengan preferensi pribadi pembaca.\r\n\r\nSinopsis Buku:\r\nKasuga akhirnya berhasil kencan dengan Saeki yang disukainya! Masalahnya, Nakamura memerintahkan Kasuga untuk mengenakan seragam olahraga yang dicurinya selama kencan. Sementara Kasuga dilanda kecemasan, hari kencan pun tiba. Selama Kasuga dan Saeki kencan, ternyata Nakamura terus membuntuti. Di tengah kencan yang berjalan lancar, tiba-tiba Nakamura memberi perintah lagi kepada Kasuga. Kali ini apa lagi perintahnya\u2026!?\r\n\r\nSelling Point:\r\nKomik yang mendapat banyak sekali pujian dan penghargaan.\r\n\r\nProfil Penulis:\r\nSh\u016bz\u014d Oshimi si pengarang manga The Flowers of Evil (Japanese: \u60e1\u306e\u83ef, Hepburn: Aku no Hana) baru saja mengumumkan di akun Twitternya pada hari Senin bahwa ia akan menggambar manga one-shot baru berjudul \u201cKusakabe-san\u201d ketika Futabasha merilis versi baru dari situs Web Comic Action-nya sebagai Web Action pada hari Jumat. Oshimi memperlihatkan sketsa di samping pengumuman.",
#             "pageNum": 192,
#             "publisherID": "PB0002",
#             "publishDate": "2023-06-04",
#             "weight": 0.15,
#             "width": 13.0,
#             "length": 18.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 19,
#             "isbn": 9786230047923,
#             "authorID": "AU0019",
#             "title": "Level Comic: Bungo Stray Dogs 04",
#             "basePrice": 50000,
#             "description": "Di antara jenis buku lainnya, komik memang disukai oleh semua kalangan mulai dari anak kecil hingga orang dewasa. Alasan komik lebih disukai oleh banyak orang karena disajikan dengan penuh dengan gambar dan cerita yang mengasyikan sehingga mampu menghilangkan rasa bosan di kala waktu senggang.\r\n\r\nKomik seringkali dijadikan sebagai koleksi dan diburu oleh penggemarnya karena serinya yang cukup terkenal dan kepopulerannya terus berlanjut sampai saat ini. Dalam memilih jenis komik, ada baiknya perhatikan terlebih dahulu ringkasan cerita komik di sampul bagian belakang sehingga sesuai dengan preferensi pribadi pembaca.\r\n\r\nSinopsis Buku:\r\nAtsushi Nakajima menunaikan pekerjaan normalnya sebagai detektif bersama Kenji Miyazawa yang merupakan seniornya. Kyoka diterima masuk ke agensi detektif, dan konflik besar-besaran dengan Port Mafia pun untuk sementara beres. Namun, saat itulah miliuner Fitzgerald yang mengepalai Guild, kelompok pemilik kemampuan khusus di Amerika Utara sekaligus dalang kerusuhan yang baru saja terjadi, secara langsung menyambangi kantor agensi detektif! Dia mendesak Fukuzawa untuk menyerahkan sesuatu... tak hanya itu, pembunuh eksentrik dari Guild, Montgomery, menyerang Atsushi dan lainnya!\r\n\r\nSelling Point:\r\n- Kisah action supernatural menarik yang terinspirasi dari sastrawan Jepang dan dunia. Para tokohnya diberi nama yang sama dengan sastrawan terkenal dan memiliki kemampuan yang berhubungan dengan karya mereka. \r\n- Telah terbit sebanyak 22 jilid. \r\n- Serial populer yang telah dicetak sebanyak 8,5 juta eksemplar. \r\n- Telah diadaptasi menjadi serial animasi sebanyak 3 musim di Jepang. Musim keempat sedang dalam produksi. \r\n- Telah diadaptasi menjadi novel, komik spin off, film animasi layar lebar, drama panggung, game, dan live action.",
#             "pageNum": 188,
#             "publisherID": "PB0002",
#             "publishDate": "2023-06-04",
#             "weight": 0.145,
#             "width": 12.0,
#             "length": 18.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 20,
#             "isbn": 9786230047695,
#             "authorID": "AU0103",
#             "title": "PET BOOM - Dark Urban Legend 4-",
#             "basePrice": 40000,
#             "description": "Di antara jenis buku lainnya, komik memang disukai oleh semua kalangan mulai dari anak kecil hingga orang dewasa. Alasan komik lebih disukai oleh banyak orang karena disajikan dengan penuh dengan gambar dan cerita yang mengasyikan sehingga mampu menghilangkan rasa bosan di kala waktu senggang.\r\n\r\nKomik seringkali dijadikan sebagai koleksi dan diburu oleh penggemarnya karena serinya yang cukup terkenal dan kepopulerannya terus berlanjut sampai saat ini. Dalam memilih jenis komik, ada baiknya perhatikan terlebih dahulu ringkasan cerita komik di sampul bagian belakang sehingga sesuai dengan preferensi pribadi pembaca.\r\n\r\nSinopsis Buku :\r\nMia, seorang gadis SMA penyuka hewan, ingin sekali memelihara kucing. Di dekat rumahnya, ada sebuah bangunan kosong yang dijuluki \u201cRumah Kucing\u201d saking penuhnya dengan kucing. Saat Mia bermain dengan kucing di sana, barulah dia tahu kalau ternyata rumah itu ada penghuninya!! Yaitu, seorang bibi tua dengan wajah menyeramkan yang konon memakan kucing\u2026!? Selain kisah horor Mia di \u2018\u2019PET BOOM\u2019\u2019, ada beberapa kisah horor lain yang tak kalah seram... Kisah-kisah \u2019\u2019horor masa kini\u2019\u2019, ada di sini!\r\n\r\nSelling Point :\r\nKomik Horror Oneshot, tidak bersambung, yang isinya tentang kisah-kisah kelam nan mencekam, juga tabu, yang tak boleh dilanggar, yang dikemas dalam beberapa cerita pendek...\r\n\r\nInformasi Tambahan:\r\n#komikmisteri #horror #ceritamisteri #horrorcomic #ceritalepas #oneshot #komikelexmedia #serialmisteri #darkurbanlegend #kisahhoror",
#             "pageNum": 200,
#             "publisherID": "PB0002",
#             "publishDate": "2023-06-04",
#             "weight": 0.145,
#             "width": 12.0,
#             "length": 18.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 21,
#             "isbn": 9786230047701,
#             "authorID": "AU0077",
#             "title": "MAO 07",
#             "basePrice": 40000,
#             "description": "Di antara jenis buku lainnya, komik memang disukai oleh semua kalangan mulai dari anak kecil hingga orang dewasa. Alasan komik lebih disukai oleh banyak orang karena disajikan dengan penuh dengan gambar dan cerita yang mengasyikan sehingga mampu menghilangkan rasa bosan di kala waktu senggang.\r\n\r\nKomik seringkali dijadikan sebagai koleksi dan diburu oleh penggemarnya karena serinya yang cukup terkenal dan kepopulerannya terus berlanjut sampai saat ini. Dalam memilih jenis komik, ada baiknya perhatikan terlebih dahulu ringkasan cerita komik di sampul bagian belakang sehingga sesuai dengan preferensi pribadi pembaca.\r\n\r\nSinopsis Buku:\r\nDaigo adalah kakak seperguruan yang penting bagi Mao. Lahir dan bertumbuh bersama, lalu merekomendasikan Mao untuk masuk ke klan Ko yang sama dengannya, bagaikan penyelamat yang memberinya kehidupan normal. Akan tetapi, Daigo memiliki rahasia\u2026\r\n\r\nSelling Point :\r\nKarya Rumiko Takahashi yang sudah terkenal di Indonesia Inuyasha, Ranma 1/2 dan Rinne.\r\n\r\nInformasi Tambahan :\r\n#siluman #monster #rumikotakahashi #mao #nanoka #boyscomic #komikpetualangan\r\n\r\nCerita Sebelumnya :\r\nDatang sebuah cahaya dan kegelapan yang berasal dari Sana, orang yang dicintai Mao. Sana yang seharusnya sudah tewas, mengubah namanya menjadi \u201cYurako\u201d, dan Mao mengetahui bahwa dirinya masih hidup. Namun mengapa Sana berada di pihak Shiranui yang merupakan musuhnya\u2026?",
#             "pageNum": 192,
#             "publisherID": "PB0002",
#             "publishDate": "2023-06-04",
#             "weight": 0.13,
#             "width": 12.0,
#             "length": 18.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 22,
#             "isbn": 9786230047954,
#             "authorID": "AU0065",
#             "title": "Why? Insects - Serangga (Edisi Baru)",
#             "basePrice": 119000,
#             "description": "Why? Insects - Serangga (Edisi Baru) Bermanfaat dan Serangga Berbahaya merupakan seri komik yang ditulis oleh Yearimdang. Pada seri ini akan dibahas mengenai berbagai macam serangga yang bermanfaat bagi kehidupan manusia maupun makhluk hidup lainnya. Di dunia yang sangat luas ini, tentunya kita manusia tidak hidup sendirian. Kita dikelilingi oleh banyak makhluk-makhluk lain seperti hewan dan tumbuhan. Salah satu yang sering kita jumpai yaitu keberadaan serangga di sekitar kita. Selama ini kita banyak menganggap bahwa serangga merupakan hewan yang keberadaannya cukup mengganggu, namun ternyata masih banyak sekali serangga-serangga yang mempunyai banyak manfaat dalam hidup kita. Pada komik ini akan dibahas serangga-serangga bermanfaat tersebut.\r\n\r\nSinopsis Buku:\r\nAda berapa banyak serangga yang hidup bersama kita saat ini? Mulai dari lebah dan kupu-kupu yang terbang mencari sari bunga, nyamuk yang selalu menghampiri kita, lalat yang mengganggu waktu makan kita, dan sebagainya. Wah, ternyata ada banyak, ya! Dikatakan bahwa ada sekitar 100 jenis serangga yang diketahui saat ini, itu artinya masih banyak serangga yang belum kita jumpai! Kalian pasti penasaran dengan kehidupan serangga yang sangat beragam ini, \u2018kan? Yuk, ikuti petualangan Omji dan Komji yang masuk ke dalam dunia serangga!\r\n\r\nSelling Point:\r\nSalah satu seri komik pendidikan dengan penjualan terbaik di Indonesia dan Korea Selatan. Komik ini menyajikan informasi dan pengetahuan baru untuk anak-anak dalam format cerita yang menarik dan penyampaian yang mudah, sehingga wawasan anak-anak akan bertambah tanpa mereka sadari. Karakter yang menggemaskan dan cerita yang seru juga akan membuat anak-anak semakin terhibur membacanya.",
#             "pageNum": 160,
#             "publisherID": "PB0002",
#             "publishDate": "2023-06-04",
#             "weight": 0.25,
#             "width": 18.0,
#             "length": 24.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 23,
#             "isbn": 9786230310997,
#             "authorID": "AU0064",
#             "title": "Solo Leveling 01",
#             "basePrice": 85000,
#             "description": "Solo Leveling (bahasa Korea: \ub098 \ud63c\uc790\ub9cc \ub808\ubca8\uc5c5, translit. Na Honjaman Rebereop, har. \"Hanya Saya Sendiri yang Naik Level\"; Jepang: \u4ffa\u3060\u3051\u30ec\u30d9\u30eb\u30a2\u30c3\u30d7\u306a\u4ef6, Ore Dake Reberuappu-na Kudan) adalah salah satu komik berseri berbahasa Korea asal Korea Selatan yang ditulis oleh Chugong. \r\nKomik ini diadaptasi dari versi novel yang telah terbit lebih dulu dan mendapatkan sambutan luar biasa baik di dalam Korea, maupun di luar negeri, terutama Jepang, sehingga penerbit besar Kadokawa menerbitkannya dalam versi Bahasa Jepang.\r\n\r\nTokoh utama cerita ini adalah Seong Jin-woo, seorang hunter (pemburu) level E yang terkenal paling lemah bahkan di antara sesama level E. Lalu, dia mendapatkan kesempatan sekali seumur hidup ketika terpilih sebagai \"player\" (pemain) oleh program magis yang disebut \"sistem\" dan mendapatkan kemampuan unik yang tidak dimiliki oleh hunter biasa, yaitu kemampuan mengembangkan kekuatan tanpa batas. Dengan memanfaatkan kemampuan baru yang diberikan kepadanya oleh sistem, Jinwoo akhirnya bangkit menjadi hunter terhebat sepanjang sejarah umat manusia. Namun, dia kemudian mendapati dirinya terjebak dalam perang tiada akhir antara para \"penguasa\" (ruler) dan para \"raja\" (monarch), dua kelompok makhluk mirip dewa yang memiliki agenda mereka sendiri dengan umat manusia. \r\n\r\nSinopsis Buku:\r\n10 tahun yang lalu, setelah \"gerbang\" yang menghubungkan dunia nyata dengan dunia monster terbuka, muncul juga orang-orang yang menerima kekuatan untuk berburu monster di dalam penjara bawah tanah. Mereka dikenal sebagai \"hunter\". \r\nNamun, tidak semua hunter itu kuat.\r\nSung Jin-Woo, seorang hunter level E dengan julukan \u201csenjata terlemah umat manusia\u201d. Dia terpaksa terus menjadi hunter demi membiayai pengobatan ibunya\u2026 hingga suatu hari kelompok hunternya harus menghadapi monster yang sangat kuat!?\r\n\r\nSelling Point:\r\n- Ada versi anime dan novelnya\r\n- Cerita bertema dungeon (penjara bawah tanah) yang paling popular saat ini\r\n- Cerita seru cocok untuk pembaca pria dan wanita\r\n- Komik berwarna",
#             "pageNum": 168,
#             "publisherID": "PB0015",
#             "publishDate": "2023-06-02",
#             "weight": 0.15,
#             "width": 13.0,
#             "length": 18.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 24,
#             "isbn": 9786230308260,
#             "authorID": "AU0091",
#             "title": "AKASHA : Ito Junji Compilation 03 -  Souichi's Convenient Curses",
#             "basePrice": 95000,
#             "description": "Junji Ito adalah seorang mangaka Jepang terkenal yang mengkhususkan diri dalam genre horor. Beliau dikenal karena karya-karyanya yang gelap, menakutkan, dan sering kali mengganggu imajinasi pembaca. Ito-sensei telah menciptakan banyak karya manga yang populer dan diakui secara internasional.\r\n\r\nIto Junji Compilation 3: Souichi's Convenient Curses merupakan bagian dari seri kompilasi karya beliau. Sebelumnya, m&c! juga telah menerbitkan volume satu dan duanya yang mengusung cerita berbeda dengan tokoh yang juga berbeda, yaitu Ito Junji Compilation 1: Tomie dan Ito Junji Compilation 2: Tomie.\r\n\r\nSouichi's Convenient Curses terdiri dari kumpulan kisah seputar Souchi Tsujii, anak bungsu keluarga Tsujii yang aneh. Dia suka mengulum paku dan bertingkah seperti vampir. Setiap bab dalam buku ini mengandung cerita berbeda. Dalam setiap kisahnya, Souichi bertemu dengan berbagai orang yang secara tidak sengaja memancing kemarahannya, membuatnya melancarkan kutukan kepada mereka. Kutukan-kutukan ini sering kali aneh, mengerikan, dan penuh dengan kekuatan gelap. Entah itu mengubah orang menjadi boneka hidup, memanipulasi objek untuk menyebabkan kerusakan, atau melepaskan roh jahat, kutukan Souichi memiliki efek yang mendalam dan mengganggu terhadap para korbannya. Terlepas dari sikapnya yang menakutkan dan tindakannya yang kejam, Souichi sendiri sering kali menghadapi konsekuensi dari kutukannya sendiri. Kisah-kisah dalam buku membahas kedalaman jiwa manusia, mengeksplorasi tema balas dendam, kekuasaan, dan konsekuensi dari tindakan seseorang.\r\n\r\nSinopsis Buku:\r\n\u201cIngat, ya!\r\nKalian pasti akan ketakutan!!\u201d\r\nSouichi, putra kedua keluarga Tsuji yang aneh. Mulutnya gemeletakan karena mengulum paku. Dia juga sering terlibat dalam kejadian-kejadian mengerikan.\r\nSelamat datang ke dunia aneh Souichi, yang terkadang diseling tawa sinis\u2026\r\n\r\nKeunggulan:\r\n- Karya mangaka horor legendaris, Ito Junji,\r\n- Gambarnya bagus dan menyeramkan, mendukung kisahnya yang mencekam.\r\n- Ceritanya seru dan bikin penasaran.\r\n- Ada animenya di Netflix.\r\n- Terdiri dari beberapa kisah yang dapat dibaca secara acak.",
#             "pageNum": 416,
#             "publisherID": "PB0015",
#             "publishDate": "2023-05-30",
#             "weight": 0.25,
#             "width": 13.0,
#             "length": 18.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 25,
#             "isbn": 9786230047671,
#             "authorID": "AU0023",
#             "title": "Detektif Conan 102",
#             "basePrice": 50000,
# ...
#         },
#         {
#             "index": 112,
#             "isbn": 9786230412462,
#             "authorID": "AU0039",
#             "title": "Buku Ensiklopedia Sains & Teknologi: Alat dan Mesin",
#             "basePrice": 175000,
#             "description": "Ensiklopedia Sains & Teknologi: Alat dan Mesin menjelaskan hal-hal unik dan rahasia di balik produk sains dan teknologi berupa mesin dan alat di sekitar kita, seperti cara kerja roller coaster, kompor gas, hingga eskalator. Bagaimana kita bisa bermain bungee jumping dengan aman? Bagaimana asal mula pintu otomatis? Seperti apa bentuk stapler pada zaman dahulu? Bagaimana toilet bisa dipasang di dalam rumah tanpa mengeluarkan bau? Semua hal dibahas secara detail dan menarik dengan penjelasan yang mudah dipahami sehingga kamu tidak sulit mempelajarinya dan menjadikanmu ilmuwan masa depan yang hebat!\r\n\r\nDalam program jelajah pulau terpencil atau tidak berpenghuni seperti The Law of the Jungle, kita dapat melihat bagaimana para pesertanya merasa menderita dan tidak nyaman. Mengapa demikian? Itu karena tidak ada alat dan mesin, seperti peralatan dapur dan toilet yang biasa kita gunakan dalam kehidupan sehari-hari. Berapa banyak alat dan mesin yang kita temui dari bangun hingga tertidur? Kita hidup dengan alat dan mesin yang tak terhitung jumlahnya. Mulai dari pendingin ruangan yang membuat kita bisa tidur saat cuaca panas, alarm yang membuat kita terbangun, toilet untuk buang air, penanak nasi yang ibu pakai untuk memasak nasi, pengering rambut, setrika untuk merapikan pakaian kusut, lift untuk berpindah pindah lantai, mobil dan bus untuk pergi ke sekolah, alat tulis yang digunakan di kelas, wahana untuk bermain di luar selama jam istirahat, TV untuk hiburan saat di rumah, hingga sikat gigi untuk membersihkan gigi sebelum kita tidur,\r\n\r\nSelling Point:\r\n- Memberikan informasi secara detail mengenai teknologi dalam hidup keseharian dengan bahasa yang asyik dan mudah dimengerti. \r\n- Banyak ilustrasi, foto, dan komik lucu untuk mempermudah dan menambah kesenangan anak-anak dalam mempelajari sains & teknologi. \r\n- Dilengkapi info para ilmuwan hebat dan fakta-fakta menarik seputar sains dan teknologi. \r\n- Terdapat soal esai di setiap akhir bagian untuk mengasah kemampuan terhadap materi yang sudah dipelajari.",
#             "pageNum": 208,
#             "publisherID": "PB0008",
#             "publishDate": "2023-04-02",
#             "weight": 0.28,
#             "width": 18.0,
#             "length": 24.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 113,
#             "isbn": 9789797946746,
#             "authorID": "AU0063",
#             "title": "Unrivaled",
#             "basePrice": 105000,
#             "description": "Setelah mengalami tiga kali pengalaman buruk: perselingkuhan sang ayah, dikhianati mantan pacar, dan kematian sahabat kecilnya, Gwen bertekad untuk tidak pernah lagi percaya dengan yang namanya cinta. Karena traumanya itu, Gwen bahkan sampai didiagnosis\r\nmengidap generalized anxiety disorder dan trust issue.\r\n\r\nNamun, tak disangka, kecintaan Gwen pada hewan membuatnya terjerumus untuk menyepakati sebuah pertaruhan bodoh. Demi hadiah taruhan berupa rubah fennec yang terkenal mahal, ia menerima tantangan untuk menjadi pacarnya Salga\u2014mahasiswa fakultas kedokteran yang terkenal tampan dan cuek. \r\n\r\nBerkat dewi fortuna yang sedang mendukungnya, Gwen berhasil menjadi pacar cowok tsundere itu. Sayangnya, ketika Gwen mulai nyaman dengan hubungan mereka, penyebab traumanya di masa lalu terkuak. Salga ternyata memiliki ikatan yang kuat dengan penyebab trauma itu. Mental Gwen kembali menjadi kacau yang berakibat munculnya rasa cemas yang tak terkendali hingga mempengaruhi kehidupannya. \r\n\r\nUntuk mendapatkan kembali ketenangan dalam hidupnya, sanggupkah Gwen menghadapi traumanya? Dan, bagaimana sikap Salga setelah tahu bahwa dirinya terikat dengan masa lalu gadis yang ia cintai itu?\r\n\r\nTentang Penulis:\r\nMarsella Tina, bisa dipanggil Tina atau Sella, lahir pada tanggal 16 Agustus. Suka mengubah nama pena, tapi sejauh ini tetap bertahan dengan nama pena ShinyAlph di sosial media. Kpopers garis keras, suka EXO, NCT, Red Velvet, dan Apink. Bias sejauh ini baru Chanyeol, Sehun, Jeno, dan Jaehyun. Belum tahu nanti, kayaknya bakal bertambah karena aku suka oleng. Suka banget menghalu, apa lagi yang romantis-romantis. Karena hobi itulah bisa tercipta Unrivaled ini.\r\n\r\nInformasi Tambahan\r\nTahun Terbit: Cetakan Pertama, 2023",
#             "pageNum": 356,
#             "publisherID": "PB0022",
#             "publishDate": "2023-04-02",
#             "weight": 0.26,
#             "width": 13.0,
#             "length": 19.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 114,
#             "isbn": 9786230046926,
#             "authorID": "AU0094",
#             "title": "Radiant 04",
#             "basePrice": 45000,
#             "description": "Radiant (bahasa Jepang: \u30e9\u30c7\u30a3\u30a2\u30f3 Hepburn: Radian) adalah sebuah seri manga Perancis yang ditulis dan diilustrasikan oleh Tony Valente. Seri ini diterbitkan oleh Ankama sejak tahun 2013 dan sekarang telah dibundel menjadi 16 volume dalam bahasa Prancis. Seri ini kemudian diterbitkan oleh penerbit Jepang Asuka Shinsha pada tahun 2015, membuatnya menjadi mantra Prancis pertama yang diterbitkan di Jepang. Seri ini telah dilisensi oleh Viz Media dalam bahasa Inggris sejak tahun 2018 dan sekarang sudah diterbitkan sebanyak 14 volume. Seri ini juga tersedia dalam beberapa bahasa lainnya seperti Jerman, Italia, dan Spanyol. Seri ini diadaptasi menjadi anime oleh Lerche yang ditayangkan sejak tanggal 6 Oktober 2018 hingga 23 Februari 2019. Musim keduanya mulai tayang sejak tanggal 2 Oktober 2019.\r\n\r\nSeth, tokoh protagonis dari Radiant, adalah penyihir remaja yang selamat dari serangan Nemesis sepuluh tahun sebelumnya. Seth bercita-cita untuk mengalahkan semua Nemesis dan membawa kedamaian bagi para penyihir dan seluruh umat manusia. Seth kemudian memulai pencarian untuk menemukan tempat yang menjadi asal muasal Nemesis, Radiant.\r\n\r\nSinopsis Buku:\r\nKuulangi: Aku di sini sebagai pengamat. Kehadiranmu mengumumkan munculnya kekuatan baru. Aku yang datang sendiri untuk menyaksikan lahirnya keseimbangan baru ini. Dengan kata lain, pihak mana yang akan ikuti?\r\n\r\nSelling Point:\r\nKomik manga pertama di Indonesia. Sudah diterjemahkan dalam berbagai bahasa.\r\n\r\nInformasi Tambahan:\r\n#Radiant #manfra #Seth #TonyValente",
#             "pageNum": 184,
#             "publisherID": "PB0002",
#             "publishDate": "2023-03-31",
#             "weight": 0.15,
#             "width": 12.0,
#             "length": 18.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 115,
#             "isbn": 9786026714794,
#             "authorID": "AU0003",
#             "title": "Si Juki Anak Kosan Vol 3",
#             "basePrice": 84000,
#             "description": "Wah, si Juki dan kawan-kawan kembali dengan kisah yang super absurd di kosan. Mulai dari bertukar nasib, ngambil alih Warteg Mbok Jum hingga membuat mesin pemberantas kegalauan menjadi bagian dari hari-hari si Juki sebagai mahasiswa dan anak kosan.\r\n\r\nNah, penasaran kan? Jadi tunggu apalagi. Ayo beli buku ini sekarang. Tapi ingat di toko buku gak bisa ngutang.\r\nKalo Jepang punya Doraemon, kalo kita punya @jukihoki ! Karakter iconic yang satu ini emang tak terlupakan ya, apalagi karakter ini menggambarkan kehidupan sehari-hari mahasiswa yang cukup relate di Indonesia\ud83d\udc4c\ud83c\udffb Tapi dibalik kesuksesan karakter ini, sebenarnya value apa sih yang diperkuat dan dituangin sama @fazameonk dalam karakter @jukihoki ? - #ARAHJournal\r\n\r\n#\ud835\ude71\ud835\ude74\ud835\ude81\ud835\ude70\ud835\ude7d\ud835\ude78\ud835\ude71\ud835\ude74\ud835\ude73\ud835\ude70 \ud83d\udc4a\ud83c\udffb Assalamu'alaikum geess. Siapa nih yg nggak kenal Muhammad Marzuki alias Juki, aktor komik nomor 1. \ud83d\udcd6 Buku ini tentang biografi Juki, calon presiden di tahun 2014. Dicerikatan bagaimana kisah awal lahirnya Si Juki, sampai saat Juki melakukan hal yg paling anti mainstream dalam hidupnya yaitu mencalonkan diri sebagai presiden. Bahkan kisah cinta Mak sama Babeh Juki juga diceritain loh. Dari perkenalan bapak & ibunya, dilanjut cerita kakak pertamanya yg percaya sama alien \ud83e\udd23 & kakak keduanya yg doyan selfie \ud83d\udcd6 Si Juki ini termasuk orang yg selalu perhatian sama orang lain. Nggak cuma sama orang sih \ud83e\udd23, sama tumbuhan, hewan, bahkan sama hantu pun ia peduli loh \ud83d\udc4f\ud83c\udffb. Di masa sekolahnya Juki sering membuat organisasi\u00b2 yg bermanfaat buat sekitarnya, mungkin dari sanalah bakat memimpin Juki muncul, hingga ia ingin mencalonkan diri menjadi presiden Indonesia di tahun 2014 Pendapatku tentang buku ini \ud83d\udcda: \ud83d\udcd5 Buku ini lucu, bagus. Sebenernya ini yg beli masku cuma ia tinggalkan begitu saja, ya sudah mari dicap hak milik saja. Karena buku kakak, buku adeknya juga \ud83e\udd23. Emang buku lama & baca lagi di tahun yg jauh banget dari tahun terbitnya. tapi tetep asik kok baca bukunya. \ud83d\udcd5 Buku ini nggak full gambar kayak komik, malah menurutku kayak novel. Tapi ada beberapa part yg bergambar. Bisalah jadi pelarian kalau bosen baca novel. \ud83d\udcd5Slogan #BeraniBeda dari Juki keren banget, \"Jangan selalu mengikuti arus, jadilah diri sendiri dan #BERANIBEDA. Kalau ngikutin arus melulu apa bedanya sama eek?\" \ud83d\udcd5 Di dalam buku ini juga ada petuah\u00b2 dari Babeh. Petuahnya bagus, tapi dikemas dengan lucu, jadi sambil ketawa sambil dapet \"Toedjoeh Petoeah Sakti\". Petuah paling lucu yg \"BAB Setiap Pagi\" dari judulnya aja udah lucu \ud83e\udd23. Terus sama yg \"berani\" juga lucu sih, kok bisa itu lo pocongnya malah kabur, sangat tidak menyangka \ud83e\udd23 \ud83d\udcd5 Sebagai capres Tahun 2014, jelas Juki punya Visi-Misi. Visi-Misi keren loh. Meskipun ada singkatan\u00b2 lucu, tapi nggak ngurangin bobot Visi-Misi nya\ud83e\udd23. Intip foto buat lihat Visi-Misi Juki Tak kasih tahu, Juki cocok buat kita\u00b2 yg jomlo karena prokernya ada yg menguntungkan para jomlo",
#             "pageNum": 190,
#             "publisherID": "PB0020",
#             "publishDate": "2023-03-30",
#             "weight": 0.22,
#             "width": 14.0,
#             "length": 20.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 116,
#             "isbn": 9786235729503,
#             "authorID": "AU0021",
#             "title": "My Wife`s My Lecturer, My Husband`s My Student",
#             "basePrice": 85000,
#             "description": "Semua orang memiliki kisahnya sendiri-sendiri. Kisah itu terangkum dalam tempat yang dinamakan kenangan. Untuk mengabadikan kenangan itu, Kami menuliskan kisah kami berdua dalam buku ini. Ada banyak kesenangan dan kesedihan yang kami lalui bersama dalam sebuah ikatan yang dinamakan rumah tangga. Bahwa rumah tangga itu bukan untuk menuntut semua hal baik pada pasangan, tetapi menerima setiap kekurangan pasangan dan menjadikan semua itu kesempurnaan. Semoga pembaca bisa memetik hikmah dari setiap kisah yang kami tulis.\r\n\r\nTentang Penulis:\r\nAkhmad Fauzan, Begitulah sang ayah memberinya nama setelah dia lahir pada tanggal 21 Desember 1982 di Desa Cibuyur, Pemalang. Ayahnya yang bernama Wahyudin dan Ibunya yang bernama Baroyah membesarkannya dengan penuh kasih sayang.\r\n\r\nPendidikan Tingkat Kanak-Kanak atau TK tidak pernah ditempuhnya karena kala itu belum ada satupun TK di desanya. Dia langsung menempuh pendidikan di SDN Mereng, MTs Nurul Huda kemudian SMAN Belik sebelum kuliah di UMP.\r\n\r\nMoto hidupnya adalah \"Khoirunnaas anfa'uhum linnaas\" yang artinya sebaik-baik manusia adalah yang memberi manfaat bagi manusia lainnya. Moto ini membawanya sering diundang menjadi seorang motivator bagi para pelajar tingkat SMP, SMA, maupun Perguruan Tinggi. Beberapa sekolah juga sering mengundangnya mengisi training motivasi ataupun \"ice breaking\" untuk para gurunya.\r\n\r\nEli Antina, Terlahir pada tanggal 7 Juli 1976 dari seorang ibu bernama Murtiyah dan ayah bernama Mirun. Eli Antina, S. Pd menghidupkan masa kecilnya di Keser, Notog. Kecamatan Patikraja, Kabupaten Banyumas, Jawa Tengah.\r\n\r\nPendidikan Tingkat Kanak-kanak hingga SMU dia tempuh di desanya sebelum mengambil kuliah jurusan Pendidikan Bahasa Inggris di UNNES (Universitas Negeri Semarang) yang dia selesaikan di tahun 2000.\r\n\r\nCita-cita terbesarnya adalah menjadi seorang Ibu rumah tangga, namun karena jodoh belum menghampirinya pasca lulus S-1, maka dia memutuskan untuk menjadi guru di sebuah SMK Pariwisata di Purwokerto. Belum ada satu tahun di SMK, dia diterima mengajar sebagai dosen luar biasa di STAIN Purwokerto (sekarang UIN SAIZU) dengan tugas mengajar Bahasa Inggris di Pusat Bahasa dari tahun 2001 hingga 2010.\r\n\r\nInformasi Tambahan\r\nTahun Terbit: Cetakan Pertama, Desember 2022",
#             "pageNum": 174,
#             "publisherID": "PB0014",
#             "publishDate": "2023-03-29",
#             "weight": 0.155,
#             "width": 14.0,
#             "length": 20.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 117,
#             "isbn": 9786230310423,
#             "authorID": "AU0068",
#             "title": "AKASHA : Chainsaw Man 02",
#             "basePrice": 48000,
#             "description": "Di antara jenis buku lainnya, komik memang disukai oleh semua kalangan mulai dari anak kecil hingga orang dewasa. Alasan komik lebih disukai oleh banyak orang karena disajikan dengan penuh dengan gambar dan cerita yang mengasyikan sehingga mampu menghilangkan rasa bosan di kala waktu senggang.\r\n\r\nKomik seringkali dijadikan sebagai koleksi dan diburu oleh penggemarnya karena serinya yang cukup terkenal dan kepopulerannya terus berlanjut sampai saat ini. Dalam memilih jenis komik, ada baiknya perhatikan terlebih dahulu ringkasan cerita komik di sampul bagian belakang sehingga sesuai dengan preferensi pribadi pembaca.\r\n\r\nM&C! Publishing adalah penerbit di bawah Divisi Ritel dan Penerbitan Grup Kompas Gramedia, perusahaan penerbitan terbesar di Indonesia. Grup Kompas Gramedia memulai usaha dengan fokus di media cetak. Dalam perkembangannya, perusahaan telah berkembang menjadi kelompok usaha dengan berbagai divisi. Di bidang informasi, grup ini juga merambah ke media elektronik dan multimedia. M&C! Penerbitan telah menerbitkan berbagai judul dan jenis buku: komik, komik pendidikan, buku anak-anak, novel, buku nonfiksi. Salah Satunya seperti komik \u201dAKASHA : Chainsaw Man 02\u201d.\r\n\r\nSinopsis Buku:\r\nDenji, pemuda super miskin yang dikejar banyak utang, bekerja sebagai devil hunter bersama iblis bernama Pochita. Hari-harinya sebagai manusia kasta terbawah berubah total setelah sebuah pengkhianatan brutal. Meski Denji menyimpan iblis dalam tubuhnya setelah insiden tersebut, dia tetap harus memburu iblis agar bisa bertahan hidup!?",
#             "pageNum": 192,
#             "publisherID": "PB0015",
#             "publishDate": "2023-04-07",
#             "weight": 0.15,
#             "width": 13.0,
#             "length": 19.0,
#             "language": "Indonesia"
#         },
#         {
#             "index": 118,
#             "isbn": 9786230308116,
#             "authorID": "AU0009",
#             "title": "AKASHA : Wotakoi : Love is Hard for Otaku 09",
#             "basePrice": 40000,
#             "description": "Kabakura dan Koyanagi menikah!? Apakah pasangan tertua kita yang tak pernah berhenti bertengkar ini akan benar-benar mengikat janji suci? Atau gambar di cover hanya pancingan saja? Lalu bagaimana dengan hubungan Naoya dan Ko setelah pergi nonton berdua? Hubungan mereka akan semakin dekat\u2026 atau sebaliknya\u2026?",
#             "pageNum": 136,
#             "publisherID": "PB0015",
#             "publishDate": "2022-10-08",
#             "weight": 0.105,
#             "width": 13.0,
#             "length": 18.0,
#             "language": "Indonesia"
#         }
#     ]
# }

# %%
# author.json
result = authDF.to_json(orient="table")
parsed = loads(result)
print(dumps(parsed, indent=4))

authDF.to_json(r'C:\Users\StepHomie\Documents\Hans St\Code\Jupyter\Seleksi-2023-Tugas-1\Data Scraping\data\author.json', orient="table", indent=4)
# Out:
# {
#     "schema": {
#         "fields": [
#             {
#                 "name": "index",
#                 "type": "integer"
#             },
#             {
#                 "name": "authorID",
#                 "type": "string"
#             },
#             {
#                 "name": "authorName",
#                 "type": "string"
#             },
#             {
#                 "name": "description",
#                 "type": "string"
#             }
#         ],
#         "primaryKey": [
#             "index"
#         ],
#         "pandas_version": "1.4.0"
#     },
#     "data": [
#         {
#             "index": 0,
#             "authorID": "AU0001",
#             "authorName": "TSUTOMO SATO",
#             "description": "by 18221171"
#         },
#         {
#             "index": 1,
#             "authorID": "AU0002",
#             "authorName": "Ojiro Makoto",
#             "description": "by 18221171"
#         },
#         {
#             "index": 2,
#             "authorID": "AU0003",
#             "authorName": "Faza Meonk",
#             "description": "by 18221171"
#         },
#         {
#             "index": 3,
#             "authorID": "AU0004",
#             "authorName": "RYOHGO NARITA/SHINTA FUJIMOTO",
#             "description": "by 18221171"
#         },
#         {
#             "index": 4,
#             "authorID": "AU0005",
#             "authorName": "TAPPEI NAGATSUKI/MAKOTO FUGETSU/SHINICHIROU OTSUKA",
#             "description": "by 18221171"
#         },
#         {
#             "index": 5,
#             "authorID": "AU0006",
#             "authorName": "Motohiro Katou,",
#             "description": "by 18221171"
#         },
#         {
#             "index": 6,
#             "authorID": "AU0007",
#             "authorName": "Soichiro YAMAMOTO",
#             "description": "by 18221171"
#         },
#         {
#             "index": 7,
#             "authorID": "AU0008",
#             "authorName": "Tsuina Miura / Takahiro Oba",
#             "description": "by 18221171"
#         },
#         {
#             "index": 8,
#             "authorID": "AU0009",
#             "authorName": "FUJITA",
#             "description": "by 18221171"
#         },
#         {
#             "index": 9,
#             "authorID": "AU0010",
#             "authorName": "Jougi Shiraishi",
#             "description": "by 18221171"
#         },
#         {
#             "index": 10,
#             "authorID": "AU0011",
#             "authorName": "Muneyuki Kaneshiro,",
#             "description": "by 18221171"
#         },
#         {
#             "index": 11,
#             "authorID": "AU0012",
#             "authorName": "Motohiro Katou",
#             "description": "by 18221171"
#         },
#         {
#             "index": 12,
#             "authorID": "AU0013",
#             "authorName": "Irvan Aqila",
#             "description": "by 18221171"
#         },
#         {
#             "index": 13,
#             "authorID": "AU0014",
#             "authorName": "Sihanjir /Bangsyah",
#             "description": "by 18221171"
#         },
#         {
#             "index": 14,
#             "authorID": "AU0015",
#             "authorName": "One",
#             "description": "by 18221171"
#         },
#         {
#             "index": 15,
#             "authorID": "AU0016",
#             "authorName": "Valerie Patkar",
#             "description": "by 18221171"
#         },
#         {
#             "index": 16,
#             "authorID": "AU0017",
#             "authorName": "Hitsuji Gondaira",
#             "description": "by 18221171"
#         },
#         {
#             "index": 17,
#             "authorID": "AU0018",
#             "authorName": "Nobuhiro Watsuki",
#             "description": "by 18221171"
#         },
#         {
#             "index": 18,
#             "authorID": "AU0019",
#             "authorName": "Kafka Asagiri",
#             "description": "by 18221171"
#         },
#         {
#             "index": 19,
#             "authorID": "AU0020",
#             "authorName": "Erni Windiyarti",
#             "description": "by 18221171"
#         },
#         {
#             "index": 20,
#             "authorID": "AU0021",
#             "authorName": "Akhmad Fauzan & Eli Antina",
#             "description": "by 18221171"
#         },
#         {
#             "index": 21,
#             "authorID": "AU0022",
#             "authorName": "Seimaru Amagi & Fumiya Sato",
#             "description": "by 18221171"
#         },
#         {
#             "index": 22,
#             "authorID": "AU0023",
#             "authorName": "Aoyama Gosho",
#             "description": "by 18221171"
#         },
#         {
#             "index": 23,
#             "authorID": "AU0024",
#             "authorName": "SHUZO OSHIMI",
#             "description": "by 18221171"
#         },
#         {
#             "index": 24,
#             "authorID": "AU0025",
#             "authorName": "Rumiko Takahashi",
#             "description": "by 18221171"
#         },
#         {
#             "index": 25,
#             "authorID": "AU0026",
#             "authorName": "Zhaenal Fanani - Regu Kancil Studio",
#             "description": "by 18221171"
#         },
#         {
#             "index": 26,
#             "authorID": "AU0027",
#             "authorName": "Hojo Tsukasa",
#             "description": "by 18221171"
#         },
#         {
#             "index": 27,
#             "authorID": "AU0028",
#             "authorName": "Dianobi",
#             "description": "by 18221171"
#         },
#         {
#             "index": 28,
#             "authorID": "AU0029",
#             "authorName": "JVSAN",
#             "description": "by 18221171"
#         },
#         {
#             "index": 29,
#             "authorID": "AU0030",
#             "authorName": "Usbatun Shaliha",
#             "description": "by 18221171"
#         },
#         {
#             "index": 30,
#             "authorID": "AU0031",
#             "authorName": "Annisa Nisfihani",
#             "description": "by 18221171"
#         },
#         {
#             "index": 31,
#             "authorID": "AU0032",
#             "authorName": "Yana Toboso",
#             "description": "by 18221171"
#         },
#         {
#             "index": 32,
#             "authorID": "AU0033",
#             "authorName": "Arswendo Atmowiloto",
#             "description": "by 18221171"
#         },
#         {
#             "index": 33,
#             "authorID": "AU0034",
#             "authorName": "Haruichi Furudate",
#             "description": "by 18221171"
#         },
#         {
#             "index": 34,
#             "authorID": "AU0035",
#             "authorName": "Miyuki Mitsubachi,",
#             "description": "by 18221171"
#         },
#         {
#             "index": 35,
#             "authorID": "AU0036",
#             "authorName": "Nao Hinachi",
#             "description": "by 18221171"
#         },
#         {
#             "index": 36,
#             "authorID": "AU0037",
#             "authorName": "Kak Freddie & Kak Andiko",
#             "description": "by 18221171"
#         },
#         {
#             "index": 37,
#             "authorID": "AU0038",
#             "authorName": "Ruth Ware",
#             "description": "by 18221171"
#         },
#         {
#             "index": 38,
#             "authorID": "AU0039",
#             "authorName": "KL Management",
#             "description": "by 18221171"
#         },
#         {
#             "index": 39,
#             "authorID": "AU0040",
#             "authorName": "HAZUKI MINASE, ITSUKI KAMEYA",
#             "description": "by 18221171"
#         },
#         {
#             "index": 40,
#             "authorID": "AU0041",
#             "authorName": "Xiao Jiangnan",
#             "description": "by 18221171"
#         },
#         {
#             "index": 41,
#             "authorID": "AU0042",
#             "authorName": "Dian K & Aan W",
#             "description": "by 18221171"
#         },
#         {
#             "index": 42,
#             "authorID": "AU0043",
#             "authorName": "Hata Kenjiro",
#             "description": "by 18221171"
#         },
#         {
#             "index": 43,
#             "authorID": "AU0044",
#             "authorName": "Aida Iro",
#             "description": "by 18221171"
#         },
#         {
#             "index": 44,
#             "authorID": "AU0045",
#             "authorName": "Yim Kang Jae",
#             "description": "by 18221171"
#         },
#         {
#             "index": 45,
#             "authorID": "AU0046",
#             "authorName": "Muhammad 'Mice' Mirsad",
#             "description": "by 18221171"
#         },
#         {
#             "index": 46,
#             "authorID": "AU0047",
#             "authorName": "Nurul Chomaria",
#             "description": "by 18221171"
#         },
#         {
#             "index": 47,
#             "authorID": "AU0048",
#             "authorName": "M&C",
#             "description": "by 18221171"
#         },
#         {
#             "index": 48,
#             "authorID": "AU0049",
#             "authorName": "YeaRimDang",
#             "description": "by 18221171"
#         },
#         {
#             "index": 49,
#             "authorID": "AU0050",
#             "authorName": "Kamome Shirahama",
#             "description": "by 18221171"
#         },
#         {
#             "index": 50,
#             "authorID": "AU0051",
#             "authorName": "Akira Toriyama",
#             "description": "by 18221171"
#         },
#         {
#             "index": 51,
#             "authorID": "AU0052",
#             "authorName": "Ohba Tsugumi",
#             "description": "by 18221171"
#         },
#         {
#             "index": 52,
#             "authorID": "AU0053",
#             "authorName": "Eiichiro Oda",
#             "description": "by 18221171"
#         },
#         {
#             "index": 53,
#             "authorID": "AU0054",
#             "authorName": "Saniyyah Putri Salsabila Said",
#             "description": "by 18221171"
#         },
#         {
#             "index": 54,
#             "authorID": "AU0055",
#             "authorName": "Miki Yoshikawa",
#             "description": "by 18221171"
#         },
#         {
#             "index": 55,
#             "authorID": "AU0056",
#             "authorName": "Lilpudu",
#             "description": "by 18221171"
#         },
#         {
#             "index": 56,
#             "authorID": "AU0057",
#             "authorName": "HAKURI",
#             "description": "by 18221171"
#         },
#         {
#             "index": 57,
#             "authorID": "AU0058",
#             "authorName": "UMI SAKURAI",
#             "description": "by 18221171"
#         },
#         {
#             "index": 58,
#             "authorID": "AU0059",
#             "authorName": "Yoshimura Akemi,",
#             "description": "by 18221171"
#         },
#         {
#             "index": 59,
#             "authorID": "AU0060",
#             "authorName": "Rei Toma",
#             "description": "by 18221171"
#         },
#         {
#             "index": 60,
#             "authorID": "AU0061",
#             "authorName": "One & Yusuke Murata",
#             "description": "by 18221171"
#         },
#         {
#             "index": 61,
#             "authorID": "AU0062",
#             "authorName": "Hiroyuki Takei",
#             "description": "by 18221171"
#         },
#         {
#             "index": 62,
#             "authorID": "AU0063",
#             "authorName": "Marsella Tina",
#             "description": "by 18221171"
#         },
#         {
#             "index": 63,
#             "authorID": "AU0064",
#             "authorName": "Chugong",
#             "description": "by 18221171"
#         },
#         {
#             "index": 64,
#             "authorID": "AU0065",
#             "authorName": "Kwangwoong Lee",
#             "description": "by 18221171"
#         },
#         {
#             "index": 65,
#             "authorID": "AU0066",
#             "authorName": "Sui Ishida",
#             "description": "by 18221171"
#         },
#         {
#             "index": 66,
#             "authorID": "AU0067",
#             "authorName": "Hirohiko Araki",
#             "description": "by 18221171"
#         },
#         {
#             "index": 67,
#             "authorID": "AU0068",
#             "authorName": "Tatsuki Fujimoto",
#             "description": "by 18221171"
#         },
#         {
#             "index": 68,
#             "authorID": "AU0069",
#             "authorName": "NATSU HYUUGA / NEKOKURAGE",
#             "description": "by 18221171"
#         },
#         {
#             "index": 69,
#             "authorID": "AU0070",
#             "authorName": "Kohei Horikoshi",
#             "description": "by 18221171"
#         },
#         {
#             "index": 70,
#             "authorID": "AU0071",
#             "authorName": "Tomohito ODA",
#             "description": "by 18221171"
#         },
#         {
#             "index": 71,
#             "authorID": "AU0072",
#             "authorName": "Yousuke Kaneda",
#             "description": "by 18221171"
#         },
#         {
#             "index": 72,
#             "authorID": "AU0073",
#             "authorName": "TYPE-MOON / REI WATARU",
#             "description": "by 18221171"
#         },
#         {
#             "index": 73,
#             "authorID": "AU0074",
#             "authorName": "Hajime Komoto",
#             "description": "by 18221171"
#         },
#         {
#             "index": 74,
#             "authorID": "AU0075",
#             "authorName": "Yuto Suzuki",
#             "description": "by 18221171"
#         },
#         {
#             "index": 75,
#             "authorID": "AU0076",
#             "authorName": "Tetsuo Hara & Buronson",
#             "description": "by 18221171"
#         },
#         {
#             "index": 76,
#             "authorID": "AU0077",
#             "authorName": "Takahashi Rumiko",
#             "description": "by 18221171"
#         },
#         {
#             "index": 77,
#             "authorID": "AU0078",
#             "authorName": "Oldheva",
#             "description": "by 18221171"
#         },
#         {
#             "index": 78,
#             "authorID": "AU0079",
#             "authorName": "Wataru ISHII",
#             "description": "by 18221171"
#         },
#         {
#             "index": 79,
#             "authorID": "AU0080",
#             "authorName": "YAMAMOTO SOUICHIROU",
#             "description": "by 18221171"
#         },
#         {
#             "index": 80,
#             "authorID": "AU0081",
#             "authorName": "Shinshinhye",
#             "description": "by 18221171"
#         },
#         {
#             "index": 81,
#             "authorID": "AU0082",
#             "authorName": "Kousuke Oono",
#             "description": "by 18221171"
#         },
#         {
#             "index": 82,
#             "authorID": "AU0083",
#             "authorName": "Masashi Kishimoto",
#             "description": "by 18221171"
#         },
#         {
#             "index": 83,
#             "authorID": "AU0084",
#             "authorName": "Alfia Ramadhani",
#             "description": "by 18221171"
#         },
#         {
#             "index": 84,
#             "authorID": "AU0085",
#             "authorName": "Kugil Publishing",
#             "description": "by 18221171"
#         },
#         {
#             "index": 85,
#             "authorID": "AU0086",
#             "authorName": "Haro Aso, Kotaro Takata,",
#             "description": "by 18221171"
#         },
#         {
#             "index": 86,
#             "authorID": "AU0087",
#             "authorName": "Prasodjo Muhammad",
#             "description": "by 18221171"
#         },
#         {
#             "index": 87,
#             "authorID": "AU0088",
#             "authorName": "Gege Akutami",
#             "description": "by 18221171"
#         },
#         {
#             "index": 88,
#             "authorID": "AU0089",
#             "authorName": "ITO Junji",
#             "description": "by 18221171"
#         },
#         {
#             "index": 89,
#             "authorID": "AU0090",
#             "authorName": "Yupitawdr",
#             "description": "by 18221171"
#         },
#         {
#             "index": 90,
#             "authorID": "AU0091",
#             "authorName": "Ito Junji",
#             "description": "by 18221171"
#         },
#         {
#             "index": 91,
#             "authorID": "AU0092",
#             "authorName": "Kim Ji Hun",
#             "description": "by 18221171"
#         },
#         {
#             "index": 92,
#             "authorID": "AU0093",
#             "authorName": "Nene Yukimori",
#             "description": "by 18221171"
#         },
#         {
#             "index": 93,
#             "authorID": "AU0094",
#             "authorName": "TONY VALENTE",
#             "description": "by 18221171"
#         },
#         {
#             "index": 94,
#             "authorID": "AU0095",
#             "authorName": "Tomoki Izumi",
#             "description": "by 18221171"
#         },
#         {
#             "index": 95,
#             "authorID": "AU0096",
#             "authorName": "YOICHI TSUKAHARA/YOSHITO USUI",
#             "description": "by 18221171"
#         },
#         {
#             "index": 96,
#             "authorID": "AU0097",
#             "authorName": "Ken Wakui",
#             "description": "by 18221171"
#         },
#         {
#             "index": 97,
#             "authorID": "AU0098",
#             "authorName": "Koyoharu Gotouge",
#             "description": "by 18221171"
#         },
#         {
#             "index": 98,
#             "authorID": "AU0099",
#             "authorName": "Cixin Liu",
#             "description": "by 18221171"
#         },
#         {
#             "index": 99,
#             "authorID": "AU0100",
#             "authorName": "Yearim dang",
#             "description": "by 18221171"
#         },
#         {
#             "index": 100,
#             "authorID": "AU0101",
#             "authorName": "Pionicon",
#             "description": "by 18221171"
#         },
#         {
#             "index": 101,
#             "authorID": "AU0102",
#             "authorName": "Kei Koga",
#             "description": "by 18221171"
#         },
#         {
#             "index": 102,
#             "authorID": "AU0103",
#             "authorName": "Ryo Azuki",
#             "description": "by 18221171"
#         },
#         {
#             "index": 103,
#             "authorID": "AU0104",
#             "authorName": "Joji Morikawa",
#             "description": "by 18221171"
#         }
#     ]
# }

# %%
# publisher.json
result = publDF.to_json(orient="table")
parsed = loads(result)
print(dumps(parsed, indent=4))

publDF.to_json(r'C:\Users\StepHomie\Documents\Hans St\Code\Jupyter\Seleksi-2023-Tugas-1\Data Scraping\data\publisher.json', orient="table", indent=4)
# Out:
# {
#     "schema": {
#         "fields": [
#             {
#                 "name": "index",
#                 "type": "integer"
#             },
#             {
#                 "name": "publisherID",
#                 "type": "string"
#             },
#             {
#                 "name": "publisherName",
#                 "type": "string"
#             },
#             {
#                 "name": "address",
#                 "type": "string"
#             },
#             {
#                 "name": "phone",
#                 "type": "string"
#             }
#         ],
#         "primaryKey": [
#             "index"
#         ],
#         "pandas_version": "1.4.0"
#     },
#     "data": [
#         {
#             "index": 0,
#             "publisherID": "PB0001",
#             "publisherName": "Sinar angsa",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         },
#         {
#             "index": 1,
#             "publisherID": "PB0002",
#             "publisherName": "Elex Media Komputindo",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         },
#         {
#             "index": 2,
#             "publisherID": "PB0003",
#             "publisherName": "Romancious",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         },
#         {
#             "index": 3,
#             "publisherID": "PB0004",
#             "publisherName": "bukune",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         },
#         {
#             "index": 4,
#             "publisherID": "PB0005",
#             "publisherName": "Salsabila Al-kautsar",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         },
#         {
#             "index": 5,
#             "publisherID": "PB0006",
#             "publisherName": "Salsabila",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         },
#         {
#             "index": 6,
#             "publisherID": "PB0007",
#             "publisherName": "Aria Media Mandiri",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         },
#         {
#             "index": 7,
#             "publisherID": "PB0008",
#             "publisherName": "Bhuana Ilmu Populer",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         },
#         {
#             "index": 8,
#             "publisherID": "PB0009",
#             "publisherName": "Akad x Tekad",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         },
#         {
#             "index": 9,
#             "publisherID": "PB0010",
#             "publisherName": "Loveable",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         },
#         {
#             "index": 10,
#             "publisherID": "PB0011",
#             "publisherName": "Al-Kautsar Kids",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         },
#         {
#             "index": 11,
#             "publisherID": "PB0012",
#             "publisherName": "Akad x Skuad",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         },
#         {
#             "index": 12,
#             "publisherID": "PB0013",
#             "publisherName": "Bukune",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         },
#         {
#             "index": 13,
#             "publisherID": "PB0014",
#             "publisherName": "Ump Press",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         },
#         {
#             "index": 14,
#             "publisherID": "PB0015",
#             "publisherName": "m&c!",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         },
#         {
#             "index": 15,
#             "publisherID": "PB0016",
#             "publisherName": "GagasMedia",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         },
#         {
#             "index": 16,
#             "publisherID": "PB0017",
#             "publisherName": "Kepustakaan Populer Gramedia",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         },
#         {
#             "index": 17,
#             "publisherID": "PB0018",
#             "publisherName": "Gramedia Pustaka Utama",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         },
#         {
#             "index": 18,
#             "publisherID": "PB0019",
#             "publisherName": "Noura Books Publishing",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         },
#         {
#             "index": 19,
#             "publisherID": "PB0020",
#             "publisherName": "Falcon",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         },
#         {
#             "index": 20,
#             "publisherID": "PB0021",
#             "publisherName": "Gema Insani Pers",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         },
#         {
#             "index": 21,
#             "publisherID": "PB0022",
#             "publisherName": "Mediakita",
#             "address": "by 18221171",
#             "phone": "by 18221171"
#         }
#     ]
# }

# %% [markdown]
# ---
# #### (Draft) Scraping Test-Run & Cleaning
# ---

# %%
# Create New Session
driver = webdriver.Chrome(options=chrome_options)
    
# Open Chrome
driver.get(hrefArray[2])
time.sleep(8)

# Get the HTML
html = driver.page_source

# Change html into Soup Class
soup = bsp(html, "lxml")
print(soup.prettify())

# Close
driver.quit()
# Out:
# <html class="" lang="id">
#  <head>
#   <!-- Google Tag Manager -->
#   <script async="" src="https://cdn.yellowmessenger.com/plugin/latest/dist/main.min.js" type="text/javascript">
#   </script>
#   <script async="" src="https://app.yellowmessenger.com/widget/main.js" type="text/javascript">
#   </script>
#   <script async="" src="//cdnt.netcoresmartech.com/webactivity/ADGMOT35CHFLVDHBJNIG50K96B33CLCBGFVBD608PHJ3ICES10U0.js">
#   </script>
#   <script async="" src="//cdnt.netcoresmartech.com/webp/ADGMOT35CHFLVDHBJNIG50K96B33CLCBGFVBD608PHJ3ICES10U0_webp.js">
#   </script>
#   <script async="" src="//cdnt.netcoresmartech.com/webactivity/ADGMOT35CHFLVDHBJNIG50K96B33CLCBGFVBD608PHJ3ICES10U0.js">
#   </script>
#   <script async="" src="//cdnt.netcoresmartech.com/webactivity/ADGMOT35CHFLVDHBJNIG50K96B33CLCBGFVBD608PHJ3ICES10U0.js">
#   </script>
#   <script async="" src="https://webtrafficsource.com/track/code.js">
#   </script>
#   <script async="" data-id="C7OGSDL6KGKTT9CM9QUG" src="https://analytics.tiktok.com/i18n/pixel/static/main.MWJjY2ZiZDQwMA.js" type="text/javascript">
#   </script>
#   <script async="" data-id="C7QCHK56KGKTT9CMBVMG" src="https://analytics.tiktok.com/i18n/pixel/static/main.MWJjY2ZiZDQwMA.js" type="text/javascript">
#   </script>
#   <script async="" src="https://chimpstatic.com/mcjs-connected/js/users/e4bb97926f317d398603ad7c8/8a7067da253537aa9cda00ea4.js">
#   </script>
#   <script async="" src="https://script.accesstrade.co.id/lp.js?cb=1689349133304">
#   </script>
#   <script async="" src="//static.ads-twitter.com/uwt.js">
#   </script>
#   <script async="" src="https://analytics.tiktok.com/i18n/pixel/events.js?sdkid=C7OGSDL6KGKTT9CM9QUG&amp;lib=ttq" type="text/javascript">
#   </script>
#   <script async="" src="https://analytics.tiktok.com/i18n/pixel/events.js?sdkid=C7QCHK56KGKTT9CMBVMG&amp;lib=ttq" type="text/javascript">
#   </script>
#   <script async="" src="https://connect.facebook.net/signals/config/775212506661087?v=2.9.111&amp;r=stable">
#   </script>
#   <script async="" src="https://connect.facebook.net/en_US/fbevents.js">
#   </script>
#   <script async="" src="https://cdn.jsdelivr.net/npm/search-insights@1.3.1" type="text/javascript">
#   </script>
#   <script async="" src="https://static.hotjar.com/c/hotjar-1565272.js?sv=7" type="text/javascript">
#   </script>
#   <script async="" gtm="GTM-T24BH5Q" src="https://www.google-analytics.com/gtm/optimize.js?id=GTM-W59JGX3" type="text/javascript">
#   </script>
#   <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-FVK74FX33P&amp;l=dataLayer&amp;cx=c" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-2DFX21FM6E&amp;l=dataLayer&amp;cx=c" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-T24BH5Q">
#   </script>
#   <script>
#    let gtmContainerId = '';
#         if (window.location.hostname === 'staging.gramedia.com') {
#             gtmContainerId = 'GTM-TLFHPHF'
#         } else if (window.location.hostname === 'www.gramedia.com') {
#             gtmContainerId = 'GTM-T24BH5Q'
#         } else {
#             gtmContainerId = 'GTM-5HBVG55'
#         }
#
#         (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer',gtmContainerId);
#   </script>
#   <!-- End Google Tag Manager -->
#   <base href="/"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="#281e5a" name="theme-color"/>
#   <meta content="index, follow" name="robots"/>
#   <link href="/assets/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="manifest.json" rel="manifest"/>
#   <link href="/assets/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="z91Vp6ZYo9UoX5D4ur6i4Lrl0l1j3DDoCH08fD3n53g" name="google-site-verification"/>
#   <meta content="810657685650228" property="fb:app_id"/>
#   <!--Jixie Tracker-->
#   <!-- <script src="https://scripts.jixie.io/jixietracker.js"></script> -->
#   <!--End Jixie Tracker-->
#   <link href="styles.bf6884ffee424c78f203.css" rel="stylesheet"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <script async="" src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/393095129/?random=1689349133292&amp;cv=11&amp;fst=1689349133292&amp;bg=ffffff&amp;guid=ON&amp;async=1&amp;gtm=45He37c0&amp;u_w=1450&amp;u_h=816&amp;url=https%3A%2F%2Fwww.gramedia.com%2Fproducts%2Fworld-ghost-stories-eropa&amp;hn=www.googleadservices.com&amp;frm=0&amp;auid=799146509.1689349133&amp;uaa=x86&amp;uab=64&amp;uafvl=Not.A%252FBrand%3B8.0.0.0%7CChromium%3B114.0.5735.199%7CGoogle%2520Chrome%3B114.0.5735.199&amp;uamb=0&amp;uap=Windows&amp;uapv=15.0.0&amp;uaw=0&amp;rfmt=3&amp;fmt=4" type="text/javascript">
#   </script>
#   <script async="" src="https://static.hotjar.com/c/hotjar-1905814.js?sv=6">
#   </script>
#   <script async="" charset="utf-8" src="https://script.hotjar.com/modules.5957fbf26d1b525b5a12.js">
#   </script>
#   <style>
#    .clearfix[_ngcontent-web-gramedia-c0]{clear:both;content:"";display:table}.apperance-none[_ngcontent-web-gramedia-c0]{-webkit-appearance:none;-moz-appearance:none;appearance:none}.gm-style[_ngcontent-web-gramedia-c0]   .controls[_ngcontent-web-gramedia-c0]   button[_ngcontent-web-gramedia-c0]{border:0;background-color:#fff;color:rgba(0,0,0,.6);width:35px;height:35px;border-radius:50%}.gm-style[_ngcontent-web-gramedia-c0]   .controls[_ngcontent-web-gramedia-c0]   button[_ngcontent-web-gramedia-c0]:hover{color:rgba(0,0,0,.9)}.gm-style[_ngcontent-web-gramedia-c0]   .controls.zoom-control[_ngcontent-web-gramedia-c0]{display:flex;flex-direction:column;height:auto}.gm-style[_ngcontent-web-gramedia-c0]   .controls.zoom-control[_ngcontent-web-gramedia-c0]   button[_ngcontent-web-gramedia-c0]{font:1.85em Arial;margin:4px 8px;padding:0}.menu-navbar[_ngcontent-web-gramedia-c0]{position:fixed;top:24px;right:0;left:0;background:#fff;color:#0060ae;z-index:100;box-shadow:0 6px 10px #bbbbbb59;height:65px;font-family:Nunito,serif}.menu-navbar[_ngcontent-web-gramedia-c0] > div[_ngcontent-web-gramedia-c0]{clear:both;content:"";display:table;width:100%;display:flex;flex-direction:row;justify-content:flex-start}.menu-navbar[_ngcontent-web-gramedia-c0] > div[_ngcontent-web-gramedia-c0] > .header-logo[_ngcontent-web-gramedia-c0]{flex:1;line-height:1;margin:13px 0 0;display:block}.menu-navbar[_ngcontent-web-gramedia-c0] > div[_ngcontent-web-gramedia-c0] > .header-logo[_ngcontent-web-gramedia-c0]   img[_ngcontent-web-gramedia-c0]{width:185px}.menu-navbar[_ngcontent-web-gramedia-c0] > div[_ngcontent-web-gramedia-c0]   .search-area[_ngcontent-web-gramedia-c0]{flex:14;display:flex}.menu-navbar[_ngcontent-web-gramedia-c0] > div[_ngcontent-web-gramedia-c0]   .search-area[_ngcontent-web-gramedia-c0]   gm-category-selector[_ngcontent-web-gramedia-c0]{display:block;flex:2.3}.menu-navbar[_ngcontent-web-gramedia-c0] > div[_ngcontent-web-gramedia-c0]   .search-area[_ngcontent-web-gramedia-c0]   gm-search-box[_ngcontent-web-gramedia-c0]{width:100%;display:block;flex:5}.menu-navbar[_ngcontent-web-gramedia-c0] > div[_ngcontent-web-gramedia-c0]   .navigation-area[_ngcontent-web-gramedia-c0]{display:flex;flex:4}.menu-navbar[_ngcontent-web-gramedia-c0] > div[_ngcontent-web-gramedia-c0]   .navigation-area[_ngcontent-web-gramedia-c0]   gm-auth-button[_ngcontent-web-gramedia-c0]{display:block;flex:1}.menu-navbar[_ngcontent-web-gramedia-c0] > div[_ngcontent-web-gramedia-c0]   .navigation-area[_ngcontent-web-gramedia-c0]   gm-notification-button[_ngcontent-web-gramedia-c0]{flex:1}.menu-navbar[_ngcontent-web-gramedia-c0] > div[_ngcontent-web-gramedia-c0]   .navigation-area[_ngcontent-web-gramedia-c0]   gm-cart-button[_ngcontent-web-gramedia-c0]{display:block;flex:1;position:relative}.mini-top-header[_ngcontent-web-gramedia-c0]{height:24px;background-color:#ccdfef;position:fixed;top:0;width:100%;z-index:100;font-family:Nunito,serif;font-size:14px}.mini-top-header[_ngcontent-web-gramedia-c0]   a[_ngcontent-web-gramedia-c0]{color:#151515}.mini-top-header[_ngcontent-web-gramedia-c0]   a[_ngcontent-web-gramedia-c0]   i[_ngcontent-web-gramedia-c0]{margin-right:4px}.mini-top-header[_ngcontent-web-gramedia-c0]   a[_ngcontent-web-gramedia-c0]   .help-link[_ngcontent-web-gramedia-c0]{margin:4px 22px;float:right}#mobile-search-box[_ngcontent-web-gramedia-c0]{display:none;z-index:999;position:fixed;top:0;background:#fff;width:100%;box-shadow:0 6px 10px #bbbbbb59}#mobile-search-box[_ngcontent-web-gramedia-c0]   div[_ngcontent-web-gramedia-c0]{text-align:center;position:relative}#mobile-search-box[_ngcontent-web-gramedia-c0]   div[_ngcontent-web-gramedia-c0]   img[_ngcontent-web-gramedia-c0]{width:155px;margin-top:2px}#mobile-search-box[_ngcontent-web-gramedia-c0]   div[_ngcontent-web-gramedia-c0]   gm-cart-button[_ngcontent-web-gramedia-c0]{display:block;position:absolute;top:7px;right:0}.floating-wa[_ngcontent-web-gramedia-c0]{position:fixed;display:flex;justify-content:center;align ...
#   </style>
#   <style>
#    ng-progress{z-index:999999;pointer-events:none}ng-progress[fixed=true] .ng-progress-bar,ng-progress[fixed=true] .ng-spinner{position:fixed}ng-progress[fixed=true] .ng-spinner{top:15px}ng-progress[fixed=true][spinnerPosition=left] .ng-spinner{left:15px}ng-progress[fixed=true][spinnerPosition=right] .ng-spinner{right:15px}ng-progress[thick=true] .ng-spinner-icon{width:24px;height:24px;border-width:3px}ng-progress[thick=true] .ng-bar-placeholder{height:3px!important}ng-progress[dir='ltr+'] .ng-meteor,ng-progress[dir=ltr-] .ng-meteor{-webkit-transform:rotate(3deg);transform:rotate(3deg)}ng-progress[dir='ltr+'][thick=true] .ng-meteor,ng-progress[dir=ltr-][thick=true] .ng-meteor{-webkit-transform:rotate(4deg);transform:rotate(4deg)}ng-progress[dir='ltr+'] .ng-bar,ng-progress[dir='rtl+'] .ng-bar{margin-left:-100%}ng-progress[dir='ltr+'] .ng-meteor,ng-progress[dir='rtl+'] .ng-meteor{right:0}ng-progress[dir='ltr+'] .ng-meteor,ng-progress[dir=rtl-] .ng-meteor{top:-3px}ng-progress[dir='ltr+'][thick=true] .ng-meteor,ng-progress[dir=rtl-][thick=true] .ng-meteor{top:-4px}ng-progress[dir='rtl+'] .ng-meteor,ng-progress[dir=ltr-] .ng-meteor{bottom:-3px}ng-progress[dir='rtl+'][thick=true] .ng-meteor,ng-progress[dir=ltr-][thick=true] .ng-meteor{bottom:-4px}ng-progress[dir='rtl+'] .ng-bar-placeholder,ng-progress[dir=ltr-] .ng-bar-placeholder{-webkit-transform:rotate(180deg);transform:rotate(180deg)}ng-progress[dir='rtl+'] .ng-spinner-icon,ng-progress[dir=ltr-] .ng-spinner-icon{animation-direction:reverse}ng-progress[dir='rtl+'] .ng-meteor,ng-progress[dir=rtl-] .ng-meteor{-webkit-transform:rotate(-3deg);transform:rotate(-3deg)}ng-progress[dir='rtl+'][thick=true] .ng-meteor,ng-progress[dir=rtl-][thick=true] .ng-meteor{-webkit-transform:rotate(-4deg);transform:rotate(-4deg)}ng-progress[spinnerPosition=left] .ng-spinner{left:10px}ng-progress[spinnerPosition=right] .ng-spinner{right:10px}.ng-progress-bar{position:relative;z-index:999999;top:0;left:0;width:100%;zoom:1;opacity:0}.ng-progress-bar.-active{opacity:1;transition:none}.ng-bar-placeholder{position:absolute;height:2px;width:100%}.ng-bar{width:100%;height:100%;-webkit-transform:translate(-100%,0,0);transform:translate(-100%,0,0)}.ng-meteor{display:block;position:absolute;width:100px;height:100%;opacity:1}.ng-spinner{position:absolute;display:block;z-index:1031;top:10px}.ng-spinner-icon{width:18px;height:18px;box-sizing:border-box;-webkit-animation:250ms linear infinite spinner-animation;animation:250ms linear infinite spinner-animation;border:2px solid transparent;border-radius:50%}@-webkit-keyframes spinner-animation{0%{-webkit-transform:rotate(0);transform:rotate(0)}100%{-webkit-transform:rotate(360deg);transform:rotate(360deg)}}@keyframes spinner-animation{0%{-webkit-transform:rotate(0);transform:rotate(0)}100%{-webkit-transform:rotate(360deg);transform:rotate(360deg)}}
#   </style>
#   <style>
#    .clearfix[_ngcontent-web-gramedia-c2]{clear:both;content:"";display:table}.apperance-none[_ngcontent-web-gramedia-c2]{-webkit-appearance:none;-moz-appearance:none;appearance:none}.gm-style[_ngcontent-web-gramedia-c2]   .controls[_ngcontent-web-gramedia-c2]   button[_ngcontent-web-gramedia-c2]{border:0;background-color:#fff;color:rgba(0,0,0,.6);width:35px;height:35px;border-radius:50%}.gm-style[_ngcontent-web-gramedia-c2]   .controls[_ngcontent-web-gramedia-c2]   button[_ngcontent-web-gramedia-c2]:hover{color:rgba(0,0,0,.9)}.gm-style[_ngcontent-web-gramedia-c2]   .controls.zoom-control[_ngcontent-web-gramedia-c2]{display:flex;flex-direction:column;height:auto}.gm-style[_ngcontent-web-gramedia-c2]   .controls.zoom-control[_ngcontent-web-gramedia-c2]   button[_ngcontent-web-gramedia-c2]{font:1.85em Arial;margin:4px 8px;padding:0}.selector[_ngcontent-web-gramedia-c2]   .nav-category[_ngcontent-web-gramedia-c2]{font-size:16px;font-family:Nunito,serif;font-weight:700;color:#0060ae;border:none;background:0 0;margin-right:10px;cursor:pointer;float:right;margin-top:23px}.selector[_ngcontent-web-gramedia-c2]   .nav-category[_ngcontent-web-gramedia-c2]   i[_ngcontent-web-gramedia-c2]{font-size:12px;margin-left:15px;margin-right:20px}.selector[_ngcontent-web-gramedia-c2]   .nav-category-mobile[_ngcontent-web-gramedia-c2]{display:none}.selector[_ngcontent-web-gramedia-c2]   .container[_ngcontent-web-gramedia-c2]{margin-top:88px;padding:20px 0;position:fixed;top:0;left:0;right:0;bottom:0;background:#fff;z-index:1;line-height:42px;font-weight:400;width:100%;max-width:100%;height:460px;min-height:0;box-shadow:0 0 0 0 rgba(0,0,0,.12),0 4px 4px 0 rgba(0,0,0,.24);overflow:auto}.selector[_ngcontent-web-gramedia-c2]   .container[_ngcontent-web-gramedia-c2]   .nav-header-mobile[_ngcontent-web-gramedia-c2]{display:none}.selector[_ngcontent-web-gramedia-c2]   .container[_ngcontent-web-gramedia-c2]   .close-category[_ngcontent-web-gramedia-c2]{display:none;height:30px;width:30px;position:fixed;font-size:30px;font-family:system-ui;background:0 0;border:none;right:10px;color:#0060ae}.selector[_ngcontent-web-gramedia-c2]   .container[_ngcontent-web-gramedia-c2]   .category[_ngcontent-web-gramedia-c2]{margin:auto;display:block}.selector[_ngcontent-web-gramedia-c2]   .container[_ngcontent-web-gramedia-c2]   .category[_ngcontent-web-gramedia-c2]   .inner-category[_ngcontent-web-gramedia-c2]{clear:both;content:"";margin:0 auto;display:flex;flex-direction:row}.selector[_ngcontent-web-gramedia-c2]   .container[_ngcontent-web-gramedia-c2]   .category[_ngcontent-web-gramedia-c2]   .inner-category[_ngcontent-web-gramedia-c2]   div[_ngcontent-web-gramedia-c2]{float:left}.selector[_ngcontent-web-gramedia-c2]   .container[_ngcontent-web-gramedia-c2]   .category[_ngcontent-web-gramedia-c2]   .inner-category[_ngcontent-web-gramedia-c2]   .left-category[_ngcontent-web-gramedia-c2]{width:auto;height:420px;position:sticky;top:0;border-right:1px solid rgba(1,26,92,.2);margin:0;padding-right:30px}.selector[_ngcontent-web-gramedia-c2]   .container[_ngcontent-web-gramedia-c2]   .category[_ngcontent-web-gramedia-c2]   .inner-category[_ngcontent-web-gramedia-c2]   .left-category[_ngcontent-web-gramedia-c2]   a[_ngcontent-web-gramedia-c2]{color:#e52e45;font-family:Nunito,serif;font-weight:700;text-decoration:none}.selector[_ngcontent-web-gramedia-c2]   .container[_ngcontent-web-gramedia-c2]   .category[_ngcontent-web-gramedia-c2]   .inner-category[_ngcontent-web-gramedia-c2]   .right-category[_ngcontent-web-gramedia-c2]{box-sizing:border-box;padding-left:50px}ul.list-parent[_ngcontent-web-gramedia-c2]{display:block;width:260px}ul.list-parent[_ngcontent-web-gramedia-c2] > li[_ngcontent-web-gramedia-c2]{display:block;width:100%;margin-bottom:20px}ul.list-parent[_ngcontent-web-gramedia-c2] > li[_ngcontent-web-gramedia-c2] > a[_ngcontent-web-gramedia-c2]{color:#151515;font-weight:700;font-family:Nunito,sans-serif;transition:color .3s;width:100%;display:block;line-height:1.2em}ul ...
#   </style>
#   <style>
#    .clearfix[_ngcontent-web-gramedia-c3]{clear:both;content:"";display:table}.apperance-none[_ngcontent-web-gramedia-c3]{-webkit-appearance:none;-moz-appearance:none;appearance:none}.gm-style[_ngcontent-web-gramedia-c3]   .controls[_ngcontent-web-gramedia-c3]   button[_ngcontent-web-gramedia-c3]{border:0;background-color:#fff;color:rgba(0,0,0,.6);width:35px;height:35px;border-radius:50%}.gm-style[_ngcontent-web-gramedia-c3]   .controls[_ngcontent-web-gramedia-c3]   button[_ngcontent-web-gramedia-c3]:hover{color:rgba(0,0,0,.9)}.gm-style[_ngcontent-web-gramedia-c3]   .controls.zoom-control[_ngcontent-web-gramedia-c3]{display:flex;flex-direction:column;height:auto}.gm-style[_ngcontent-web-gramedia-c3]   .controls.zoom-control[_ngcontent-web-gramedia-c3]   button[_ngcontent-web-gramedia-c3]{font:1.85em Arial;margin:4px 8px;padding:0}form[_ngcontent-web-gramedia-c3]{float:left;width:100%;position:relative}form[_ngcontent-web-gramedia-c3]   [_ngcontent-web-gramedia-c3]:-moz-placeholder, form[_ngcontent-web-gramedia-c3]   [_ngcontent-web-gramedia-c3]:-ms-input-placeholder, form[_ngcontent-web-gramedia-c3]   [_ngcontent-web-gramedia-c3]::-moz-placeholder, form[_ngcontent-web-gramedia-c3]   [_ngcontent-web-gramedia-c3]::-webkit-input-placeholder{color:#33477c;opacity:0}form[_ngcontent-web-gramedia-c3]   .search-on-mobile[_ngcontent-web-gramedia-c3]{display:none}form[_ngcontent-web-gramedia-c3]   input[type=search][_ngcontent-web-gramedia-c3], form[_ngcontent-web-gramedia-c3]   searchReadonly[type=searchReadonly][_ngcontent-web-gramedia-c3]{line-height:30px;border:1px solid #fff;border-radius:21px;height:42px;background-color:#f5f5f5;font-size:16px;width:100%;margin-top:12px;padding-left:20px;padding-right:40px;color:#6d6d6d;-webkit-appearance:none;outline:0!important}form[_ngcontent-web-gramedia-c3]   input[type=search][_ngcontent-web-gramedia-c3]::-webkit-search-cancel-button, form[_ngcontent-web-gramedia-c3]   searchReadonly[type=searchReadonly][_ngcontent-web-gramedia-c3]::-webkit-search-cancel-button{-webkit-appearance:none;background:0 0}form[_ngcontent-web-gramedia-c3]   button[_ngcontent-web-gramedia-c3]{margin:10px;height:45px;background-color:transparent;border-radius:0;color:#011a5c;font-size:16px;cursor:pointer;border:none;position:absolute;right:2px;top:3px}form[_ngcontent-web-gramedia-c3]   i[_ngcontent-web-gramedia-c3]{position:absolute;right:12px;top:20px;font-size:22px;color:#6d6d6d}form[_ngcontent-web-gramedia-c3]   .search-box[_ngcontent-web-gramedia-c3]{position:absolute;top:53px;border-top:1px solid #ddd;background:#fff;color:#1a1a1a;padding:10px 0;border-radius:10px;box-shadow:4px 9px 8px 0 rgba(0,0,0,.12),0 8px 8px 0 rgba(0,0,0,.24);left:0;right:0;max-height:480px;overflow-y:auto}form[_ngcontent-web-gramedia-c3]   .search-box-query-text[_ngcontent-web-gramedia-c3]{display:block;width:100%}form[_ngcontent-web-gramedia-c3]   .search-box-query-text[_ngcontent-web-gramedia-c3] > a[_ngcontent-web-gramedia-c3]{display:block;width:100%;padding:0 21px;font-family:Nunito;font-size:16px}form[_ngcontent-web-gramedia-c3]   .search-box-title[_ngcontent-web-gramedia-c3]{width:100%;margin:0 0 5px;padding:10px 10px 0 21px;display:flex;font-family:Nunito;justify-content:space-between}form[_ngcontent-web-gramedia-c3]   .search-box-title[_ngcontent-web-gramedia-c3] > span[_ngcontent-web-gramedia-c3]{font-family:Nunito;font-size:16px;font-weight:400;font-style:normal;font-stretch:normal;line-height:normal;letter-spacing:normal;text-align:left;color:#d8d8d8}form[_ngcontent-web-gramedia-c3]   .search-box-title[_ngcontent-web-gramedia-c3] > span.remove-all[_ngcontent-web-gramedia-c3]{font-style:normal;font-stretch:normal;line-height:normal;letter-spacing:normal;color:#e52e45;font-weight:400;cursor:pointer}form[_ngcontent-web-gramedia-c3]   .search-box-author[_ngcontent-web-gramedia-c3], form[_ngcontent-web-gramedia-c3]   .search-box-suggestion[_ngcontent-web-gramedia-c3]{width:100%}form[_ngcontent-web-gramedia-c3]   .search-box-author[_ ...
#   </style>
#   <style>
#    .clearfix[_ngcontent-web-gramedia-c4]{clear:both;content:"";display:table}.apperance-none[_ngcontent-web-gramedia-c4]{-webkit-appearance:none;-moz-appearance:none;appearance:none}.gm-style[_ngcontent-web-gramedia-c4]   .controls[_ngcontent-web-gramedia-c4]   button[_ngcontent-web-gramedia-c4]{border:0;background-color:#fff;color:rgba(0,0,0,.6);width:35px;height:35px;border-radius:50%}.gm-style[_ngcontent-web-gramedia-c4]   .controls[_ngcontent-web-gramedia-c4]   button[_ngcontent-web-gramedia-c4]:hover{color:rgba(0,0,0,.9)}.gm-style[_ngcontent-web-gramedia-c4]   .controls.zoom-control[_ngcontent-web-gramedia-c4]{display:flex;flex-direction:column;height:auto}.gm-style[_ngcontent-web-gramedia-c4]   .controls.zoom-control[_ngcontent-web-gramedia-c4]   button[_ngcontent-web-gramedia-c4]{font:1.85em Arial;margin:4px 8px;padding:0}#login-button[_ngcontent-web-gramedia-c4]{text-align:right}#login-button[_ngcontent-web-gramedia-c4]   button[_ngcontent-web-gramedia-c4]{border:none;background:0 0;height:65px;font-size:18px;font-weight:700;font-family:Nunito,serif;color:#0060ae;cursor:pointer;margin-left:54px}@media only screen and (max-width:960px){div[_ngcontent-web-gramedia-c4]{position:relative;right:auto;top:auto}div[_ngcontent-web-gramedia-c4] > button[_ngcontent-web-gramedia-c4]{height:38px;color:#0060ae;font-family:Nunito,serif;font-size:15px;font-weight:700;line-height:18px}}
#   </style>
#   <style>
#    .clearfix{clear:both;content:"";display:table}.apperance-none{-webkit-appearance:none;-moz-appearance:none;appearance:none}.gm-style .controls button{border:0;background-color:#fff;color:rgba(0,0,0,.6);width:35px;height:35px;border-radius:50%}.gm-style .controls button:hover{color:rgba(0,0,0,.9)}.gm-style .controls.zoom-control{display:flex;flex-direction:column;height:auto}.gm-style .controls.zoom-control button{font:1.85em Arial;margin:4px 8px;padding:0}#icon-bag{float:right}#icon-bag i{font-size:30px;color:#0060ae;position:relative;top:14px}#icon-bag span{font-family:Nunito,serif;position:absolute;top:-5px;right:12px;background:#e52e45;padding:4px 6px;min-width:23px;text-align:center;line-height:1;border-radius:10px;color:#fff;font-size:15px}#icon-bag span.iconix{top:8px;right:-6px;background:#e52e45;padding:4px 6px;min-width:20px;text-align:center;font-size:12px}.mat-menu-content{padding:0!important}.mat-menu-panel{overflow:hidden!important;max-width:100%!important;width:100%;display:block;background:#fff;text-align:center;font-family:Nunito,serif;box-shadow:0 0 16px 0 rgba(0,0,0,.12),0 16px 16px 0 rgba(0,0,0,.24);border-radius:0 0 5px 5px}.cart-list{width:360px;padding:16px;overflow-y:scroll;max-height:450px}.empty-cart{width:360px;padding-top:32px;padding-bottom:32px;margin:0}.empty-cart img{width:150px;height:110px;margin-bottom:25px}.empty-cart p{font-family:Nunito,sans-serif;font-size:16px;font-weight:400;font-style:normal;font-stretch:normal;line-height:1.31;letter-spacing:normal;text-align:center;color:rgba(0,0,0,.54)}.cart-checkout{padding:20px 16px 0;border-top:1px solid #e8eaf6}.cart-checkout .total{text-align:left;font-size:22px;font-weight:400;letter-spacing:normal;color:#151515}.cart-checkout .total span{float:right;font-weight:700;color:#151515}.cart-checkout button{width:100%;height:40px;color:#fff;background-color:#0060ae;border-radius:2px;padding:10px 15px;border:none;margin:16px 0;font-size:16px}.cart-page{color:#0060ae;font-size:14px}.items{margin-bottom:8px;padding-bottom:8px;border-bottom:1px solid #e8eaf6}gm-cart-button{text-align:center}gm-cart-button #cart-area{position:absolute;height:100%;right:0}gm-cart-button button{height:100%;border:none;background:0 0}gm-cart-button button i{font-size:32px;color:#0060ae}gm-cart-button button span{position:absolute;top:9px;background:#e52e45;font-family:Nunito,serif;padding:4px 6px;min-width:20px;text-align:center;line-height:1;border-radius:10px;color:#fff;font-size:12px;left:14px}gm-cart-button .hide{display:none}@media only screen and (max-width:960px){gm-cart-button #cart-area{display:none}gm-cart-button #icon-bag{display:block!important}gm-cart-button #icon-bag i{top:-8px}gm-cart-button div{position:relative;right:0;top:-7px}}
#   </style>
#   <style>
#    .clearfix[_ngcontent-web-gramedia-c7]{clear:both;content:"";display:table}.apperance-none[_ngcontent-web-gramedia-c7]{-webkit-appearance:none;-moz-appearance:none;appearance:none}.gm-style[_ngcontent-web-gramedia-c7]   .controls[_ngcontent-web-gramedia-c7]   button[_ngcontent-web-gramedia-c7]{border:0;background-color:#fff;color:rgba(0,0,0,.6);width:35px;height:35px;border-radius:50%}.gm-style[_ngcontent-web-gramedia-c7]   .controls[_ngcontent-web-gramedia-c7]   button[_ngcontent-web-gramedia-c7]:hover{color:rgba(0,0,0,.9)}.gm-style[_ngcontent-web-gramedia-c7]   .controls.zoom-control[_ngcontent-web-gramedia-c7]{display:flex;flex-direction:column;height:auto}.gm-style[_ngcontent-web-gramedia-c7]   .controls.zoom-control[_ngcontent-web-gramedia-c7]   button[_ngcontent-web-gramedia-c7]{font:1.85em Arial;margin:4px 8px;padding:0}nav[_ngcontent-web-gramedia-c7]{position:absolute;left:0;top:-5px;height:100%;text-transform:uppercase;font-size:14px}nav[_ngcontent-web-gramedia-c7]   .nav-button[_ngcontent-web-gramedia-c7]{height:100%;font-size:35px;background:0 0;border:none;color:#0060ae}nav[_ngcontent-web-gramedia-c7]   .container[_ngcontent-web-gramedia-c7]{position:fixed;top:0;left:0;right:0;bottom:0;background:#fff;z-index:1;line-height:42px;font-weight:400;width:100%;max-width:100%;min-height:0;overflow:auto}nav[_ngcontent-web-gramedia-c7]   .container[_ngcontent-web-gramedia-c7]   .nav-header[_ngcontent-web-gramedia-c7]{background:#fff;box-shadow:0 6px 10px #bbbbbb59;line-height:1;margin-bottom:20px}nav[_ngcontent-web-gramedia-c7]   .container[_ngcontent-web-gramedia-c7]   .nav-header[_ngcontent-web-gramedia-c7] > div[_ngcontent-web-gramedia-c7]{padding:10px}nav[_ngcontent-web-gramedia-c7]   .container[_ngcontent-web-gramedia-c7]   .nav-header[_ngcontent-web-gramedia-c7] > div[_ngcontent-web-gramedia-c7]   button[_ngcontent-web-gramedia-c7]{display:block;border:none;background:0 0;width:100%;text-align:center}nav[_ngcontent-web-gramedia-c7]   .container[_ngcontent-web-gramedia-c7]   .nav-header[_ngcontent-web-gramedia-c7] > div[_ngcontent-web-gramedia-c7]   button[_ngcontent-web-gramedia-c7]   img[_ngcontent-web-gramedia-c7]{width:125px}nav[_ngcontent-web-gramedia-c7]   .container[_ngcontent-web-gramedia-c7]   .nav-header[_ngcontent-web-gramedia-c7]   .close-category[_ngcontent-web-gramedia-c7]{display:block;height:47px;position:fixed;font-size:42px;background:0 0;border:none;right:16px;color:#0060ae}nav[_ngcontent-web-gramedia-c7]   .container[_ngcontent-web-gramedia-c7]   ul[_ngcontent-web-gramedia-c7]   li[_ngcontent-web-gramedia-c7]{border-bottom:1px solid #e8eaf6}nav[_ngcontent-web-gramedia-c7]   .container[_ngcontent-web-gramedia-c7]   ul[_ngcontent-web-gramedia-c7]   li[_ngcontent-web-gramedia-c7]   p[_ngcontent-web-gramedia-c7]{font-size:22px;font-weight:700;padding:0 25px;text-align:left;color:#151515;text-transform:none;font-family:Nunito,serif}nav[_ngcontent-web-gramedia-c7]   .container[_ngcontent-web-gramedia-c7]   ul[_ngcontent-web-gramedia-c7]   li[_ngcontent-web-gramedia-c7]   button[_ngcontent-web-gramedia-c7]{border:none;background:0 0;padding:16px 20px;line-height:1;text-align:left;display:block;width:100%;font-family:Nunito,serif;color:#151515;font-weight:700;font-size:16px}nav[_ngcontent-web-gramedia-c7]   .container[_ngcontent-web-gramedia-c7]   ul[_ngcontent-web-gramedia-c7]   li[_ngcontent-web-gramedia-c7]   button[_ngcontent-web-gramedia-c7]   i[_ngcontent-web-gramedia-c7]{float:right}
#   </style>
#   <style>
#    .clearfix[_ngcontent-web-gramedia-c8]{clear:both;content:"";display:table}.apperance-none[_ngcontent-web-gramedia-c8]{-webkit-appearance:none;-moz-appearance:none;appearance:none}.gm-style[_ngcontent-web-gramedia-c8]   .controls[_ngcontent-web-gramedia-c8]   button[_ngcontent-web-gramedia-c8]{border:0;background-color:#fff;color:rgba(0,0,0,.6);width:35px;height:35px;border-radius:50%}.gm-style[_ngcontent-web-gramedia-c8]   .controls[_ngcontent-web-gramedia-c8]   button[_ngcontent-web-gramedia-c8]:hover{color:rgba(0,0,0,.9)}.gm-style[_ngcontent-web-gramedia-c8]   .controls.zoom-control[_ngcontent-web-gramedia-c8]{display:flex;flex-direction:column;height:auto}.gm-style[_ngcontent-web-gramedia-c8]   .controls.zoom-control[_ngcontent-web-gramedia-c8]   button[_ngcontent-web-gramedia-c8]{font:1.85em Arial;margin:4px 8px;padding:0}a[_ngcontent-web-gramedia-c8], span[_ngcontent-web-gramedia-c8]{text-decoration:none;text-transform:capitalize;font-family:Nunito;font-size:10px;letter-spacing:-.3px;color:#a1aac1}[_nghost-web-gramedia-c8]{display:block;width:100%}ul[_ngcontent-web-gramedia-c8]{margin-top:25px;margin-bottom:40px;width:100%;text-align:left;display:table;content:"";clear:both}ul[_ngcontent-web-gramedia-c8]   li[_ngcontent-web-gramedia-c8]{display:inline-block;float:left}ul[_ngcontent-web-gramedia-c8]   li[_ngcontent-web-gramedia-c8]:last-child   a[_ngcontent-web-gramedia-c8]{cursor:auto;color:#011a5c}@media only screen and (max-width:540px){ul[_ngcontent-web-gramedia-c8]{padding:0 15px}}@media only screen and (min-width:541px) and (max-width:960px){ul[_ngcontent-web-gramedia-c8]{padding:0 40px}}@media only screen and (max-width:960px){ul[_ngcontent-web-gramedia-c8]{width:100%;padding:0 15px;margin-top:20px;margin-bottom:24px}}
#   </style>
#   <style>
#    .clearfix{clear:both;content:"";display:table}.apperance-none{-webkit-appearance:none;-moz-appearance:none;appearance:none}.gm-style .controls button{border:0;background-color:#fff;color:rgba(0,0,0,.6);width:35px;height:35px;border-radius:50%}.gm-style .controls button:hover{color:rgba(0,0,0,.9)}.gm-style .controls.zoom-control{display:flex;flex-direction:column;height:auto}.gm-style .controls.zoom-control button{font:1.85em Arial;margin:4px 8px;padding:0}#footer-top{width:100%;color:#151515;background:#ccdfef}#footer-bottom{background:#fff;box-sizing:border-box;text-align:left;color:#fff;padding-bottom:30px}#footer-bottom h3,#footer-bottom h4{font-family:Nunito,serif;font-weight:700;font-size:14px;color:#0060ae;margin-bottom:20px}#footer-bottom a{display:block;color:#151515;text-decoration:none;line-height:2.5;font-size:14px;font-family:Nunito,serif}#footer-bottom h4{margin:0}#footer-bottom ul{margin:0 auto;padding-top:30px;display:flex}#footer-bottom ul li{width:25%;padding-right:80px}#footer-bottom ul li:last-child{padding-right:0}#footer-bottom .apps{margin-top:20px;font-family:Nunito,serif;font-size:14px;color:#151515}#footer-bottom .apps div{display:flex}#footer-bottom .apps a{margin-right:15px}#footer-bottom .apps a:last-child{margin-right:0}#footer-bottom .apps img{width:100%;max-width:120px}#copyright{width:100%;background:#ccdfef;text-align:center}#copyright p{font-family:Nunito,serif;font-size:12px;color:#0060ae;padding:10px 0;margin:0}#footer-bottom-mobile{display:none}.shadow-content{box-shadow:0 -2px 10px #e5e5e5;height:80px}.shadow-content .inner-container{height:100%;display:flex;justify-content:space-between;align-items:center}.shadow-content .inner-container .texting{font-family:Nunito,serif;font-size:20px;color:#6d6d6d;text-align:center}@media screen and (max-width:1200px){.shadow-content .inner-container .texting{font-size:18px}}.shadow-content .inner-container .social a{margin-right:30px}.shadow-content .inner-container .social a:last-child{margin-right:0}gm-seo-footer{background:#f5f5f5;border-top:3px solid #fff;text-align:left;color:#fff}gm-seo-footer .seo-footer{padding-bottom:60px}gm-seo-footer .seo-footer .footerHide,gm-seo-footer .seo-footer .footerShow{display:block}gm-seo-footer .seo-footer .btnMore{font-family:Nunito,serif;font-size:10px;font-weight:400;font-style:normal;font-stretch:normal;line-height:1.3;letter-spacing:normal;color:#e52e45;cursor:pointer;display:none}gm-seo-footer .seo-footer h1{font-family:Nunito,serif;font-size:18px;font-weight:700;font-style:normal;font-stretch:normal;line-height:1.39;letter-spacing:normal;color:rgba(40,30,90,.86);padding:24px 0 8px}gm-seo-footer .seo-footer h2{font-family:Nunito,serif;font-size:14px;font-weight:700;font-style:normal;font-stretch:normal;line-height:1.29;letter-spacing:normal;color:rgba(40,30,90,.86);padding:12px 0 8px}gm-seo-footer .seo-footer p{font-family:Nunito,serif;font-size:12px;font-weight:400;font-style:normal;font-stretch:normal;line-height:1.33;letter-spacing:normal;text-align:justify;color:rgba(0,0,0,.86)}gm-seo-footer #seo-footer{padding-bottom:30px}gm-seo-footer #seo-footer .name{font-family:Nunito,serif;font-size:18px;font-weight:700;font-style:normal;font-stretch:normal;line-height:1.39;letter-spacing:normal;color:rgba(40,30,90,.86);padding:24px 0 8px}gm-seo-footer #seo-footer .description{min-height:120px;font-family:Nunito,serif;font-size:12px;font-weight:400;font-style:normal;font-stretch:normal;line-height:1.33;letter-spacing:normal;color:rgba(0,0,0,.86);text-align:justify}@media only screen and (max-width:1024px){#footer-bottom{padding-bottom:0}#footer-bottom ul{display:none}#footer-bottom #footer-bottom-mobile{padding:0 20px;display:flex;flex-direction:column;align-items:center;text-align:center;line-height:200%}#footer-bottom #footer-bottom-mobile .separator{margin:30px 0!important;width:100%;height:1px;background-color:rgba(109,109,109,.2)}#footer-bottom #footer-bottom-mobile .menu-footer{margin-top:30px;max-width:40 ...
#   </style>
#   <style>
#    .clearfix[_ngcontent-web-gramedia-c18]{clear:both;content:"";display:table}.apperance-none[_ngcontent-web-gramedia-c18]{-webkit-appearance:none;-moz-appearance:none;appearance:none}.gm-style[_ngcontent-web-gramedia-c18]   .controls[_ngcontent-web-gramedia-c18]   button[_ngcontent-web-gramedia-c18]{border:0;background-color:#fff;color:rgba(0,0,0,.6);width:35px;height:35px;border-radius:50%}.gm-style[_ngcontent-web-gramedia-c18]   .controls[_ngcontent-web-gramedia-c18]   button[_ngcontent-web-gramedia-c18]:hover{color:rgba(0,0,0,.9)}.gm-style[_ngcontent-web-gramedia-c18]   .controls.zoom-control[_ngcontent-web-gramedia-c18]{display:flex;flex-direction:column;height:auto}.gm-style[_ngcontent-web-gramedia-c18]   .controls.zoom-control[_ngcontent-web-gramedia-c18]   button[_ngcontent-web-gramedia-c18]{font:1.85em Arial;margin:4px 8px;padding:0}.inner-container[_ngcontent-web-gramedia-c18]{height:120px;display:flex;justify-content:space-between;align-items:center}.inner-container[_ngcontent-web-gramedia-c18]   .special-text[_ngcontent-web-gramedia-c18]   h2[_ngcontent-web-gramedia-c18]{text-align:left;font-size:25px;font-weight:700;font-family:Nunito,serif}.inner-container[_ngcontent-web-gramedia-c18]   .subcriber-box[_ngcontent-web-gramedia-c18]{width:600px;max-width:600px;height:40px;font-family:Nunito,serif;background-color:#fff;border-radius:10px;margin-left:50px}.inner-container[_ngcontent-web-gramedia-c18]   .subcriber-box[_ngcontent-web-gramedia-c18]   form[_ngcontent-web-gramedia-c18]{height:100%;display:flex}.inner-container[_ngcontent-web-gramedia-c18]   .subcriber-box[_ngcontent-web-gramedia-c18]   input[type=email][_ngcontent-web-gramedia-c18]{padding:0 20px;width:100%;height:100%;background-color:#fff;border-radius:10px;border:none;font-family:Nunito,serif;font-size:14px;box-shadow:none;-webkit-appearance:none;-moz-appearance:none;appearance:none}.inner-container[_ngcontent-web-gramedia-c18]   .subcriber-box[_ngcontent-web-gramedia-c18]   input[type=email][_ngcontent-web-gramedia-c18]:focus{outline:0}.inner-container[_ngcontent-web-gramedia-c18]   .subcriber-box[_ngcontent-web-gramedia-c18]   input[type=email][_ngcontent-web-gramedia-c18]::-webkit-search-cancel-button{-webkit-appearance:none;-moz-appearance:none;appearance:none}.inner-container[_ngcontent-web-gramedia-c18]   .subcriber-box[_ngcontent-web-gramedia-c18]   button[_ngcontent-web-gramedia-c18]{padding:0 30px;height:100%;border-radius:0 10px 10px 0;border:none;background-color:#0060ae;color:#fff;font-family:Nunito,serif;font-size:14px;text-align:center}.inner-container[_ngcontent-web-gramedia-c18]   .subcriber-box[_ngcontent-web-gramedia-c18]   button[_ngcontent-web-gramedia-c18]:focus{outline:0}@media screen and (max-width:1024px){.inner-container[_ngcontent-web-gramedia-c18]{height:-moz-min-content;height:min-content;flex-direction:column;align-items:center;justify-content:center;padding:20px}.inner-container[_ngcontent-web-gramedia-c18]   .special-text[_ngcontent-web-gramedia-c18]{margin-bottom:10px}.inner-container[_ngcontent-web-gramedia-c18]   .special-text[_ngcontent-web-gramedia-c18]   h2[_ngcontent-web-gramedia-c18]{text-align:center;font-size:24px}.inner-container[_ngcontent-web-gramedia-c18]   .subcriber-box[_ngcontent-web-gramedia-c18]{width:100%;height:40px;margin-left:0}}@media screen and (max-width:1024px) and screen and (max-width:500px){.inner-container[_ngcontent-web-gramedia-c18]   .special-text[_ngcontent-web-gramedia-c18]   h2[_ngcontent-web-gramedia-c18]{font-size:16px}}
#   </style>
#   <style>
#    .clearfix[_ngcontent-web-gramedia-c19]{clear:both;content:"";display:table}.apperance-none[_ngcontent-web-gramedia-c19]{-webkit-appearance:none;-moz-appearance:none;appearance:none}.gm-style[_ngcontent-web-gramedia-c19]   .controls[_ngcontent-web-gramedia-c19]   button[_ngcontent-web-gramedia-c19]{border:0;background-color:#fff;color:rgba(0,0,0,.6);width:35px;height:35px;border-radius:50%}.gm-style[_ngcontent-web-gramedia-c19]   .controls[_ngcontent-web-gramedia-c19]   button[_ngcontent-web-gramedia-c19]:hover{color:rgba(0,0,0,.9)}.gm-style[_ngcontent-web-gramedia-c19]   .controls.zoom-control[_ngcontent-web-gramedia-c19]{display:flex;flex-direction:column;height:auto}.gm-style[_ngcontent-web-gramedia-c19]   .controls.zoom-control[_ngcontent-web-gramedia-c19]   button[_ngcontent-web-gramedia-c19]{font:1.85em Arial;margin:4px 8px;padding:0}#footer-top[_ngcontent-web-gramedia-c19]{width:100%;color:#151515;background:#ccdfef}#footer-bottom[_ngcontent-web-gramedia-c19]{background:#fff;box-sizing:border-box;text-align:left;color:#fff;padding-bottom:30px}#footer-bottom[_ngcontent-web-gramedia-c19]   h3[_ngcontent-web-gramedia-c19], #footer-bottom[_ngcontent-web-gramedia-c19]   h4[_ngcontent-web-gramedia-c19]{font-family:Nunito,serif;font-weight:700;font-size:14px;color:#0060ae;margin-bottom:20px}#footer-bottom[_ngcontent-web-gramedia-c19]   a[_ngcontent-web-gramedia-c19]{display:block;color:#151515;text-decoration:none;line-height:2.5;font-size:14px;font-family:Nunito,serif}#footer-bottom[_ngcontent-web-gramedia-c19]   h4[_ngcontent-web-gramedia-c19]{margin:0}#footer-bottom[_ngcontent-web-gramedia-c19]   ul[_ngcontent-web-gramedia-c19]{margin:0 auto;padding-top:30px;display:flex}#footer-bottom[_ngcontent-web-gramedia-c19]   ul[_ngcontent-web-gramedia-c19]   li[_ngcontent-web-gramedia-c19]{width:25%;padding-right:80px}#footer-bottom[_ngcontent-web-gramedia-c19]   ul[_ngcontent-web-gramedia-c19]   li[_ngcontent-web-gramedia-c19]:last-child{padding-right:0}#footer-bottom[_ngcontent-web-gramedia-c19]   .apps[_ngcontent-web-gramedia-c19]{margin-top:20px;font-family:Nunito,serif;font-size:14px;color:#151515}#footer-bottom[_ngcontent-web-gramedia-c19]   .apps[_ngcontent-web-gramedia-c19]   div[_ngcontent-web-gramedia-c19]{display:flex}#footer-bottom[_ngcontent-web-gramedia-c19]   .apps[_ngcontent-web-gramedia-c19]   a[_ngcontent-web-gramedia-c19]{margin-right:15px}#footer-bottom[_ngcontent-web-gramedia-c19]   .apps[_ngcontent-web-gramedia-c19]   a[_ngcontent-web-gramedia-c19]:last-child{margin-right:0}#footer-bottom[_ngcontent-web-gramedia-c19]   .apps[_ngcontent-web-gramedia-c19]   img[_ngcontent-web-gramedia-c19]{width:100%;max-width:120px}#copyright[_ngcontent-web-gramedia-c19]{width:100%;background:#ccdfef;text-align:center}#copyright[_ngcontent-web-gramedia-c19]   p[_ngcontent-web-gramedia-c19]{font-family:Nunito,serif;font-size:12px;color:#0060ae;padding:10px 0;margin:0}#footer-bottom-mobile[_ngcontent-web-gramedia-c19]{display:none}.shadow-content[_ngcontent-web-gramedia-c19]{box-shadow:0 -2px 10px #e5e5e5;height:80px}.shadow-content[_ngcontent-web-gramedia-c19]   .inner-container[_ngcontent-web-gramedia-c19]{height:100%;display:flex;justify-content:space-between;align-items:center}.shadow-content[_ngcontent-web-gramedia-c19]   .inner-container[_ngcontent-web-gramedia-c19]   .texting[_ngcontent-web-gramedia-c19]{font-family:Nunito,serif;font-size:20px;color:#6d6d6d;text-align:center}@media screen and (max-width:1200px){.shadow-content[_ngcontent-web-gramedia-c19]   .inner-container[_ngcontent-web-gramedia-c19]   .texting[_ngcontent-web-gramedia-c19]{font-size:18px}}.shadow-content[_ngcontent-web-gramedia-c19]   .inner-container[_ngcontent-web-gramedia-c19]   .social[_ngcontent-web-gramedia-c19]   a[_ngcontent-web-gramedia-c19]{margin-right:30px}.shadow-content[_ngcontent-web-gramedia-c19]   .inner-container[_ngcontent-web-gramedia-c19]   .social[_ngcontent-web-gramedia-c19]   a[_ngcontent-web-gramedia-c19]:last-child{margin-right ...
#   </style>
#   <script charset="utf-8" src="https://assets.ubembed.com/universalscript/releases/v0.180.1/bundle.js">
#   </script>
#   <script charset="utf-8" src="https://assets.ubembed.com/universalscript/releases/v0.180.1/bundle.js">
#   </script>
#   <script async="" id="smartech_v4" src="https://osjs.netcoresmartech.com/v1/js-versioning?clientkey=ADGMOT35CHFLVDHBJNIG50K96B33CLCBGFVBD608PHJ3ICES10U0&amp;siteid=8a76e1ae64a56a3d9cd72b20f6d433d4&amp;rc=s">
#   </script>
#   <script charset="utf-8" src="https://analytics.tiktok.com/i18n/pixel/static/identify_0e808.js">
#   </script>
#   <style>
#    [_nghost-web-gramedia-c20]{display:block}gm-product[_ngcontent-web-gramedia-c20]{display:block}
#   </style>
#   <title>
#    World Ghost Stories Eropa
#   </title>
#   <link href="" rel="canonical"/>
#   <script _ngcontent-web-gramedia-c20="" type="application/ld+json">
#    {"@context":"http://schema.org/","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https://www.gramedia.com"},{"@type":"ListItem","position":2,"name":"Buku","item":"https://www.gramedia.com/search?category=buku"},{"@type":"ListItem","position":3,"name":"Komik & Novel Grafis","item":"https://www.gramedia.com/search?category=komik"},{"@type":"ListItem","position":4,"name":"World Ghost Stories Eropa"}]}
#   </script>
#   <style>
#    @import url(https://cdnjs.cloudflare.com/ajax/libs/bootstrap/5.1.0/css/bootstrap-grid.min.css);.clearfix{clear:both;content:"";display:table}.apperance-none{-webkit-appearance:none;-moz-appearance:none;appearance:none}.gm-style .controls button{border:0;background-color:#fff;color:rgba(0,0,0,.6);width:35px;height:35px;border-radius:50%}.gm-style .controls button:hover{color:rgba(0,0,0,.9)}.gm-style .controls.zoom-control{display:flex;flex-direction:column;height:auto}.gm-style .controls.zoom-control button{font:1.85em Arial;margin:4px 8px;padding:0}.row-product{display:flex;flex-wrap:wrap}.col-info{flex:1;margin-right:30px}.sticky-section{position:sticky;top:130px;text-align:-webkit-center}.sticky-quantity{position:sticky;top:120px;height:-moz-min-content;height:min-content;border-radius:10px;width:275px;padding-top:10px}.sticky-quantity .pre-order{width:100%;padding:12px;font-family:Nunito,serif}.sticky-quantity .pre-order h3{color:#151515;font-weight:700;font-size:16px}.sticky-quantity .pre-order p{font-size:14px;color:#5a5a5a;margin-bottom:0}.box-image{box-shadow:0 0 10px rgba(229,229,229,.8);border-radius:10px;max-width:345px}.box-image .image{text-align:center;padding:20px;max-height:345px;cursor:pointer}.box-image .image img{width:100%;max-height:305px;-o-object-fit:contain;object-fit:contain}.box-image .preview{display:flex;justify-content:space-between;padding:10px 11px;border-top:1px solid #e5e5e5;cursor:pointer}.box-image .preview p{font-family:Nunito,serif;font-weight:700;font-size:14px;color:#0060ae}.box-info{position:relative;padding-top:10px}.box-info .horizontal-list{list-style:none;padding-left:0;margin-bottom:5px;overflow:hidden;text-overflow:ellipsis;display:-webkit-box;-webkit-line-clamp:1;-webkit-box-orient:vertical}.box-info .horizontal-list li{display:inline-block}.box-info .horizontal-list .title-author{font-size:16px;line-height:18px;font-family:Nunito,serif;color:#6d6d6d}.box-info .horizontal-list .title-author a{text-decoration:none;color:#6d6d6d}.box-info .book-title{margin-bottom:15px}.box-info .book-title h2{font-family:Nunito,serif;font-size:24px;color:#151515;overflow:hidden;text-overflow:ellipsis;display:-webkit-box;-webkit-line-clamp:2;-webkit-box-orient:vertical;width:90%}.box-info .list-rate li{display:inline;border-right:1px solid #e5e5e5;padding:0 15px}.box-info .list-rate li:nth-child(1){padding-left:0}.box-info .list-rate li:nth-child(4){border-right:0}.box-info .list-rate li img{margin-bottom:-2px}.box-info .list-rate li span{font-family:Nunito,serif;font-size:14px;color:#6d6d6d;padding-left:5px}.box-info .list-rate li span:nth-child(1){padding-left:0}.box-info .icon-info{position:absolute;right:-5px;top:0}.box-info .icon-info img{cursor:pointer}.tabs-book{border-bottom:1px solid #e5e5e5;margin-bottom:10px;padding-bottom:10px;display:flex;flex-wrap:nowrap;overflow:auto;-webkit-overflow-scrolling:touch;-ms-overflow-style:-ms-autohiding-scrollbar}.tabs-book a{flex:0 0 auto;font-family:Nunito,serif;font-size:14px;font-weight:700;color:#6d6d6d;margin-left:20px}.tabs-book a:nth-child(1){margin-left:0}.tabs-book .active,.tabs-book a:hover{color:#0060ae}.img-icon{width:20px;height:20px;margin-bottom:10px}.book-carousel{margin-top:15px}.book-carousel .carousel-cell{width:20%;height:60px;margin-right:10px;border-radius:10px;box-shadow:0 0 10px rgba(229,229,229,.8)}.book-carousel .carousel-cell .img-thumb{-o-object-fit:contain;object-fit:contain;width:100%;height:60px;-o-object-position:center;object-position:center;border-radius:10px}.book-carousel .flickity-prev-next-button{top:50%!important;width:20px;height:20px;border-radius:50%;transform:translateY(-50%);color:#0060ae;background:#fff;filter:drop-shadow(0 0 10px rgba(0, 96, 174, .15))}.book-carousel .flickity-prev-next-button.next{right:-10px}.book-carousel .flickity-prev-next-button.previous{left:-10px}.desc-section h3{font-family:Nunito,serif;font-weight:700;font-size:16px;color:#151515}.desc-section .product-desc{font-family:Nunito,seri ...
#   </style>
#   <meta content="World Ghost Stories Eropa" name="title"/>
#   <style>
# ...
# (b="webkitHidden",d="webkitvisibilitychange");d?e.addEventListener(d,function(){a(e[b])}):(g.addEventListener("blur",function(){a(!0)}),g.addEventListener("focus",function(){a(!1)}))}function t(a,b){var d,c,e,h=null,f=0,g=function(){f=new Date;h=null;e=a.apply(d,c)};return function(){var l=new Date;f||(f=l);var k=b-(l-f);d=this;c=arguments;0>=k?(clearTimeout(h),h=null,f=l,e=a.apply(d,c)):h||(h=setTimeout(g,k));return e}}g.EngagementTimer=g.EngagementTimer||c;k.prototype.clear=function(){this._cleared=
# !0};k.prototype.tick=function(){setTimeout(function(){this._cleared||(this._fn(),this.tick())}.bind(this),this._interval)};c.prototype._startTimer=function(){this._Interval=new k(function(){this._tick();this._Interval.clear();this._Interval=new k(this._tick.bind(this),this._minInterval);this._tickElapsed=0}.bind(this),Math.min(this._minInterval-this._tickElapsed,this._minInterval))};c.prototype._tick=function(){var a=+new Date;this._trackedTime+=a-this._lastTick;this._lastTick=a;this._trackedTime<
# this._min||(this._trackedTime>this._max?this.destroy():this._checkMarks())};c.prototype.on=function(a,b){this._events[a]||(this._events[a]=[]);this._events[a].push(b)};c.prototype.reset=function(){this._each=this._each.initialValues.slice(0);this._every=this._every.initialValues.slice(0);this._lastTick=+new Date;this._trackedTime=this._tickRemainder=0;this._cache={};this.emit("reset",{data:{timestamp:+new Date}})};c.prototype.start=function(){var a=+new Date;this._running||(!this._idleTimer&&this._idleAfter&&
# this._resetIdleTimeout(),this._running=!0,this._startTimer(),this._lastTick=a-this._tickElapsed,this.emit("start",{data:{timestamp:a}}))};c.prototype.pause=function(){var a=+new Date;this._tickElapsed=a-this._lastTick;this._trackedTime+=this._tickElapsed;this._Interval&&this._Interval.clear();clearTimeout(this._idleTimer);this._running=!1;this.emit("pause",{data:{timestamp:+new Date}})};c.prototype.emit=function(a,b){var d=this._events[a];d&&this._events[a].forEach(function(a){setTimeout(function(){a(b)},
# 0)})};c.prototype.destroy=function(){this._Interval&&this._Interval.clear();clearTimeout(this._idleTimeout)};c.prototype._checkMarks=function(){for(var a=Math.floor(this._trackedTime/1E3),b=[],d=0,c,e,h,f;this._each.length;){f=this._each.shift();if(f>a){this._each.unshift(f);break}b.push(f)}for(;d<this._every.length;)if(f=this._every.initialValues[d],e=this._every[d],h=0,d+=1,e<=a){for(c=Math.floor((a-e)/f);h<c;)h+=1,b.push(f*h+e);this._every[d-1]=f*h}b.sort(p).forEach(this._checkMark.bind(this))};
# c.prototype._checkMark=function(a){this._cache[a]||(this._cache[a]=!0,this.emit("interval",{data:{time:a}}))};c.prototype._resetIdleTimeout=function(){clearTimeout(this._idleTimer);this._idleTimer=setTimeout(function(){this.pause();this.emit("idle",{data:{timestamp:+new Date}});this._idleTimer=null}.bind(this),this._idleAfter)}})(document,window);
# (function(e){var g=EngagementTimer({every:[Number(google_tag_manager["rm"]["7813781"](14))],idleAfter:Number(google_tag_manager["rm"]["7813781"](15)),engagementEvents:["click","touchstart","scroll","keydown","mousemove"],idleOnVisibilityChange:!0,max:Number(google_tag_manager["rm"]["7813781"](16)),min:Number(google_tag_manager["rm"]["7813781"](17))});g.on("interval",function(g){e.dataLayer.push({event:"engagementTimer",attributes:{counter:g.data.time}})});g.start();e.EngagementTimer=null})(window);
#   </script>
#   <script id="" src="https://ff494fcd4a2b4c8e81d380c41422b7df.js.ubembed.com" type="text/javascript">
#   </script>
#   <script id="" src="https://ff494fcd4a2b4c8e81d380c41422b7df.js.ubembed.com" type="text/javascript">
#   </script>
#   <script id="" type="text/javascript">
#    OMID=1923367;OPID=35864;ORef=escape(window.parent.location.href);!function(){var b=document.createElement("script");b.type="text/javascript";b.async=!0;b.src="//track.omguk.com/e/qs/?action\x3dContent\x26MID\x3d"+OMID+"\x26PID\x3d"+OPID+"\x26ref\x3d"+ORef;var a=document.getElementsByTagName("body")[0];a?a.appendChild(b,a):(a=document.getElementsByTagName("script")[0],a.parentNode.insertBefore(b,a))}();
#   </script>
#   <script async="" src="//track.omguk.com/e/qs/?action=Content&amp;MID=1923367&amp;PID=35864&amp;ref=https%3A//www.gramedia.com/products/world-ghost-stories-eropa" type="text/javascript">
#   </script>
#   <script id="" type="text/javascript">
#    var ssSessionId="";null!=ssGetURLParameter("utm_source")&&(ssSessionId=ssGetURLParameter("utm_source"));var gclid="";null!=ssGetURLParameter("gclid")&&(gclid=ssGetURLParameter("gclid"));"optimisemedia"==ssSessionId.toLowerCase()?ssSetCookie(ssSessionId):("optimisemedia"!=ssSessionId.toLowerCase()&&""!=ssSessionId.toLowerCase()||""!=gclid)&&checkCookie("optimisemedia")&&eraseCookie("optimisemedia");
# function readCookie(a){a+="\x3d";for(var b=document.cookie.split(";"),d=0;d<b.length;d++){for(var c=b[d];" "==c.charAt(0);)c=c.substring(1,c.length);if(0==c.indexOf(a))return c.substring(a.length,c.length)}return null}function eraseCookie(a){document.cookie=a+"\x3d"+a+";expires\x3dThu, 01 Jan 1970 00:00:00 GMT; path\x3d/"}function checkCookie(a){return null!=readCookie(a)}
# function ssGetURLParameter(a){return decodeURIComponent(((new RegExp("[?|\x26]"+a+"\x3d([^\x26;]+?)(\x26|#|;|$)")).exec(location.search)||[,""])[1].replace(/\+/g,"%20"))||null}function ssSetCookie(a){document.cookie=a+"\x3d"+a+";expires\x3d "+ssCalculateExpireDate(30)+"; path\x3d/"}function ssCalculateExpireDate(a){var b=new Date;b.setTime(b.getTime()+864E5*a);b.toUTCString();return b};
#   </script>
#   <script id="" src="//cdnt.netcoresmartech.com/smartechclient.js" type="text/javascript">
#   </script>
#   <script id="" src="https://invol.co/icmt.js?id=ICM-155-1746" type="text/javascript">
#   </script>
#   <script id="" type="text/javascript">
#    (function(a,c,e,f,d,b){a.hj=a.hj||function(){(a.hj.q=a.hj.q||[]).push(arguments)};a._hjSettings={hjid:1905814,hjsv:6};d=c.getElementsByTagName("head")[0];b=c.createElement("script");b.async=1;b.src=e+a._hjSettings.hjid+f+a._hjSettings.hjsv;d.appendChild(b)})(window,document,"https://static.hotjar.com/c/hotjar-",".js?sv\x3d");
#   </script>
#   <script id="" src="//gramedia.api.useinsider.com/ins.js?id=10001896" type="text/javascript">
#   </script>
#   <script src="polyfills.f63bdb8913fc53633d14.js" type="text/javascript">
#   </script>
#   <script src="scripts.ca791c62e06701f6c340.js" type="text/javascript">
#   </script>
#   <script src="main.54a366a3f2e3ef481d76.js" type="text/javascript">
#   </script>
#   <div aria-atomic="true" aria-live="polite" class="cdk-live-announcer-element cdk-visually-hidden">
#   </div>
#   <img height="1" src="https://t.co/i/adsct?bci=3&amp;eci=2&amp;event_id=424ad472-7810-446f-afff-1521c552e9da&amp;events=%5B%5B%22pageview%22%2C%7B%7D%5D%5D&amp;integration=advertiser&amp;p_id=Twitter&amp;p_user_id=0&amp;pl_id=bc29612b-e04f-4153-b34d-3b81d47f2d2c&amp;tw_document_href=https%3A%2F%2Fwww.gramedia.com%2Fproducts%2Fworld-ghost-stories-eropa&amp;tw_iframe_status=0&amp;tw_order_quantity=0&amp;tw_sale_amount=0&amp;txn_id=o87bn&amp;type=javascript&amp;version=2.3.29" style="display: none;" width="1"/>
#   <img height="1" src="https://analytics.twitter.com/i/adsct?bci=3&amp;eci=2&amp;event_id=424ad472-7810-446f-afff-1521c552e9da&amp;events=%5B%5B%22pageview%22%2C%7B%7D%5D%5D&amp;integration=advertiser&amp;p_id=Twitter&amp;p_user_id=0&amp;pl_id=bc29612b-e04f-4153-b34d-3b81d47f2d2c&amp;tw_document_href=https%3A%2F%2Fwww.gramedia.com%2Fproducts%2Fworld-ghost-stories-eropa&amp;tw_iframe_status=0&amp;tw_order_quantity=0&amp;tw_sale_amount=0&amp;txn_id=o87bn&amp;type=javascript&amp;version=2.3.29" style="display: none;" width="1"/>
#   <script id="" type="text/javascript">
#    smartech("create","ADGMOT35CHFLVDHBJNIG50K96B33CLCBGFVBD608PHJ3ICES10U0");smartech("register","8a76e1ae64a56a3d9cd72b20f6d433d4");smartech("dispatch",1,{});
#   </script>
#   <div style="display: none; visibility: hidden;">
#    <script src="//cdnt.netcoresmartech.com/smartechclient.js">
#    </script>
#    <script>
#     smartech("create","ADGMOT35CHFLVDHBJNIG50K96B33CLCBGFVBD608PHJ3ICES10U0");smartech("register","8a76e1ae64a56a3d9cd72b20f6d433d4");smartech("dispatch",1,{});
#    </script>
#   </div>
#   <div style="display: none; visibility: hidden;">
#    <script>
#     smartech("identify",google_tag_manager["rm"]["7813781"](13));console.log("undefined");
#    </script>
#   </div>
#   <div style="display: none; visibility: hidden;">
#    <script>
#     window.insider_object={product:{name:google_tag_manager["rm"]["7813781"](18),custom:{product_basket_id:google_tag_manager["rm"]["7813781"](19)}}};
#    </script>
#   </div>
#   <script id="" type="text/javascript">
#    window.iaCallback=window.iaCallback||[];function iaq(){iaCallback.push(arguments)};
#   </script>
#   <script>
#    window[window.TiktokAnalyticsObject].instance("C7QCHK56KGKTT9CMBVMG").track("ViewContent",{"pixelMethod":"standard","is_standard_mode":"1"});
#   </script>
#   <div id="ia-icm-775">
#    <script>
#     (function(hourExpiry){var transactionId=getURLParameter('session_id');var cookieName='icm-ssid';if(transactionId!==false){setCookie(cookieName,transactionId,hourExpiry);}function getURLParameter(query){query=query.replace(/[[]/,"\[").replace(/[]]/,"\]");var expr="[\?&]"+query+"=([^&#]*)";var regex=new RegExp(expr);var results=regex.exec(window.location.href);if(results!==null){return results[1];}else{return false;}}function setCookie(cname,cvalue,chour){var d=new Date();d.setTime(d.getTime()+(chour*60*1000));var expires="expires="+d.toUTCString();document.cookie=cname+"="+cvalue+";"+expires+";path=/";}function getUTMValues(){var utmSource,utmMedium,utmCampaign,utmString,sessionId;var emptyUTM="[]|[]|[]|[]";if(getURLParameter("utm_source")){utmSource=getURLParameter("utm_source");}else{utmSource="";}if(getURLParameter("utm_medium")){utmMedium=getURLParameter("utm_medium");}else{utmMedium="";}if(getURLParameter("utm_campaign")){utmCampaign=getURLParameter("utm_campaign");}else{utmCampaign="";}if(transactionId!==false){sessionId=transactionId;}else{sessionId="";}utmString="["+decodeURIComponent(utmSource).replace(/ /g,"_")+"]"+"|"+"["+decodeURIComponent(utmMedium).replace(/ /g,"_")+"]"+"|"+"["+decodeURIComponent(utmCampaign).replace(/ /g,"_")+"]"+"|"+"["+decodeURIComponent(sessionId).replace(/ /g,"_")+"]";if(utmString!==emptyUTM){localStorage.setItem("ts",utmString);}}getUTMValues();})(involve_asia_global_data.session_hours)
#    </script>
#   </div>
#   <div id="ia-icm-1382">
#    <script>
#     (function(){var s=document.createElement("script");s.async=true;s.src=(document.location.protocol=="https:"?"https:":"http:")+"//webtrafficsource.com/track/code.js";var a=document.getElementsByTagName("script")[0];a.parentNode.insertBefore(s,a);})();
#    </script>
#   </div>
#   <iframe aria-hidden="true" id="_hjSafeContext_15315985" src="about:blank" style="display: none !important; width: 1px !important; height: 1px !important; opacity: 0 !important; pointer-events: none !important;" tabindex="-1" title="_hjSafeContext">
#   </iframe>
#   <iframe id="insider-worker" src="https://gramedia.api.useinsider.com/worker-new.html" style="display: none;">
#   </iframe>
#   <div class="ub-emb-container">
#    <div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    try{var jq = document.createElement('script'); jq.src = "https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min.js"; document.getElementsByTagName('head')[0].appendChild(jq);  var bxGaCallBack = function(gaName, eventName, device, pageName, title) {     ga("create", "UA-57567756-1", {         name: gaName     });     ga(gaName + '.send', {         hitType: 'event',         eventCategory: 'NetcoreData',         eventAction: eventName + ' | Netcore | ' + device + ' | ' + pageName + ' | ' + title,         eventLabel: 'Netcore',         eventValue: 0     }); };}catch(e){bxErrMan.push({cx:{errAt:"insertedJS"},eM:e.message,sT:e.stack},"warn")}
#   </script>
#   <div id="icm-beacon-div-6734-88">
#    <img height="1px" src="https://invol.co/icm-beacon/155?referrer=&amp;href=https%3A%2F%2Fwww.gramedia.com%2Fproducts%2Fworld-ghost-stories-eropa" style="display:none;" width="1px"/>
#   </div>
#   <style>
#    @font-face {    font-family:  botplatform-font;    src: url('https://cdn.yellowmessenger.com/files/fonts/proximanova-regular.a7942249.woff') format('woff');    font-display: swap;}@font-face {    font-family:  botplatform-font;    src: url('https://cdn.yellowmessenger.com/files/fonts/proximanova-semibold.46e3f047.woff') format('woff');    font-weight: 700;    font-display: swap;}@font-face {    font-family:  botplatform-font;    src: url('https://cdn.yellowmessenger.com/files/fonts/proximanova-regular-italic.053a1112.woff') format('woff');    font-style: italic;    font-display: swap;}@font-face {    font-family:  botplatform-font;    src: url('https://cdn.yellowmessenger.com/files/fonts/proximanova-semibold-italic.660bf63e.woff') format('woff');    font-weight: 700;    font-style: italic;    font-display: swap;}
#   </style>
#   <div id="ymPluginDivContainerInitial" style="display: block;">
#    <div class="" id="ymDivCircle" role="button" style="display: block; background-color: rgb(67, 132, 245); background-image: none; height: 60px; width: 60px; bottom: 20px;" tabindex="0">
#     <img alt="Gramedia" src="https://cdn.yellowmessenger.com/AU3KBlwWtlTP1631517580165.png" style="background: rgb(67, 132, 245); height: 60px; width: 60px;"/>
#    </div>
#    <div class="hide ym-hidden" id="ym-notification">
#    </div>
#    <div class="" id="ymFrameHolder" style="display: none; bottom: 95px;">
#     <div class="ym-loading-spinner" style="display: none;">
#      <div class="ym-double-bounce1">
#      </div>
#      <div class="ym-double-bounce2">
#      </div>
#     </div>
#     <iframe allowfullscreen="" allowtransparency="true" frameborder="0" id="ymIframe" name="ymIframe" scrolling="yes" style="height: calc(100vh - 120px);">
#     </iframe>
#    </div>
#   </div>
#   <script type="text/javascript">
#    try{document.querySelector("body").addEventListener("click",function(ev){if(ev.target.classList.contains("bxModalContainer")){ev.target.parentElement.style.display="none";}});}catch(e){bxErrMan.push({cx:{errAt:"insertedJS"},eM:e.message,sT:e.stack},"warn")}
#   </script>
#   <div class="bx-intent-modal-parent" id="body-mouseleave-bx-modal-parent">
#    <div class="bxModalContainer" id="body-mouseleave-bx-modal">
#    </div>
#   </div>
#   <div class="floating_boxx_widget" style="     position: fixed;     left: 0px;     bottom: 106px;     z-index: 99; ">
#    <a class="tm-bb" href="/boutique?all" style="     -webkit-writing-mode: vertical-lr;     -moz-writing-mode: vertical-lr;     -ms-writing-mode: tb-rl;     -o-writing-mode: vertical-lr;     writing-mode: vertical-lr;     -webkit-transform: rotate(180deg);     -moz-transform: rotate(180deg);     -ms-transform: rotate(180deg);     -o-transform: rotate(180deg);     transform: rotate(180deg);     padding: 19px 5px;     position: initial; ">
#     Rekomendasi untukmu
#    </a>
#   </div>
#   <style id="ins-free-style" innerhtml="">
#   </style>
#   <div class="ins-ghost textads banner-ads banner_ads ad-unit ad-zone ad-space adsbox" style="width: 1px !important; height: 1px !important; position: absolute !important; left: -10000px !important; top: -1000px !important;">
#   </div>
#   <div class="ins-ghost textads banner-ads banner_ads ad-unit ad-zone ad-space adsbox" style="width: 1px !important; height: 1px !important; position: absolute !important; left: -10000px !important; top: -1000px !important;">
#   </div>
#  </body>
#  <iframe id="__JSBridgeIframe_1.0__" style="display: none;" title="jsbridge___JSBridgeIframe_1.0__">
#  </iframe>
#  <iframe id="__JSBridgeIframe_SetResult_1.0__" style="display: none;" title="jsbridge___JSBridgeIframe_SetResult_1.0__">
#  </iframe>
#  <iframe id="__JSBridgeIframe__" style="display: none;" title="jsbridge___JSBridgeIframe__">
#  </iframe>
#  <iframe id="__JSBridgeIframe_SetResult__" style="display: none;" title="jsbridge___JSBridgeIframe_SetResult__">
#  </iframe>
# </html>

# %%
# Find Author
authorName = soup.find("span", "title-author")
print(authorName.get_text())

# Find Title
bookTitle = soup.find("div", "book-title")
print(bookTitle.get_text())

# Find Base Price (Price Before Discount)
basePrice = soup.find("div", "price-promo")
if (basePrice is None):
    basePrice = soup.find("div", "price-from")
print(int(basePrice.get_text().replace("Rp","").replace(".","").replace(" ","")))

# Find Description
prodDesc = soup.find("div", "product-desc")
bookDesc = prodDesc.find_all("div", "")
print(bookDesc[1].get_text().strip())

# Find Book Details
bookDetail = soup.find("div", "detail-section")
details = bookDetail.find_all("p")
print(int(details[0].get_text()))
print(details[1].get_text())
print(float(details[3].get_text().replace("kg","").replace(" ","")))
print(int(details[4].get_text()))
print(int(details[5].get_text().replace("cm","").replace(" ","")))
print(details[6].get_text().capitalize())
print(int(details[7].get_text().replace("cm","").replace(" ","")))

# Special Process for Publish Date
from datetime import datetime
print(datetime.strptime(details[2].get_text().strip(), '%d %b %Y').strftime('%Y-%m-%d'))
# Out:
# Yim Kang Jae
# World Ghost Stories Eropa
# 125000
# "Di Eropa, banyak sekali cerita hantu yang berkembang di sana. Selain itu, ada banyak tempat dan legenda yang tak kalah menyeramkan di sana. Tokoh hantu terkenal pun banyak yang berasal dari Eropa. Di antaranya, raksasa Frankenstein yang besar dan mengerikan, drakula pengisap darah manusia, dan lain-lain.
#
#
#
# Beberapa kisah atau cerita hantu di Eropa pun sering keluar dalam film atau dongeng.
# Komik ini terdiri dari dua bentuk cerita, yaitu berbentuk dongeng dan komik. Dengan gaya bahasa penulisan yang seru, komik ini pasti membuat pembaca bergidik ngeri.  "
# 192
# Bhuana Ilmu Populer
# 0.2
# 9786024554811
# 17
# Indonesia
# 22
# 2018-04-08

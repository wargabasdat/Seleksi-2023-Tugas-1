# %% [markdown]
# # CSGO Liquipedia Scraper

# %% [markdown]
# ### Attariq Muhammad Azhar (18221043)

# %% [markdown]
# ### Tugas Seleksi Calon Asisten Lab Basis Data

# %% [markdown]
# ## Import Library

# %%
from bs4 import BeautifulSoup
import requests 
from datetime import datetime
import json
import time

# %% [markdown]
# ## Function Declarations

# %%
# Get the soup object from url
def parseHTML(url):
    # Send GET request to url with headers
    headers = {'user-agent' : 'Mozilla/5.0 (X11; Linux x86_64); Basis Data/Admin Basis Data/basisdata@std.stei.itb.ac.id'}
    req = requests.get(url, headers = headers).text

    # Parse HTML with BeautifulSoup
    soup = BeautifulSoup(req, 'lxml')
    return soup

# Get liquipedia url destination from href
def liquipedia_url(href):
    return 'https://liquipedia.net' + href

# Get the team name that participated in the tournament 
def getTeamName(tournament, is_winner):
    if is_winner:
        # Get url of the first place team
        href = tournament.find('div', class_ = 'gridCell Placement FirstPlace').find('span', class_ = 'team-template-team-short').find('span', class_ = 'team-template-text').find('a')['href']
    else:
        # Get url of the second place team
        href = tournament.find('div', class_ = 'gridCell Placement SecondPlace').find('span', class_ = 'team-template-team-short').find('span', class_ = 'team-template-text').find('a')['href']
    
    # Parse HTML from url of the team
    subsoup = parseHTML(liquipedia_url(href))

    # Get team name from subsoup
    team_name = subsoup.find('div', class_='infobox-header wiki-backgroundcolor-light').text[6:]

    return team_name

# Get the team data that participated in the tournament
def getTeamData(tournament, is_winner):
    try:
        if is_winner:
            # Get url of the first place team
            href = tournament.find('div', class_ = 'gridCell Placement FirstPlace').find('span', class_ = 'team-template-team-short').find('span', class_ = 'team-template-text').find('a')['href']
        else:
            # Get url of the second place team
            href = tournament.find('div', class_ = 'gridCell Placement SecondPlace').find('span', class_ = 'team-template-team-short').find('span', class_ = 'team-template-text').find('a')['href']
    except Exception as e:
        print("Error while scraping href")
        print(e)
    
    # Parse HTML from url of the team and get the team name from subsoup
    try:
        subsoup = parseHTML(liquipedia_url(href))
        team_name = subsoup.find('div', class_='infobox-header wiki-backgroundcolor-light').text[6:]
    except Exception as e:
        print("Error while scraping team_name")
        print(e)

    # Get team region from subsoup
    try:
        region_div = subsoup.find('div', class_='infobox-cell-2 infobox-description', text='Region:')
        region = region_div.find_next_sibling('div').text.strip()
    except Exception as e:
        print("Error while scraping region")
        print(e)

    # Get approx. total winnings of the team from subsoup
    try:
        approx_div = subsoup.find('div', class_='infobox-cell-2 infobox-description', text='Approx. Total Winnings:')
        approx = approx_div.find_next_sibling('div').text.strip()
        
        # Cast the approx. total winnings from string to int
        approx = int(approx[1:].replace(',', ''))
    except:
        # If the team has no approx. total winnings, the variable is set to 0
        approx = 0
    
    # Return the data as a dictionary
    team = {
        "team_name" : team_name,
        "region" : region,
        "approx_total_winnings": approx
    }

    return team

# Get the tournament data
def getTournamentData(tournament):
    # tournament variable contains div tag with class = 'gridRow'

    # Get tournament name from tournament
    try:
        tournament_name = tournament.find('div', class_ = 'gridCell Tournament Header').b.a.text
    except Exception as e:
        print("Error while scraping tournament_name")
        print(e)

    # Parse HTML from the tournament and get the subsoup
    # This parsing is done to get the tournament's start date, end date, and type (online/offline)
    try: 
        href = tournament.find('div', class_ = 'gridCell Tournament Header').find('b').find('a')['href']
        subsoup = parseHTML(liquipedia_url(href))
    except Exception as e:
        print("Error while scraping href")
        print(e)

    # Get the tournament's start date from subsoup
    try:
        start_date_div = subsoup.find('div', class_ = 'infobox-cell-2 infobox-description', text = 'Start Date:')
        start_date = start_date_div.find_next_sibling('div').text.strip()
    except Exception as e:
        print("Error while scraping start_date")
        print(e)

    # Get the tournament's end date from subsoup
    try:
        end_date_div = subsoup.find('div', class_ = 'infobox-cell-2 infobox-description', text = 'End Date:')
        end_date = end_date_div.find_next_sibling('div').text.strip()
    except Exception as e:
        print("Error while scraping end_date")
        print(e)
    
    # Get the tournament's city from the gridRow
    try: 
        city = tournament.find('div', class_='gridCell EventDetails Location Header').text
        city = city.replace('\xa0', '')
    except Exception as e:
        print("Error while scraping city")
        print(e)
    
    # Get the tournament's country from the gridRow
    try:
        country = tournament.find('div', class_='gridCell EventDetails Location Header').find('span', class_ = 'flag').find('img')['title']
    except Exception as e:
        print("Error while scraping country")
        print(e)

    # Get the tournament's type from subsoup
    try: 
        type_div = subsoup.find('div', class_ = 'infobox-cell-2 infobox-description', text = 'Type:')
        type_ = type_div.find_next_sibling('div').text.strip()
    except Exception as e:
        print("Error while scraping type")
        print(e)
    
    # If the tournament is online, the city and country variables are set to empty strings
    if type_ == 'Online':
        city = ''
        country = ''

    # Get the statement of whether the tournament is a major or not from subsoup
    # (The statement value is boolean)
    try:
        is_major = True
        valve_tier = subsoup.find('div', class_ = 'valvepremier-highlighted')
        
        if type(valve_tier) == type(None):
            is_major = False
        
    except Exception as e:
        print("Error while scraping is_major")
        print(e)

    # Get the tournament's prize pool from the gridRow
    try:
        prize_pool = tournament.find('div', class_ = 'gridCell EventDetails Prize Header').text
        prize_pool = float(prize_pool[1:].replace(',', ''))
    except Exception as e:
        print("Error while scraping prize_pool")
        print(e)

    # Get the tournament's number of participants from the gridRow
    try:
        number_of_participants = tournament.find('div', class_ = 'gridCell EventDetails PlayerNumber Header').text
        number_of_participants = int(number_of_participants.replace('\u00a0teams', ''))
    except Exception as e:
        print("Error while scraping number_of_participants")
        print(e)
    
    # Return the data as a dictionary
    tourney = {
        "tournament_name" : tournament_name,
        "start_date" : start_date,
        "end_date" : end_date, 
        "city" : city,
        "country" : country,
        "type" : type_,
        "is_major" : is_major,
        # Get the tournament's winner and runner up 
        "winner" : getTeamName(tournament, True),
        "runner_up" : getTeamName(tournament, False),
        "prize_pool" : prize_pool,
        "number_of_participants" : number_of_participants
    }

    return tourney

# %% [markdown]
# ## Scraping Data

# %%
# Variables declaration
soup = parseHTML('https://liquipedia.net/counterstrike/S-Tier_Tournaments')

# Variable contains all the div tags with class = 'gridRow'
# Each div tag contains the data of a tournament
tournaments = soup.find_all('div', class_ = 'gridRow')

# Lists to store the data
tournament_data = []
team_data = []

# Counters to keep track of the number of tournaments that had been scraped and errors
count = 0
error_count = 0

# Loop through all the tournaments
for tournament in tournaments:
    try: 
        # Get the tournament's winner
        winner = tournament.find('div', class_ = 'gridCell Placement FirstPlace').find('span', class_ = 'team-template-team-short').find('span', class_ = 'team-template-text').find('a')['href']

        # Get the game type of the tournament (CS:GO / CS)
        game = tournament.find('div', class_ = 'gridCell Game Header').find('span', class_ = 'icon-16px').a['title']
        if game == 'Counter-Strike: Global Offensive':
            try:
                # Get the tournament's data and store it in the tournament_data list
                tourney = getTournamentData(tournament)
                tournament_data.append(tourney)

                # Get the tournament's winner and store it in the team_data list (if it's not already in the list)
                winner = getTeamData(tournament, True)
                if winner not in team_data:
                    team_data.append(winner)

                # Get the tournament's runner up and store it in the team_data list (if it's not already in the list)
                runner_up = getTeamData(tournament, False)
                if runner_up not in team_data:
                    team_data.append(runner_up)

                # Output to notify the user that the tournament had been scraped 
                # and the number of tournaments that had been scraped
                count += 1
                print('\n' + tourney.get('tournament_name') + ' scraped')
                print(f'{count} tournaments had been scraped\n')

            except Exception as e:
                # Exception handler and counter to keep track of the number of errors
                print(e)
                error_count += 1
        
        # If the game type is CS (not CS:GO), the tournament will be skipped
        # (This scraping process is only for CS:GO Tournaments)
        else:
            pass

    # If the tournament is not conducted yet, the winner variable will be None
    # Hence the tournament will be skipped
    except:
        pass

    # Sleep for 3 seconds to prevent getting blocked by the website
    time.sleep(3)

# Output to notify the user that the scraping process had been completed
if error_count > 0:
    print(f'{error_count} errors occured while scraping')
else:
    print('No errors occured while scraping')
# Out:
# /Users/retaconsulting/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:82: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
# /Users/retaconsulting/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:89: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
# /Users/retaconsulting/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:109: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
# /Users/retaconsulting/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:45: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
# /Users/retaconsulting/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:52: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
# BLAST Premier: Spring Final 2023 scraped
# 1 tournaments had been scraped
#
#
# Intel Extreme Masters Dallas 2023 scraped
# 2 tournaments had been scraped
#
#
# BLAST.tv Paris Major 2023 scraped
# 3 tournaments had been scraped
#
#
# Intel Extreme Masters Rio 2023 scraped
# 4 tournaments had been scraped
#
#
# ESL Pro League Season 17 scraped
# 5 tournaments had been scraped
#
#
# Intel Extreme Masters Katowice 2023 scraped
# 6 tournaments had been scraped
#
#
# BLAST Premier: World Final 2022 scraped
# 7 tournaments had been scraped
#
#
# BLAST Premier: Fall Finals 2022 scraped
# 8 tournaments had been scraped
#
#
# Intel Extreme Masters Rio Major 2022 scraped
# 9 tournaments had been scraped
#
#
# ESL Pro League Season 16 scraped
# 10 tournaments had been scraped
#
#
# Intel Extreme Masters XVII - Cologne scraped
# 11 tournaments had been scraped
#
#
# Roobet Cup 2022 scraped
# 12 tournaments had been scraped
#
#
# BLAST Premier: Spring Finals 2022 scraped
# 13 tournaments had been scraped
#
#
# Intel Extreme Masters XVII - Dallas scraped
# 14 tournaments had been scraped
#
#
# PGL Major Antwerp 2022 scraped
# 15 tournaments had been scraped
#
#
# ESL Pro League Season 15 scraped
# 16 tournaments had been scraped
#
#
# Intel Extreme Masters XVI - Katowice scraped
# 17 tournaments had been scraped
#
#
# BLAST Premier: World Final 2021 scraped
# 18 tournaments had been scraped
#
#
# Intel Extreme Masters XVI - Winter scraped
# 19 tournaments had been scraped
#
#
# BLAST Premier: Fall Finals 2021 scraped
# 20 tournaments had been scraped
#
#
# PGL Major Stockholm 2021 scraped
# 21 tournaments had been scraped
#
#
# ESL Pro League Season 14 scraped
# 22 tournaments had been scraped
#
#
# Intel Extreme Masters XVI - Cologne scraped
# 23 tournaments had been scraped
#
#
# BLAST Premier: Spring Finals 2021 scraped
# 24 tournaments had been scraped
#
#
# Intel Extreme Masters XVI - Summer scraped
# 25 tournaments had been scraped
#
#
# DreamHack Masters Spring 2021 scraped
# 26 tournaments had been scraped
#
#
# ESL Pro League Season 13 scraped
# 27 tournaments had been scraped
#
#
# Intel Extreme Masters XV - World Championship scraped
# 28 tournaments had been scraped
#
#
# BLAST Premier: Global Final 2020 scraped
# 29 tournaments had been scraped
#
#
# Intel Extreme Masters XV - Global Challenge scraped
# 30 tournaments had been scraped
#
#
# BLAST Premier: Fall 2020 scraped
# 31 tournaments had been scraped
#
#
# DreamHack Masters Winter 2020: Europe scraped
# 32 tournaments had been scraped
#
#
# Flashpoint Season 2 scraped
# 33 tournaments had been scraped
#
#
# Intel Extreme Masters XV - Beijing Online: Europe scraped
# 34 tournaments had been scraped
#
#
# ESL Pro League Season 12: Europe scraped
# 35 tournaments had been scraped
#
#
# ESL Pro League Season 12: North America scraped
# 36 tournaments had been scraped
#
#
# ESL One: Cologne 2020 Online - Europe scraped
# 37 tournaments had been scraped
#
#
# ESL One: Cologne 2020 Online - North America scraped
# 38 tournaments had been scraped
#
#
# BLAST Premier: Spring 2020 American Finals scraped
# 39 tournaments had been scraped
#
#
# BLAST Premier: Spring 2020 European Finals scraped
# 40 tournaments had been scraped
#
#
# DreamHack Masters Spring 2020: Europe scraped
# 41 tournaments had been scraped
#
#
# Flashpoint Season 1 scraped
# 42 tournaments had been scraped
#
#
# ESL Pro League Season 11: North America scraped
# 43 tournaments had been scraped
#
#
# ESL Pro League Season 11: Europe scraped
# 44 tournaments had been scraped
#
#
# Intel Extreme Masters XIV - World Championship scraped
# 45 tournaments had been scraped
#
#
# EPICENTER 2019 scraped
# 46 tournaments had been scraped
#
#
# BLAST Pro Series: Global Final 2019 scraped
# 47 tournaments had been scraped
#
#
# ESL Pro League Season 10 - Finals scraped
# 48 tournaments had been scraped
#
#
# Esports Championship Series Season 8 - Finals scraped
# 49 tournaments had been scraped
#
#
# CS:GO Asia Championships 2019 scraped
# 50 tournaments had been scraped
#
#
# Intel Extreme Masters XIV - Beijing scraped
# 51 tournaments had been scraped
#
#
# StarSeries & i-League CS:GO Season 8 scraped
# 52 tournaments had been scraped
#
#
# DreamHack Masters Malmö 2019 scraped
# 53 tournaments had been scraped
#
#
# ESL One: New York 2019 scraped
# 54 tournaments had been scraped
#
#
# StarLadder Berlin Major 2019 scraped
# 55 tournaments had been scraped
#
#
# Intel Extreme Masters XIV - Chicago scraped
# 56 tournaments had been scraped
#
#
# ESL One: Cologne 2019 scraped
# 57 tournaments had been scraped
#
#
# ESL Pro League Season 9 - Finals scraped
# 58 tournaments had been scraped
#
#
# Esports Championship Series Season 7 - Finals scraped
# 59 tournaments had been scraped
#
#
# DreamHack Masters Dallas 2019 scraped
# 60 tournaments had been scraped
#
#
# Intel Extreme Masters XIV - Sydney scraped
# 61 tournaments had been scraped
#
#
# StarSeries & i-League CS:GO Season 7 scraped
# 62 tournaments had been scraped
#
#
# World Electronic Sports Games 2018 scraped
# 63 tournaments had been scraped
#
#
# Intel Extreme Masters XIII - Katowice Major 2019 scraped
# 64 tournaments had been scraped
#
#
# ESL Pro League Season 8 - Finals scraped
# 65 tournaments had been scraped
#
#
# Esports Championship Series Season 6 - Finals scraped
# 66 tournaments had been scraped
#
#
# Intel Extreme Masters XIII - Chicago scraped
# 67 tournaments had been scraped
#
#
# EPICENTER 2018 scraped
# 68 tournaments had been scraped
#
#
# StarSeries & i-League CS:GO Season 6 scraped
# 69 tournaments had been scraped
#
#
# ESL One: New York 2018 scraped
# 70 tournaments had been scraped
#
#
# FACEIT Major: London 2018 scraped
# 71 tournaments had been scraped
#
#
# DreamHack Masters Stockholm 2018 scraped
# 72 tournaments had been scraped
#
#
# ELEAGUE CS:GO Premier 2018 scraped
# 73 tournaments had been scraped
#
#
# ESL One: Cologne 2018 scraped
# 74 tournaments had been scraped
#
#
# ESL One: Belo Horizonte 2018 scraped
# 75 tournaments had been scraped
#
#
# Esports Championship Series Season 5 - Finals scraped
# 76 tournaments had been scraped
#
#
# StarSeries & i-League CS:GO Season 5 scraped
# 77 tournaments had been scraped
#
#
# ESL Pro League Season 7 - Finals scraped
# 78 tournaments had been scraped
#
#
# Intel Extreme Masters XIII - Sydney scraped
# 79 tournaments had been scraped
#
#
# DreamHack Masters Marseille 2018 scraped
# 80 tournaments had been scraped
#
#
# World Electronic Sports Games 2017 scraped
# 81 tournaments had been scraped
#
#
# Intel Extreme Masters XII - World Championship scraped
# 82 tournaments had been scraped
#
#
# StarLadder & i-League StarSeries Season 4 scraped
# 83 tournaments had been scraped
#
#
# ELEAGUE Major Boston 2018 scraped
# 84 tournaments had been scraped
#
#
# Esports Championship Series Season 4 - Finals scraped
# 85 tournaments had been scraped
#
#
# ESL Pro League Season 6 - Finals scraped
# 86 tournaments had been scraped
#
#
# Intel Extreme Masters XII - Oakland scraped
# 87 tournaments had been scraped
#
#
# EPICENTER 2017 scraped
# 88 tournaments had been scraped
#
#
# ELEAGUE CS:GO Premier 2017 scraped
# 89 tournaments had been scraped
#
#
# ESL One: New York 2017 scraped
# 90 tournaments had been scraped
#
#
# ESG Tour Mykonos 2017 scraped
# 91 tournaments had been scraped
#
#
# DreamHack Masters Malmö 2017 scraped
# 92 tournaments had been scraped
#
#
# PGL Major Kraków 2017 scraped
# 93 tournaments had been scraped
#
#
# ESL One: Cologne 2017 scraped
# 94 tournaments had been scraped
#
#
# Esports Championship Series Season 3 - Finals scraped
# 95 tournaments had been scraped
#
#
# ESL Pro League Season 5 - Finals scraped
# 96 tournaments had been scraped
#
#
# Intel Extreme Masters XII - Sydney scraped
# 97 tournaments had been scraped
#
#
# StarLadder i-League StarSeries Season 3 scraped
# 98 tournaments had been scraped
#
#
# Intel Extreme Masters XI - World Championship scraped
# 99 tournaments had been scraped
#
#
# DreamHack Masters Las Vegas 2017 scraped
# 100 tournaments had been scraped
#
#
# ELEAGUE Major Atlanta 2017 scraped
# 101 tournaments had been scraped
#
#
# World Electronic Sports Games 2016 scraped
# 102 tournaments had been scraped
#
#
# Esports Championship Series Season 2 - Finals scraped
# 103 tournaments had been scraped
#
#
# ELEAGUE Season 2 scraped
# 104 tournaments had been scraped
#
#
# DreamHack Open Winter 2016 scraped
# 105 tournaments had been scraped
#
#
# Intel Extreme Masters XI - Oakland scraped
# 106 tournaments had been scraped
#
#
# ESL Pro League Season 4 - Finals scraped
# 107 tournaments had been scraped
#
#
# EPICENTER 2016 scraped
# 108 tournaments had been scraped
#
#
# ESL One: New York 2016 scraped
# 109 tournaments had been scraped
#
#
# DreamHack Open Bucharest 2016 scraped
# 110 tournaments had been scraped
#
#
# StarLadder i-League StarSeries Season 2 scraped
# 111 tournaments had been scraped
#
#
# ELEAGUE Season 1 scraped
# 112 tournaments had been scraped
#
#
# ESL One: Cologne 2016 scraped
# 113 tournaments had been scraped
#
#
# Esports Championship Series Season 1 - Finals scraped
# 114 tournaments had been scraped
#
#
# DreamHack Open Summer 2016 scraped
# 115 tournaments had been scraped
#
#
# StarLadder i-League Invitational #1 scraped
# 116 tournaments had been scraped
#
#
# ESL Pro League Season 3 - Finals scraped
# 117 tournaments had been scraped
#
#
# CEVO Pro League Season 9 scraped
# 118 tournaments had been scraped
#
#
# DreamHack Masters Malmö 2016 scraped
# 119 tournaments had been scraped
#
#
# MLG Major Championship: Columbus 2016 scraped
# 120 tournaments had been scraped
#
#
# Intel Extreme Masters X - World Championship scraped
# 121 tournaments had been scraped
#
#
# Global eSports Cup - Season 1 scraped
# 122 tournaments had been scraped
#
#
# DreamHack Open Leipzig 2016 scraped
# 123 tournaments had been scraped
#
#
# StarLadder i-League StarSeries XIV scraped
# 124 tournaments had been scraped
#
#
# ESL ESEA Pro League Season 2 - Finals scraped
# 125 tournaments had been scraped
#
#
# Fragbite Masters Season 5 scraped
# 126 tournaments had been scraped
#
#
# FACEIT League 2015 Stage 3 Finals scraped
# 127 tournaments had been scraped
#
#
# Intel Extreme Masters X - San Jose scraped
# 128 tournaments had been scraped
#
#
# CEVO Season 8 Professional scraped
# 129 tournaments had been scraped
#
#
# DreamHack Open Cluj⁠-⁠Napoca 2015 scraped
# 130 tournaments had been scraped
#
#
# The World Championships 2015 scraped
# 131 tournaments had been scraped
#
#
# PGL CS:GO Championship Series Season 1 scraped
# 132 tournaments had been scraped
#
#
# Gfinity Champion of Champions scraped
# 133 tournaments had been scraped
#
#
# DreamHack Open London 2015 scraped
# 134 tournaments had been scraped
#
#
# ESL ESEA Pro League Invitational scraped
# 135 tournaments had been scraped
#
#
# ESL One: Cologne 2015 scraped
# 136 tournaments had been scraped
#
#
# Intel Extreme Masters Season X - gamescom scraped
# 137 tournaments had been scraped
#
#
# CEVO Season 7 Professional scraped
# 138 tournaments had been scraped
#
#
# FACEIT 2015 Stage 2 Finals scraped
# 139 tournaments had been scraped
#
#
# Electronic Sports World Cup 2015 scraped
# 140 tournaments had been scraped
#
#
# ESL ESEA Pro League Season 1 - Finals scraped
# 141 tournaments had been scraped
#
#
# Gfinity Masters Summer 1 scraped
# 142 tournaments had been scraped
#
#
# StarLadder StarSeries XIII scraped
# 143 tournaments had been scraped
#
#
# DreamHack Open Summer 2015 scraped
# 144 tournaments had been scraped
#
#
# Fragbite Masters Season 4 scraped
# 145 tournaments had been scraped
#
#
# Gfinity Spring Masters 2 scraped
# 146 tournaments had been scraped
#
#
# DreamHack Open Tours 2015 scraped
# 147 tournaments had been scraped
#
#
# FACEIT League 2015 Stage I Finals scraped
# 148 tournaments had been scraped
#
#
# PGL CS:GO Championship Series Kick-Off Season scraped
# 149 tournaments had been scraped
#
#
# ESEA Season 18: Global Invite Division scraped
# 150 tournaments had been scraped
#
#
# ESL Pro League Winter 2014/15 scraped
# 151 tournaments had been scraped
#
#
# StarLadder StarSeries XII scraped
# 152 tournaments had been scraped
#
#
# Gfinity Spring Masters 1 scraped
# 153 tournaments had been scraped
#
#
# ESL One: Katowice 2015 scraped
# 154 tournaments had been scraped
#
#
# MLG X Games Aspen Invitational scraped
# 155 tournaments had been scraped
#
#
# ESEA Season 17 - Global Invite Division scraped
# 156 tournaments had been scraped
#
#
# DreamHack Winter 2014 scraped
# 157 tournaments had been scraped
#
#
# Fragbite Masters Season 3 scraped
# 158 tournaments had been scraped
#
#
# ESWC 2014 scraped
# 159 tournaments had been scraped
#
#
# FACEIT League - Season 2 scraped
# 160 tournaments had been scraped
#
#
# StarLadder StarSeries XI scraped
# 161 tournaments had been scraped
#
#
# DreamHack Invitational II scraped
# 162 tournaments had been scraped
#
#
# StarLadder StarSeries X scraped
# 163 tournaments had been scraped
#
#
# ESL One: Cologne 2014 scraped
# 164 tournaments had been scraped
#
#
# Gfinity G3 scraped
# 165 tournaments had been scraped
#
#
# ESEA Season 16 - Global Invite Division scraped
# 166 tournaments had been scraped
#
#
# DreamHack Summer 2014 scraped
# 167 tournaments had been scraped
#
#
# StarLadder StarSeries IX scraped
# 168 tournaments had been scraped
#
#
# Fragbite Masters Season 2 scraped
# 169 tournaments had been scraped
#
#
# ESL Major Series One Katowice 2014 scraped
# 170 tournaments had been scraped
#
#
# ESEA Global Finals Season 15 scraped
# 171 tournaments had been scraped
#
#
# Fragbite Masters Season 1 scraped
# 172 tournaments had been scraped
#
#
# DreamHack Winter 2013 scraped
# 173 tournaments had been scraped
#
#
# Electronic Sports World Cup 2013 scraped
# 174 tournaments had been scraped
#
#
# ESL Major Series One - Fall 2013 scraped
# 175 tournaments had been scraped
#
#
# StarLadder StarSeries VII scraped
# 176 tournaments had been scraped
#
#
# DreamHack Bucharest 2013 scraped
# 177 tournaments had been scraped
#
#
# ESEA Global Finals Season 14 scraped
# 178 tournaments had been scraped
#
#
# ESL Major Series One - Summer 2013 scraped
# 179 tournaments had been scraped
#
#
# DreamHack Summer 2013 scraped
# 180 tournaments had been scraped
#
#
# ESEA Global Finals Season 13 scraped
# 181 tournaments had been scraped
#
#
# ESL Major Series One - Spring 2013 scraped
# 182 tournaments had been scraped
#
#
# DreamHack Winter 2012 scraped
# 183 tournaments had been scraped
#
#
# ESWC 2012 scraped
# 184 tournaments had been scraped
#
# No errors occured while scraping

# %% [markdown]
# ## Writing Data to JSON

# %%
# Write the tournaments data to a JSON file
with open('CSGO_Tournaments.json', 'w') as outfile:
    json.dump(tournament_data, outfile, indent=4)

# Write the teams data to a JSON file
with open('CSGO_Teams.json', 'w') as outfile:
    json.dump(team_data, outfile, indent=4)

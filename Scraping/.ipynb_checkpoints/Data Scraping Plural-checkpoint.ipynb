# %%
# Referennces
# https://www.youtube.com/watch?v=C5AOZZWxvIY&ab_channel=GunturBudi
# https://stackoverflow.com/questions/58474049/how-to-scrape-websites-that-have-loaders 
# https://www.kaggle.com/code/farhanmalik371/bag-of-words-attempt
# https://www.selenium.dev/documentation/webdriver/getting_started/first_script/#2-take-action-on-browser

# %%
# !pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time

# Setup Options
chrome_options = Options()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# Gramedia.com has 50 pages
URL = "https://www.gramedia.com/categories/buku/komik?page="

# Array of HTMLs
htmls = ["HTML" for i in range (50)]

# There are 50 pages of book with comic & graphic novel category
for p in range(50):
    # Initiate WebDriver Session
    driver = webdriver.Chrome(options=chrome_options)
    
    # Opens The Website in Chrome
    driver.get(URL + str(p + 1))

    # Wait Loading 5s
    time.sleep(15)

    # Getting the HTML
    htmls[p] = str(driver.page_source)
    if (htmls[p] != ""):
        print("Web HTML #" + str(p + 1) + " Fetched!")
    else:
        print("Fetching #" + str(p + 1) + " Failed!")

    # Closes Chrome
    driver.quit()
    
    # Delay Web-Access
    time.sleep(5)
# Out:
# Web HTML #1 Fetched!
# Web HTML #2 Fetched!
# Web HTML #3 Fetched!
# Web HTML #4 Fetched!
# Web HTML #5 Fetched!
# Web HTML #6 Fetched!
# Web HTML #7 Fetched!
# Web HTML #8 Fetched!
# Web HTML #9 Fetched!
# Web HTML #10 Fetched!
# Web HTML #11 Fetched!
# Web HTML #12 Fetched!
# Web HTML #13 Fetched!
# Web HTML #14 Fetched!
# Web HTML #15 Fetched!
# Web HTML #16 Fetched!
# Web HTML #17 Fetched!
# Web HTML #18 Fetched!
# Web HTML #19 Fetched!
# Web HTML #20 Fetched!
# Web HTML #21 Fetched!
# Web HTML #22 Fetched!
# Web HTML #23 Fetched!
# Web HTML #24 Fetched!
# Web HTML #25 Fetched!
# Web HTML #26 Fetched!
# Web HTML #27 Fetched!
# Web HTML #28 Fetched!
# Web HTML #29 Fetched!
# Web HTML #30 Fetched!
# Web HTML #31 Fetched!
# Web HTML #32 Fetched!
# Web HTML #33 Fetched!
# Web HTML #34 Fetched!
# Web HTML #35 Fetched!
# Web HTML #36 Fetched!
# Web HTML #37 Fetched!
# Web HTML #38 Fetched!
# Web HTML #39 Fetched!
# Web HTML #40 Fetched!
# Web HTML #41 Fetched!
# Web HTML #42 Fetched!
# Web HTML #43 Fetched!
# Web HTML #44 Fetched!
# Web HTML #45 Fetched!
# Web HTML #46 Fetched!
# Web HTML #47 Fetched!
# Web HTML #48 Fetched!
# Web HTML #49 Fetched!
# Web HTML #50 Fetched!

# %%
from bs4 import BeautifulSoup as bsp
import pandas as pd

# Array as Data Container
namaBuku = []
hargaBuku = []
namaPenulis = []

for html in htmls:
    # Change class into Soup Class
    soup = bsp(html, "lxml")

    # Print HTML
    # print(soup.prettify()[1:1000])

    # Based on the HTML, each book and it's data contained in
    # "gm-product-list" tag with "card-list ng-star-inserted" class
    buku = soup.find_all("gm-product-list", "card-list ng-star-inserted")

    # Get All Product Name, Price, and Author and insert it into array
    for p in buku:
        nama = p.find("div", "list-title").get_text()
        harga = p.find('p', 'formats-price').get_text()
        try:
            penulis = p.find('span', 'list-author ng-star-inserted').get_text()
        except AttributeError: # if the author name is missing
            penulis = ""

        # Inserting datum into the array
        # Type String
        namaBuku.append(nama)
        # Type Integer
        hargaBuku.append(int(harga.replace('Rp','').replace(' ','').replace('.','')))
        # Type String
        namaPenulis.append(penulis.strip())

# Creating Dictionary to make Dataframe
prodDict = {'judul':namaBuku, 'harga':hargaBuku, 'penulis':namaPenulis}

# Create dataframe from dictionary
df = pd.DataFrame(prodDict,columns = ['judul','harga','penulis'])

# Show Tables
df
# Out:
#                                 judul   harga  \
# 0           World Ghost Stories Eropa   37500
# 1          Muhammad Membangun Madinah  135000
# 2           The Apothecary Diaries 09   36000
# 3            Full Bloom Cheekiness 18   25600
# 4     Level Comic: Tokyo Revengers 09   32000
# ..                                ...     ...
# 995               Dragon Ball Vol. 39   25000
# 996  Yamada and the 7 Witches Vol. 24   25000
# 997       Battle Game In 5 Seconds 06   25000
# 998            The Sluggish Tanaka 10   25000
# 999              LC: Giant Killing 45   27000
#
#                                  penulis
# 0                           Yim Kang Jae
# 1    Zhaenal Fanani - Regu Kancil Studio
# 2              NATSU HYUUGA / NEKOKURAGE
# 3                      Miyuki Mitsubachi
# 4                              Ken Wakui
# ..                                   ...
# 995                       Akita Toriyama
# 996                       Miki Yoshikawa
# 997     Saizou Harawata & Kashiwa Miyako
# 998                           Nozomi Uda
# 999          Tsujitomo, Masaya Tsunamoto
#
# [1000 rows x 3 columns]

# %%
from json import loads, dumps
result = df.to_json(orient="table")
parsed = loads(result)
print(dumps(parsed, indent=4))

# Into Plural.json
df.to_json(r'C:\Users\StepHomie\Documents\Hans St\Code\Jupyter\Scraping\Plural.json', orient="table", indent=4)
# Out:
# {
#     "schema": {
#         "fields": [
#             {
#                 "name": "index",
#                 "type": "integer"
#             },
#             {
#                 "name": "judul",
#                 "type": "string"
#             },
#             {
#                 "name": "harga",
#                 "type": "integer"
#             },
#             {
#                 "name": "penulis",
#                 "type": "string"
#             }
#         ],
#         "primaryKey": [
#             "index"
#         ],
#         "pandas_version": "1.4.0"
#     },
#     "data": [
#         {
#             "index": 0,
#             "judul": "World Ghost Stories Eropa",
#             "harga": 37500,
#             "penulis": "Yim Kang Jae"
#         },
#         {
#             "index": 1,
#             "judul": "Muhammad Membangun Madinah",
#             "harga": 135000,
#             "penulis": "Zhaenal Fanani - Regu Kancil Studio"
#         },
#         {
#             "index": 2,
#             "judul": "The Apothecary Diaries 09",
#             "harga": 36000,
#             "penulis": "NATSU HYUUGA / NEKOKURAGE"
#         },
#         {
#             "index": 3,
#             "judul": "Full Bloom Cheekiness 18",
#             "harga": 25600,
#             "penulis": "Miyuki Mitsubachi"
#         },
#         {
#             "index": 4,
#             "judul": "Level Comic: Tokyo Revengers 09",
#             "harga": 32000,
#             "penulis": "Ken Wakui"
#         },
#         {
#             "index": 5,
#             "judul": "Akasha : Chainsaw Man 03",
#             "harga": 38400,
#             "penulis": "Tatsuki Fujimoto"
#         },
#         {
#             "index": 6,
#             "judul": "Level Comic: Just The Two of Us 03",
#             "harga": 36000,
#             "penulis": "Yoshimura Akemi"
#         },
#         {
#             "index": 7,
#             "judul": "Akasha : Gyo Complete Edition - 2 In 1",
#             "harga": 71200,
#             "penulis": "Ito Junji"
#         },
#         {
#             "index": 8,
#             "judul": "Level Comic: Zom 100 vol 01",
#             "harga": 40000,
#             "penulis": "Haro Aso, Kotaro Takata"
#         },
#         {
#             "index": 9,
#             "judul": "C.M.B 43",
#             "harga": 25600,
#             "penulis": "Motohiro Katou"
#         },
#         {
#             "index": 10,
#             "judul": "Blue Lock 09",
#             "harga": 36000,
#             "penulis": "Muneyuki Kaneshiro"
#         },
#         {
#             "index": 11,
#             "judul": "Akasha : Trace, Recollections Of A Forensic Researcher 11",
#             "harga": 27200,
#             "penulis": "Kei Koga"
#         },
#         {
#             "index": 12,
#             "judul": "Akasha : City Hunter - Complete Edition 15",
#             "harga": 52000,
#             "penulis": "Hojo Tsukasa"
#         },
#         {
#             "index": 13,
#             "judul": "Level Comic (LC): Jojo`s Bizarre Adventure 03 - Part 1 Phantom Blood",
#             "harga": 60000,
#             "penulis": "Hirohiko Araki"
#         },
#         {
#             "index": 14,
#             "judul": "Level Comic: Aku no Hana-Kembang Jahanam 02",
#             "harga": 40000,
#             "penulis": "SHUZO OSHIMI"
#         },
#         {
#             "index": 15,
#             "judul": "Level Comic: Bungo Stray Dogs 04",
#             "harga": 40000,
#             "penulis": "Kafka Asagiri"
#         },
#         {
#             "index": 16,
#             "judul": "PET BOOM - Dark Urban Legend 4-",
#             "harga": 32000,
#             "penulis": "Ryo Azuki"
#         },
#         {
#             "index": 17,
#             "judul": "MAO 07",
#             "harga": 32000,
#             "penulis": "Takahashi Rumiko"
#         },
#         {
#             "index": 18,
#             "judul": "Why? Insects - Serangga (Edisi Baru)",
#             "harga": 89250,
#             "penulis": "Kwangwoong Lee"
#         },
#         {
#             "index": 19,
#             "judul": "Solo Leveling 01",
#             "harga": 68000,
#             "penulis": "Chugong None"
#         },
#         {
#             "index": 20,
#             "judul": "AKASHA : Ito Junji Compilation 03 -  Souichi's Convenient Curses",
#             "harga": 76000,
#             "penulis": "Ito Junji"
#         },
#         {
#             "index": 21,
#             "judul": "Detektif Conan 102",
#             "harga": 42500,
#             "penulis": "Aoyama Gosho"
#         },
#         {
#             "index": 22,
#             "judul": "Plants Vs Zombies - Komik Dinosaurus : Planet Dinosaurus",
#             "harga": 93750,
#             "penulis": "Xiao Jiangnan"
#         },
#         {
#             "index": 23,
#             "judul": "Death Note - New Edition 02",
#             "harga": 70400,
#             "penulis": "Ohba Tsugumi"
#         },
#         {
#             "index": 24,
#             "judul": "Level Comic: Fight Ippo 131",
#             "harga": 28000,
#             "penulis": "Joji Morikawa"
#         },
#         {
#             "index": 25,
#             "judul": "Fujiwara is Almost Right 07",
#             "harga": 32000,
#             "penulis": "Nao Hinachi"
#         },
#         {
#             "index": 26,
#             "judul": "A Couple of Cuckoos 08",
#             "harga": 32000,
#             "penulis": "Miki Yoshikawa"
#         },
#         {
#             "index": 27,
#             "judul": "Kindaichi 37 tahun 11",
#             "harga": 33600,
#             "penulis": "Seimaru Amagi & Fumiya Sato"
#         },
#         {
#             "index": 28,
#             "judul": "Karena Kamu Sangat Berharga",
#             "harga": 169000,
#             "penulis": "Kim Ji Hun"
#         },
#         {
#             "index": 29,
#             "judul": "High Rise Invasion 17",
#             "harga": 25600,
#             "penulis": "Tsuina Miura / Takahiro Oba"
#         },
#         {
#             "index": 30,
#             "judul": "AKASHA : Dead Mount Death Play 08",
#             "harga": 38400,
#             "penulis": "RYOHGO NARITA/SHINTA FUJIMOTO"
#         },
#         {
#             "index": 31,
#             "judul": "Hololive Id:Entity Official Fanbook",
#             "harga": 159200,
#             "penulis": "M&C"
#         },
#         {
#             "index": 32,
#             "judul": "Kutukan Mustika Ular",
#             "harga": 88000,
#             "penulis": "Prasodjo Muhammad"
#         },
#         {
#             "index": 33,
#             "judul": "Mieruko-chan : The Girl That Sees 02",
#             "harga": 38400,
#             "penulis": "Tomoki Izumi"
#         },
#         {
#             "index": 34,
#             "judul": "Komik Laksamana Malahayati",
#             "harga": 90000,
#             "penulis": "Nurul Chomaria"
#         },
#         {
#             "index": 35,
#             "judul": "Mission: Yozakura Family 02",
#             "harga": 36000,
#             "penulis": "Hitsuji Gondaira"
#         },
#         {
#             "index": 36,
#             "judul": "Detektif Conan Shinichi Kudo Selection Vol. 01",
#             "harga": 60000,
#             "penulis": "Aoyama Gosho"
#         },
#         {
#             "index": 37,
#             "judul": "It Ends With Us",
#             "harga": 232200,
#             "penulis": "Colleen Hoover"
#         },
#         {
#             "index": 38,
#             "judul": "Sekotak Senja Untuk Nirbita",
#             "harga": 99000,
#             "penulis": "Yupitawdr None"
#         },
#         {
#             "index": 39,
#             "judul": "Take a Chance",
#             "harga": 84150,
#             "penulis": "Oldheva None"
#         },
#         {
#             "index": 40,
#             "judul": "AKASHA : Fist of the North Star 15",
#             "harga": 60000,
#             "penulis": "Tetsuo Hara & Buronson"
#         },
#         {
#             "index": 41,
#             "judul": "Tokyo Ghoul 03",
#             "harga": 44000,
#             "penulis": "Sui Ishida"
#         },
#         {
#             "index": 42,
#             "judul": "SAMURAI 8 - The Tale of Hachimaru 02",
#             "harga": 36000,
#             "penulis": "Masashi Kishimoto"
#         },
#         {
#             "index": 43,
#             "judul": "Komi Sulit Berkomunikasi 16",
#             "harga": 25600,
#             "penulis": "Tomohito ODA"
#         },
#         {
#             "index": 44,
#             "judul": "Teasing Master, Takagi 12",
#             "harga": 32000,
#             "penulis": "Soichiro YAMAMOTO"
#         },
#         {
#             "index": 45,
#             "judul": "Oh My God! Penemuan Keren dari Alam",
#             "harga": 71250,
#             "penulis": "YeaRimDang"
#         },
#         {
#             "index": 46,
#             "judul": "Teasing Master, Takagi 7",
#             "harga": 30000,
#             "penulis": "YAMAMOTO SOUICHIROU"
#         },
#         {
#             "index": 47,
#             "judul": "AKASHA : Fragments of Horror",
#             "harga": 48000,
#             "penulis": "Ito Junji"
#         },
#         {
#             "index": 48,
#             "judul": "The Witch & Dinner",
#             "harga": 64000,
#             "penulis": "Rumiko Takahashi"
#         },
#         {
#             "index": 49,
#             "judul": "Plants VS Zombies - Tubuh Manusia : Ambulans Agen Rahasia",
#             "harga": 93750,
#             "penulis": "Xiao Jiangnan"
#         },
#         {
#             "index": 50,
#             "judul": "AKASHA : The Journey of Elaina 03",
#             "harga": 38400,
#             "penulis": "Jougi Shiraishi"
#         },
#         {
#             "index": 51,
#             "judul": "The Irregular at Magic High School 04 - tamat",
#             "harga": 40000,
#             "penulis": "TSUTOMO SATO"
#         },
#         {
#             "index": 52,
#             "judul": "Pralaya",
#             "harga": 159200,
#             "penulis": "Cixin Liu"
#         },
#         {
#             "index": 53,
#             "judul": "The King`s Beast 05",
#             "harga": 32000,
#             "penulis": "Rei Toma"
#         },
#         {
#             "index": 54,
#             "judul": "Shaman King Complete Edition 07",
#             "harga": 60000,
#             "penulis": "Hiroyuki Takei"
#         },
#         {
#             "index": 55,
#             "judul": "Mob Psycho 100 14",
#             "harga": 32000,
#             "penulis": ""
#         },
#         {
#             "index": 56,
#             "judul": "Hanako Si Arwah Penasaran 18",
#             "harga": 25600,
#             "penulis": "Aida Iro"
#         },
#         {
#             "index": 57,
#             "judul": "One Punch Man 24",
#             "harga": 25600,
#             "penulis": "One & Yusuke Murata"
#         },
#         {
#             "index": 58,
#             "judul": "Fate Grand Order Epic of Remnant: Seven Duels of Swordmasters 3",
#             "harga": 36000,
#             "penulis": "TYPE-MOON / REI WATARU"
#         },
#         {
#             "index": 59,
#             "judul": "Dr. Slump 03",
#             "harga": 60000,
#             "penulis": "Akira Toriyama"
#         },
#         {
#             "index": 60,
#             "judul": "Atelier of Witch Hat 08",
#             "harga": 25600,
#             "penulis": "Kamome Shirahama"
#         },
#         {
#             "index": 61,
#             "judul": "Sorry For Not Answering The Phone, Im Too Busy Trying To Fly",
#             "harga": 88000,
#             "penulis": "JVSAN"
#         },
#         {
#             "index": 62,
#             "judul": "Job? Akulah Ahlinya Hewan Peliharaan",
#             "harga": 75000,
#             "penulis": "Kugil Publishing"
#         },
#         {
#             "index": 63,
#             "judul": "Laut Pasang 1994",
#             "harga": 99000,
#             "penulis": "Lilpudu None"
#         },
#         {
#             "index": 64,
#             "judul": "Final Fantasy : Lost Stranger 07",
#             "harga": 36000,
#             "penulis": "HAZUKI MINASE, ITSUKI KAMEYA"
#         },
#         {
#             "index": 65,
#             "judul": "Sekar Pati",
#             "harga": 99000,
#             "penulis": "Erni Windiyarti"
#         },
#         {
#             "index": 66,
#             "judul": "I Found You 1991",
#             "harga": 84150,
#             "penulis": "Usbatun Shaliha"
#         },
#         {
#             "index": 67,
#             "judul": "My Hero Academia 24",
#             "harga": 36000,
#             "penulis": "Kohei Horikoshi"
#         },
#         {
#             "index": 68,
#             "judul": "Samurai X Hokkaido Arc Vol. 03",
#             "harga": 40000,
#             "penulis": "Nobuhiro Watsuki"
#         },
#         {
#             "index": 69,
#             "judul": "Q.E.D IFF 11",
#             "harga": 32000,
#             "penulis": "Motohiro Katou"
#         },
#         {
#             "index": 70,
#             "judul": "Oh My God! Smallest, Deadliest - Cara Virus Bekerja dalam Tubuh",
#             "harga": 71250,
#             "penulis": "YeaRimDang"
#         },
#         {
#             "index": 71,
#             "judul": "Oh My God! Ih, Bau! Serba-Serbi Kentut",
#             "harga": 71250,
#             "penulis": "YeaRimDang"
#         },
#         {
#             "index": 72,
#             "judul": "Plants VS Zombies - Komik Dinosaurus : Kebangkitan Sang Pahlawan",
#             "harga": 93750,
#             "penulis": "Xiao Jiangnan"
#         },
#         {
#             "index": 73,
#             "judul": "Koloni Flawless Vol. 3",
#             "harga": 46500,
#             "penulis": "Shinshinhye None"
#         },
#         {
#             "index": 74,
#             "judul": "Koloni Senior Bekalmu! Vol. 1",
#             "harga": 46500,
#             "penulis": "Sihanjir /Bangsyah"
#         },
#         {
#             "index": 75,
#             "judul": "Juliet of The Boarding School 16 - tamat",
#             "harga": 24000,
#             "penulis": "Yousuke Kaneda"
#         },
#         {
#             "index": 76,
#             "judul": "One Room of Happiness 10",
#             "harga": 24000,
#             "penulis": "HAKURI"
#         },
#         {
#             "index": 77,
#             "judul": "Hiroshi Nohara's Lunch Style 07",
#             "harga": 30000,
#             "penulis": "YOICHI TSUKAHARA/YOSHITO USUI"
#         },
#         {
#             "index": 78,
#             "judul": "AKASHA : Re:ZERO -Starting Life in Another World- The Frozen Bond 1",
#             "harga": 36000,
#             "penulis": "TAPPEI NAGATSUKI/MAKOTO FUGETSU/SHINICHIROU OTSUKA"
#         },
#         {
#             "index": 79,
#             "judul": "A Man & His Cat 6",
#             "harga": 30000,
#             "penulis": "UMI SAKURAI"
#         },
#         {
#             "index": 80,
#             "judul": "One Piece Party 07",
#             "harga": 24000,
#             "penulis": "Eiichiro Oda"
#         },
#         {
#             "index": 81,
#             "judul": "Virgo and The Sparkling Season II Vol. 02",
#             "harga": 54000,
#             "penulis": "Annisa Nisfihani"
#         },
#         {
#             "index": 82,
#             "judul": "Kubo Won`t Let Me Be Invisible 03",
#             "harga": 37500,
#             "penulis": "Nene Yukimori"
#         },
#         {
#             "index": 83,
#             "judul": "Mashle 03",
#             "harga": 33750,
#             "penulis": "Hajime Komoto"
#         },
#         {
#             "index": 84,
#             "judul": "Radiant 05",
#             "harga": 36000,
#             "penulis": "TONY VALENTE"
#         },
#         {
#             "index": 85,
#             "judul": "Agharna",
#             "harga": 80750,
#             "penulis": "Saniyyah Putri Salsabila Said"
#         },
#         {
#             "index": 86,
#             "judul": "Lentera Senja",
#             "harga": 80750,
#             "penulis": "Alfia Ramadhani"
#         },
#         {
#             "index": 87,
#             "judul": "Perjanjian Dua Surga",
#             "harga": 84150,
#             "penulis": "Dianobi None"
#         },
#         {
#             "index": 88,
#             "judul": "Komik Doa Anak Muslim Edisi Revisi",
#             "harga": 119250,
#             "penulis": "Dian K & Aan W"
#         },
#         {
#             "index": 89,
#             "judul": "Loversation",
#             "harga": 126650,
#             "penulis": "Valerie Patkar"
#         },
#         {
#             "index": 90,
#             "judul": "Keluarga Cemara#1",
#             "harga": 74250,
#             "penulis": "Arswendo Atmowiloto"
#         },
#         {
#             "index": 91,
#             "judul": "Komik Riwayat Peradaban Arab Sebelum Islam",
#             "harga": 74800,
#             "penulis": "Kak Freddie & Kak Andiko"
#         },
#         {
#             "index": 92,
#             "judul": "Komik Petualangan Sula 2: Menyusuri Jejak Al-Fatih Di Kota Kemenangan",
#             "harga": 97750,
#             "penulis": "Irvan Aqila"
#         },
#         {
#             "index": 93,
#             "judul": "AKASHA : Hellstar Remina",
#             "harga": 51000,
#             "penulis": "ITO Junji"
#         },
#         {
#             "index": 94,
#             "judul": "Aquatic Company! 01",
#             "harga": 33750,
#             "penulis": "Wataru ISHII"
#         },
#         {
#             "index": 95,
#             "judul": "Level Comic: Gokushufudo - The Way of House Husband 08",
#             "harga": 30000,
#             "penulis": "Kousuke Oono"
#         },
#         {
#             "index": 96,
#             "judul": "Level Comic: Tokyo Revengers 08",
#             "harga": 30000,
#             "penulis": "Ken Wakui"
#         },
#         {
#             "index": 97,
#             "judul": "Chion And The Cat Temple 08",
#             "harga": 24000,
#             "penulis": "Ojiro Makoto"
#         },
#         {
#             "index": 98,
#             "judul": "Fly Me to the Moon 10",
#             "harga": 24000,
#             "penulis": "Hata Kenjiro"
#         },
#         {
#             "index": 99,
#             "judul": "Black Butler 32",
#             "harga": 24000,
#             "penulis": "Yana Toboso"
#         },
#         {
#             "index": 100,
#             "judul": "DEMON SLAYER: Kimetsu no Yaiba 13",
#             "harga": 30000,
#             "penulis": "Koyoharu Gotouge"
#         },
#         {
#             "index": 101,
#             "judul": "One Piece 102",
#             "harga": 33750,
#             "penulis": "Eiichiro Oda"
#         },
#         {
#             "index": 102,
#             "judul": "Buku Ensiklopedia Sains & Teknologi: Alat dan Mesin",
#             "harga": 131250,
#             "penulis": "KL Management"
#         },
#         {
#             "index": 103,
#             "judul": "Unrivaled",
#             "harga": 89250,
#             "penulis": "Marsella Tina"
#         },
#         {
#             "index": 104,
#             "judul": "Radiant 04",
#             "harga": 33750,
#             "penulis": "TONY VALENTE"
#         },
#         {
#             "index": 105,
#             "judul": "AKASHA : Oshi no Ko : Anak Idola 07",
#             "harga": 36000,
#             "penulis": "Aka AKASAKA"
#         },
#         {
#             "index": 106,
#             "judul": "Si Juki Anak Kosan Vol 3",
#             "harga": 71400,
#             "penulis": "Faza Meonk"
#         },
#         {
#             "index": 107,
#             "judul": "My Wife`s My Lecturer, My Husband`s My Student",
#             "harga": 72250,
#             "penulis": "Akhmad Fauzan & Eli Antina"
#         },
#         {
#             "index": 108,
#             "judul": "AKASHA : Chainsaw Man 02",
#             "harga": 36000,
#             "penulis": "Tatsuki Fujimoto"
#         },
#         {
#             "index": 109,
#             "judul": "AKASHA : Wotakoi : Love is Hard for Otaku 09",
#             "harga": 30000,
#             "penulis": "FUJITA"
#         },
#         {
#             "index": 110,
#             "judul": "KOLONI Kill Starter Vol. 2",
#             "harga": 46500,
#             "penulis": "Erfan Fajar"
#         },
#         {
#             "index": 111,
#             "judul": "Plants VS Zombies - Komik Tubuh Manusia : Penjaga Kehidupan",
#             "harga": 93750,
#             "penulis": "Xiao Jiangnan"
#         },
#         {
#             "index": 112,
#             "judul": "Full Bloom Cheekiness 17",
#             "harga": 24000,
#             "penulis": "Miyuki Mitsubachi"
#         },
#         {
#             "index": 113,
#             "judul": "Cat Tales 07",
#             "harga": 24000,
#             "penulis": "Konomi Wagata"
#         },
#         {
#             "index": 114,
#             "judul": "Kaguya-sama, Love is War 13",
#             "harga": 33750,
#             "penulis": "Aka AKASAKA"
#         },
#         {
#             "index": 115,
#             "judul": "AKASHA : Record of Ragnarok 11",
#             "harga": 33750,
#             "penulis": "AJI Chika, Shinya UMEMURA"
#         },
#         {
#             "index": 116,
#             "judul": "AKASHA : Higehiro 02",
#             "harga": 36000,
#             "penulis": "Shimesaba/Booota/ Imaru Adachi"
#         },
#         {
#             "index": 117,
#             "judul": "Level Comic: Giant Killing 58",
#             "harga": 26250,
#             "penulis": "Tsujitomo, Masaya Tsunamoto"
#         },
#         {
#             "index": 118,
#             "judul": "Level Comic: Jojo`s BIzarre Adventure 05 - Part 2 Battle Tendency",
#             "harga": 63750,
#             "penulis": "Hirohiko Araki"
#         },
#         {
#             "index": 119,
#             "judul": "Ruler of The Land 83",
#             "harga": 24000,
#             "penulis": "Jeon Keuk Jin & Yang Jae Hyun"
#         },
#         {
#             "index": 120,
#             "judul": "Interview with Monster Girls 06",
#             "harga": 30000,
#             "penulis": "Petos None"
#         },
#         {
#             "index": 121,
#             "judul": "Restaurant To Another World Vol. 01",
#             "harga": 33750,
#             "penulis": "Junpei Inuzuka"
#         },
#         {
#             "index": 122,
#             "judul": "Libra of Nil Admirari 02",
#             "harga": 33750,
#             "penulis": "Otome, Sho Yuzuki"
#         },
#         {
#             "index": 123,
#             "judul": "Kisah Hantu-Hantu Di Nusantara",
#             "harga": 55250,
#             "penulis": "Ipnu R. Nugroho"
#         },
#         {
#             "index": 124,
#             "judul": "Meet Me in Amsterdam",
#             "harga": 84150,
#             "penulis": "Kalea None"
#         },
#         {
#             "index": 125,
#             "judul": "Buku Ensiklopedia Sains & Teknologi: Kehidupan Sehari-hari",
#             "harga": 131250,
#             "penulis": "KL Management"
#         },
#         {
#             "index": 126,
#             "judul": "Komik 10 Ulama Perawi Hadits",
#             "harga": 123250,
#             "penulis": "Izzah Annisa&fajar Istiqlal"
#         },
#         {
#             "index": 127,
#             "judul": "The Cold Sato is only Sweet to Me 01",
#             "harga": 33750,
#             "penulis": "Kazami Sawatari"
#         },
#         {
#             "index": 128,
#             "judul": "Lc: The Drops Of God 39",
#             "harga": 12000,
#             "penulis": "Agi Tadashi,shu Okimoto"
#         },
#         {
#             "index": 129,
#             "judul": "Yowamushi Pedal, Go! 20",
#             "harga": 44250,
#             "penulis": "Wataru Watanabe"
#         },
#         {
#             "index": 130,
#             "judul": "AKASHA : Dead Mount Death Play 07",
#             "harga": 36000,
#             "penulis": "RYOHGO NARITA/SHINTA FUJIMOTO"
#         },
#         {
#             "index": 131,
#             "judul": "AKASHA : Fate/Type Redline : Strange Story of Imperial Capital Holy Grail 01",
#             "harga": 46400,
#             "penulis": "Ryoji Hirano/Keikenti/ Type-Moon"
#         },
#         {
#             "index": 132,
#             "judul": "Level Comic: Kanojo Okarishimasu 10",
#             "harga": 30000,
#             "penulis": "REIJI MIYAJIMA"
#         },
#         {
#             "index": 133,
#             "judul": "Teasing Master, Takagi 11",
#             "harga": 30000,
#             "penulis": "Soichiro YAMAMOTO"
#         },
#         {
#             "index": 134,
#             "judul": "Detektif Conan Spesial 46",
#             "harga": 30000,
#             "penulis": "Aoyama Gosho"
#         },
#         {
#             "index": 135,
#             "judul": "Komik Waktu dalam Alquran",
#             "harga": 96750,
#             "penulis": "Aan Wulandari Usman"
#         },
#         {
#             "index": 136,
#             "judul": "Komik Mahfudzat: 22 Peribahasa Arab untuk Keseharianmu",
#             "harga": 111750,
#             "penulis": "Dian K & Aan W"
#         },
#         {
#             "index": 137,
#             "judul": "Level Comic: Bungo Stray Dogs 02",
#             "harga": 37500,
#             "penulis": "Kafka Asagiri"
#         },
#         {
#             "index": 138,
#             "judul": "Detektif Kindaichi (Premium) 10",
#             "harga": 21000,
#             "penulis": "Seimaru Amagi & Fumiya Sato"
#         },
#         {
#             "index": 139,
#             "judul": "Dia Bara",
#             "harga": 80750,
#             "penulis": "Nurwina Sari"
#         },
#         {
#             "index": 140,
#             "judul": "Lautan dan Dendamnya",
#             "harga": 86250,
#             "penulis": "Adib Izra Mirza"
#         },
#         {
#             "index": 141,
#             "judul": "Sakamoto Days 02",
#             "harga": 33750,
#             "penulis": "Yuto Suzuki"
#         },
#         {
#             "index": 142,
#             "judul": "Arakawa Under the Bridge 01",
#             "harga": 37500,
#             "penulis": "Nakamura Hikaru"
#         },
#         {
#             "index": 143,
#             "judul": "Blue Box 01",
#             "harga": 30000,
#             "penulis": "Miura Kouji"
#         },
#         {
#             "index": 144,
#             "judul": "Naruto the Movie: Ninja Clash in the Land of Snow Vol. 1",
#             "harga": 51750,
#             "penulis": "Masashi Kishimoto"
#         },
#         {
#             "index": 145,
#             "judul": "Yotsuba &! 15",
#             "harga": 37500,
#             "penulis": "Kiyohiko Azuma"
#         },
#         {
#             "index": 146,
#             "judul": "Oh My God! - Misteri Sulap Warna dan Cahaya",
#             "harga": 71250,
#             "penulis": "YeaRimDang"
#         },
#         {
#             "index": 147,
#             "judul": "Oh My God! Ke Mana Perginya Kotoran?",
#             "harga": 71250,
#             "penulis": "YeaRimDang"
#         },
#         {
#             "index": 148,
#             "judul": "Warisan dalam Kamar Pendaringan",
#             "harga": 51000,
#             "penulis": "Widz Stoops"
#         },
#         {
#             "index": 149,
#             "judul": "Arshaka : The Prince Charming",
#             "harga": 84150,
#             "penulis": "Gulla None"
#         },
#         {
#             "index": 150,
#             "judul": "Selat : In The Time I Spent With You",
#             "harga": 84150,
#             "penulis": "Devitna None"
#         },
#         {
#             "index": 151,
#             "judul": "High Rise Invasion 16",
#             "harga": 24000,
#             "penulis": "Tsuina Miura / Takahiro Oba"
#         },
#         {
#             "index": 152,
#             "judul": "AKASHA : Fist of the North Star 14",
#             "harga": 56250,
#             "penulis": "Tetsuo Hara & Buronson"
#         },
#         {
#             "index": 153,
#             "judul": "The Misfit of Demon King Academy 03",
#             "harga": 33750,
#             "penulis": "Shu, Kaya Haruka"
#         },
#         {
#             "index": 154,
#             "judul": "A Couple of Cuckoos 07",
#             "harga": 30000,
#             "penulis": "Miki Yoshikawa"
#         },
#         {
#             "index": 155,
#             "judul": "Black Clover 21",
#             "harga": 30000,
#             "penulis": "Yuki TABATA"
#         },
#         {
#             "index": 156,
#             "judul": "Detektif Conan Premium 14",
#             "harga": 48750,
#             "penulis": "Aoyama Gosho"
#         },
#         {
#             "index": 157,
#             "judul": "Fairy Tail 100 years Quest 10",
#             "harga": 30000,
#             "penulis": "Hiro Mashima"
#         },
#         {
#             "index": 158,
#             "judul": "The Blue Orchestra 06",
#             "harga": 24000,
#             "penulis": "Makoto Akui"
#         },
#         {
#             "index": 159,
#             "judul": "Level Comic: Tokyo Revengers 07",
#             "harga": 30000,
#             "penulis": "Ken Wakui"
#         },
#         {
#             "index": 160,
#             "judul": "Hello (Again), Cello",
#             "harga": 93500,
#             "penulis": "NADIA RISTIVANI"
#         },
#         {
#             "index": 161,
#             "judul": "Paket Hai, Miiko 1-3",
#             "harga": 92250,
#             "penulis": "Eriko Ono"
#         },
#         {
#             "index": 162,
#             "judul": "Level Comic: Tokyo Revengers 4",
#             "harga": 30000,
#             "penulis": "Ken Wakui"
#         },
#         {
#             "index": 163,
#             "judul": "Parodi Negeri Kami: 38 tahun Timun di Kompas (1985-2023) jilid 2",
#             "harga": 159200,
#             "penulis": "Rahmat Riyadi"
#         },
#         {
#             "index": 164,
#             "judul": "Parodi Negeri Kami: 38 tahun Timun di Kompas (1985-2023) jilid 1",
#             "harga": 159200,
#             "penulis": "Rahmat Riyadi"
#         },
#         {
#             "index": 165,
#             "judul": "Plants VS Zombies - Komik Dinosaurus : Pertarungan Sintas di Pulau Surga",
#             "harga": 93750,
#             "penulis": "Xiao Jiangnan"
#         },
#         {
#             "index": 166,
#             "judul": "AKASHA : Fate/Strange Fake 04",
#             "harga": 52500,
#             "penulis": "SIDUKI MORII/RYOHGO NARITA/TYPE-MOON"
#         },
#         {
#             "index": 167,
#             "judul": "Edens Zero 14",
#             "harga": 32000,
#             "penulis": "Hiro Mashima"
#         },
#         {
#             "index": 168,
#             "judul": "MAO 06",
#             "harga": 30000,
#             "penulis": "Takahashi Rumiko"
#         },
#         {
#             "index": 169,
#             "judul": "Virgo and The Sparklings Season II Vol. 01: Langkah Baru",
#             "harga": 57600,
#             "penulis": "Annisa Nisfihani dan Ellie Goh"
#         },
#         {
#             "index": 170,
#             "judul": "The King`s Beast 04",
#             "harga": 30000,
#             "penulis": "Rei Toma"
#         },
#         {
#             "index": 171,
#             "judul": "Ito Junji Compilation \u2013 Tomie Part 2",
#             "harga": 63750,
#             "penulis": "Ito Junji"
#         },
#         {
#             "index": 172,
#             "judul": "AKASHA : Futo Detective 06",
#             "harga": 33750,
#             "penulis": "Sanjo Riku/ Masaki Sato"
#         },
#         {
#             "index": 173,
#             "judul": "Pasta Kacang Merah (An Sweet Bean Paste)",
#             "harga": 73500,
#             "penulis": "Durian Sukegawa"
#         },
#         {
#             "index": 174,
#             "judul": "Gita Cinta dari SMA",
#             "harga": 65000,
#             "penulis": "Eddy D. Iskandar"
#         },
#         {
#             "index": 175,
#             "judul": "Rajendra",
#             "harga": 84150,
#             "penulis": "Zahra Sahira Ruhwani"
#         },
#         {
#             "index": 176,
#             "judul": "Dickon",
#             "harga": 63750,
#             "penulis": "J. Sheridan Le Fanu"
#         },
#         {
#             "index": 177,
#             "judul": "One Piece 100",
#             "harga": 46750,
#             "penulis": "Eiichiro Oda"
#         },
#         {
#             "index": 178,
#             "judul": "Black Clover 19",
#             "harga": 30000,
#             "penulis": "Yuki TABATA"
#         },
#         {
#             "index": 179,
#             "judul": "Sri Asih Celestial Goddess Vol. 03 - Alana`s Secret",
#             "harga": 59250,
#             "penulis": "Devita Krisanti"
#         },
#         {
#             "index": 180,
#             "judul": "Yona, the Girl Standing in the Blush of Dawn 34",
#             "harga": 24000,
#             "penulis": "Mizuho Kusanagi"
#         },
#         {
#             "index": 181,
#             "judul": "Sword Art Online 004 Fairy Dance",
#             "harga": 73500,
#             "penulis": "REKI KAWAHARA / ABEC"
#         },
#         {
#             "index": 182,
#             "judul": "Haikyu!!: Fly High! Volleyball! 32",
#             "harga": 24000,
#             "penulis": "Haruichi Furudate"
#         },
#         {
#             "index": 183,
#             "judul": "One Piece Party 06",
#             "harga": 24000,
#             "penulis": "Eiichiro Oda"
#         },
#         {
#             "index": 184,
#             "judul": "Alice in Borderland Vol. 02",
#             "harga": 60000,
#             "penulis": "Haro Aso"
#         },
#         {
#             "index": 185,
#             "judul": "PRETENDING NOT TO SEE - Dark Urban Legend 3-",
#             "harga": 30000,
#             "penulis": "Ryo Azuki"
#         },
#         {
#             "index": 186,
#             "judul": "AKASHA : The Journey of Elaina 02",
#             "harga": 36000,
#             "penulis": "Jougi Shiraishi"
#         },
#         {
#             "index": 187,
#             "judul": "Fate Grand Order Epic of Remnant: Seven Duels of Swordmasters 2",
#             "harga": 33750,
#             "penulis": "TYPE-MOON / REI WATARU"
#         },
#         {
#             "index": 188,
#             "judul": "Dragon Ball Super Vol. 16",
#             "harga": 30000,
#             "penulis": "Akira Toriyama"
#         },
#         {
#             "index": 189,
#             "judul": "Komi Sulit Berkomunikasi 15",
#             "harga": 24000,
#             "penulis": "Tomohito ODA"
#         },
#         {
#             "index": 190,
#             "judul": "Jurnal Mukai Usagido 07",
#             "harga": 24000,
#             "penulis": "HISA TAKANO"
#         },
#         {
#             "index": 191,
#             "judul": "Fujiwara is Almost Right 06",
#             "harga": 30000,
#             "penulis": "Nao Hinachi"
#         },
#         {
#             "index": 192,
#             "judul": "Mob Psycho 100 13",
#             "harga": 30000,
#             "penulis": ""
#         },
#         {
#             "index": 193,
#             "judul": "Komik Tokyo Ghoul 01",
#             "harga": 41250,
#             "penulis": "Sui Ishida"
#         },
#         {
#             "index": 194,
#             "judul": "AKASHA : Takopi\u2019s Original Sin 01",
#             "harga": 36000,
#             "penulis": "Taizan5 None"
#         },
#         {
#             "index": 195,
#             "judul": "The Misfit of Demon King Academy 02",
#             "harga": 33750,
#             "penulis": "Shu, Kaya Haruka"
#         },
#         {
#             "index": 196,
#             "judul": "Level Comic Kanojo Okarishimasu 8",
#             "harga": 30000,
#             "penulis": "REIJI MIYAJIMA"
#         },
#         {
#             "index": 197,
#             "judul": "Job? Akulah Ahlinya YouTube Creator",
#             "harga": 75000,
#             "penulis": "Kugil Publishing"
#         },
#         {
#             "index": 198,
#             "judul": "Dragon Ball Super Vol. 15",
#             "harga": 30000,
#             "penulis": "Akita Toriyama"
#         },
#         {
#             "index": 199,
#             "judul": "Fairy Tail Happy Adventure 4",
#             "harga": 33000,
#             "penulis": "Hiro Mashima"
#         },
#         {
#             "index": 200,
#             "judul": "Black Site: Dark Urban Legend",
#             "harga": 33000,
#             "penulis": "Ryo Azuki"
#         },
#         {
#             "index": 201,
#             "judul": "On Children",
#             "harga": 106250,
#             "penulis": "Wu Xiaole"
#         },
#         {
#             "index": 202,
#             "judul": "Hanako Si Arwah Penasaran 0",
#             "harga": 41250,
#             "penulis": "Aida Iro"
#         },
#         {
#             "index": 203,
#             "judul": "Koloni Jawara Sejati",
#             "harga": 38400,
#             "penulis": "Tanfidz Tammamudin & Ragha Sukma"
#         },
#         {
#             "index": 204,
#             "judul": "YOUTH X MACHINEGUN Aoharu x Kikanju 05",
#             "harga": 33750,
#             "penulis": "Naoe None"
#         },
#         {
#             "index": 205,
#             "judul": "Hai, Miiko! 03 - Bookpaper",
#             "harga": 33750,
#             "penulis": "Eriko Ono"
#         },
#         {
#             "index": 206,
#             "judul": "KOLONI Rajasa - Demon of the Wood",
#             "harga": 36000,
#             "penulis": "Akhmad Fadly"
#         },
#         {
#             "index": 207,
#             "judul": "Final Fantasy : Lost Stranger 09",
#             "harga": 36000,
#             "penulis": "HAZUKI MINASE, ITSUKI KAMEYA"
#         },
#         {
#             "index": 208,
#             "judul": "SAMURAI 8 - The Tale of Hachimaru vol 01",
#             "harga": 33750,
#             "penulis": "Masashi Kishimoto"
#         },
#         {
#             "index": 209,
#             "judul": "Level Comic: Aku no Hana-Kembang Jahanam 01",
#             "harga": 40000,
#             "penulis": "SHUZO OSHIMI"
#         },
#         {
#             "index": 210,
#             "judul": "Level Comic: Bungo Stray Dogs 03",
#             "harga": 37500,
#             "penulis": "Kafka Asagiri"
#         },
#         {
#             "index": 211,
#             "judul": "Death Note - New Edition 01",
#             "harga": 66000,
#             "penulis": "Ohba Tsugumi"
#         },
#         {
#             "index": 212,
#             "judul": "Battle Game In 5 Seconds 14",
#             "harga": 24000,
#             "penulis": "Saizou Harawata & Kashiwa Miyako"
#         },
#         {
#             "index": 213,
#             "judul": "Tokyo Ghoul 02",
#             "harga": 41250,
#             "penulis": "Sui Ishida"
#         },
#         {
#             "index": 214,
#             "judul": "Fullmetal Alchemist 20th Anniversary Book",
#             "harga": 74250,
#             "penulis": "Hiromu Arakawa"
#         },
#         {
#             "index": 215,
#             "judul": "Jika Cinta itu Suci, yang Salah Manusianya",
#             "harga": 46750,
#             "penulis": "Charansa"
#         },
#         {
#             "index": 216,
#             "judul": "Jangan Panggil Namaku : Kumpulan Kisah Terhoror True Story",
#             "harga": 56525,
#             "penulis": "Asri Satitis, Siti Zulia Agustina, Myrra Shalsa Nabila, Azzahra Viana, Febri Ardhita Sidik, Dll"
#         },
#         {
#             "index": 217,
#             "judul": "Like a Stupid",
#             "harga": 59075,
#             "penulis": "Diandra Kanaya"
#         },
#         {
#             "index": 218,
#             "judul": "One Week Friends 06",
#             "harga": 30000,
#             "penulis": "Matcha Hazuki"
#         },
#         {
#             "index": 219,
#             "judul": "Ruler of The Land 82",
#             "harga": 24000,
#             "penulis": "Jeon Keuk Jin"
#         },
#         {
#             "index": 220,
#             "judul": "Classics: Jalan ke Wigan Pier (Road to Wigan Pier)",
#             "harga": 68000,
#             "penulis": "George Orwell"
#         },
#         {
#             "index": 221,
#             "judul": "Runtuhnya Dinasti Wang (A House Divided)",
#             "harga": 95250,
#             "penulis": "Pearl S. Buck"
#         },
#         {
#             "index": 222,
#             "judul": "Wang si Macan (Sons)",
#             "harga": 101250,
#             "penulis": "Pearl S. Buck"
#         },
#         {
#             "index": 223,
#             "judul": "Medicine",
#             "harga": 84150,
#             "penulis": "Theofani Caroline"
#         },
#         {
#             "index": 224,
#             "judul": "My Gus My Husband",
#             "harga": 84150,
#             "penulis": "Aulia Rahimah"
#         },
#         {
#             "index": 225,
#             "judul": "Alezra",
#             "harga": 84150,
#             "penulis": "Kusdina Ain"
#         },
#         {
#             "index": 226,
#             "judul": "Ningsih",
#             "harga": 74800,
#             "penulis": "Teguh Faluvie"
#         },
#         {
#             "index": 227,
#             "judul": "Ship of Theseus 10 - tamat",
#             "harga": 24000,
#             "penulis": "Toshiya Higashimoto"
#         },
#         {
#             "index": 228,
#             "judul": "AKASHA : Takopi\u2019s Original Sin 02 - tamat",
#             "harga": 36000,
#             "penulis": "Taizan5 None"
#         },
#         {
#             "index": 229,
#             "judul": "AKASHA : Higehiro 01",
#             "harga": 36000,
#             "penulis": "Shimesaba/Booota/ Imaru Adachi"
#         },
#         {
#             "index": 230,
#             "judul": "The Cold Sato is only Sweet to Me 02",
#             "harga": 33750,
#             "penulis": "Kazami Sawatari"
#         },
#         {
#             "index": 231,
#             "judul": "Calon Mama",
#             "harga": 84150,
#             "penulis": "Bita Maharani"
#         },
#         {
#             "index": 232,
#             "judul": "Teknik",
#             "harga": 84150,
#             "penulis": "Renita Nozaria"
#         },
#         {
#             "index": 233,
#             "judul": "Harlequin Koleksi Istimewa: Cinderella Sang Taipan Yunani (Secrets of Cinderella's Awakening)",
#             "harga": 51750,
#             "penulis": "Sharon Kendrick"
#         },
#         {
#             "index": 234,
#             "judul": "Samurai X Hokkaido Arc vol. 02",
#             "harga": 37500,
#             "penulis": "Nobuhiro Watsuki"
#         },
#         {
#             "index": 235,
#             "judul": "Dr. Slump 02",
#             "harga": 56250,
#             "penulis": "Akira Toriyama"
#         },
#         {
#             "index": 236,
#             "judul": "One Week Friends 07",
#             "harga": 30000,
#             "penulis": "Matcha Hazuki"
#         },
#         {
#             "index": 237,
#             "judul": "Blue Lock 07",
#             "harga": 33750,
#             "penulis": "Muneyuki Kaneshiro"
#         },
#         {
#             "index": 238,
#             "judul": "Level Comic: Bakemonogatari 11",
#             "harga": 30000,
#             "penulis": "NISIOISIN,OH!GREAT"
#         },
#         {
#             "index": 239,
#             "judul": "Mission: Yozakura Family 01",
#             "harga": 33750,
#             "penulis": "Hitsuji Gondaira"
#         },
#         {
#             "index": 240,
#             "judul": "Plants VS Zombies - Komik Dinosaurus : Dinosaurus dan Harta Karun Rahasia",
#             "harga": 93750,
#             "penulis": "Xiao Jiangnan"
#         },
#         {
#             "index": 241,
#             "judul": "Eknath",
#             "harga": 80750,
#             "penulis": "Sotogakpaketomat None"
#         },
#         {
#             "index": 242,
#             "judul": "Hadratus Syaikh Hasyim Asyari",
#             "harga": 89250,
#             "penulis": "Ririn Astutiningrum dan Rohmat Kurnia"
#         },
#         {
#             "index": 243,
#             "judul": "Komik Cut Nyak Din",
#             "harga": 126650,
#             "penulis": "Fedrian Hasmand"
#         },
#         {
#             "index": 244,
#             "judul": "Ayahku (Bukan) Pembohong",
#             "harga": 80750,
#             "penulis": "Tere Liye"
#         },
#         {
#             "index": 245,
#             "judul": "The Liar Between Us",
#             "harga": 84150,
#             "penulis": "Raven None"
#         },
#         {
#             "index": 246,
#             "judul": "Gemariel",
#             "harga": 80750,
#             "penulis": "Rima Hidayatul Aeni"
#         },
#         {
#             "index": 247,
#             "judul": "Si Juki Anak Kos London",
#             "harga": 70125,
#             "penulis": "Pionicon"
#         },
#         {
#             "index": 248,
#             "judul": "The Black Detective 07",
#             "harga": 26250,
#             "penulis": "Yen Hioka"
#         },
#         {
#             "index": 249,
#             "judul": "Q.E.D IFF 10",
#             "harga": 30000,
#             "penulis": "Motohiro Katou"
#         },
#         {
#             "index": 250,
#             "judul": "Cat Tales 06",
#             "harga": 25600,
#             "penulis": "Konomi Wagata"
#         },
#         {
#             "index": 251,
#             "judul": "Chion And The Cat Temple 07",
#             "harga": 24000,
#             "penulis": "Ojiro Makoto"
#         },
#         {
#             "index": 252,
#             "judul": "AKASHA : Chainsaw Man 01",
#             "harga": 40800,
#             "penulis": "Tatsuki Fujimoto"
#         },
#         {
#             "index": 253,
#             "judul": "Garis Takdir Untuk Hawa",
#             "harga": 84150,
#             "penulis": "Dutahappygirl None"
#         },
#         {
#             "index": 254,
#             "judul": "Kontrakan Nyai Suman",
#             "harga": 84150,
#             "penulis": "Alitast None"
#         },
#         {
#             "index": 255,
#             "judul": "Komik Jingga dalam Elegi",
#             "harga": 62250,
#             "penulis": "Esti Kinasih"
#         },
#         {
#             "index": 256,
#             "judul": "Petualangan Tintin: Perjalanan Ke Bulan",
#             "harga": 66750,
#             "penulis": "Herge"
#         },
#         {
#             "index": 257,
#             "judul": "Koloni Journal Of Terror 1",
#             "harga": 36000,
#             "penulis": "Sweta Kartika"
#         },
#         {
#             "index": 258,
#             "judul": "The Soaring Quadrable 2",
#             "harga": 25000,
#             "penulis": "Arai Takahiro"
#         },
#         {
#             "index": 259,
#             "judul": "Level Comic : Takasugi`s Lunch Box 10",
#             "harga": 24000,
#             "penulis": "Nozomi Yanahara"
#         },
#         {
#             "index": 260,
#             "judul": "Why? Game Science - Sains Permainan",
#             "harga": 82500,
#             "penulis": "YeaRimDang"
#         },
#         {
#             "index": 261,
#             "judul": "Plants VS Zombies - Komik Dinosaurus : Raja Dinosaurus",
#             "harga": 93750,
#             "penulis": "Xiao Jiangnan"
#         },
#         {
#             "index": 262,
#             "judul": "Ragna Crimson 04",
#             "harga": 37500,
#             "penulis": "Daiki Kobayashi"
#         },
#         {
#             "index": 263,
#             "judul": "Psychic Detective Yakumo Another Files: Silence Prophecy",
#             "harga": 73500,
#             "penulis": "Manabu Kaminaga"
#         },
#         {
#             "index": 264,
#             "judul": "Hai, Miiko! 35 - Edisi Khusus (bonus cardholder)",
#             "harga": 51000,
#             "penulis": "Eriko Ono"
#         },
#         {
#             "index": 265,
#             "judul": "Juliet of The Boarding School 15",
#             "harga": 25600,
#             "penulis": "Yousuke Kaneda"
#         },
#         {
#             "index": 266,
#             "judul": "Historical Romance: Proyek Sang Duchess (Project Duchess)",
#             "harga": 84000,
#             "penulis": "Sabrina Jeffries"
#         },
#         {
#             "index": 267,
#             "judul": "The Life We Lead",
#             "harga": 78750,
#             "penulis": "Johana Melisa"
#         },
#         {
#             "index": 268,
#             "judul": "A Terrified Teacher at Ghoul School! 01",
#             "harga": 33750,
#             "penulis": "Mai Tanaka"
#         },
#         {
#             "index": 269,
#             "judul": "She Is More Ordinary Than I Expected 04",
#             "harga": 37500,
#             "penulis": "Eita Mizuno"
#         },
#         {
#             "index": 270,
#             "judul": "One Room of Happiness 09",
#             "harga": 26250,
#             "penulis": "HAKURI"
#         },
#         {
#             "index": 271,
#             "judul": "Detektif Conan 101",
#             "harga": 42500,
#             "penulis": "Aoyama Gosho"
#         },
#         {
#             "index": 272,
#             "judul": "Mashle 02",
#             "harga": 33750,
#             "penulis": "Hajime Komoto"
#         },
#         {
#             "index": 273,
#             "judul": "Libra of Nil Admirari 01",
#             "harga": 33750,
#             "penulis": "Otome, Sho Yuzuki"
#         },
#         {
#             "index": 274,
#             "judul": "The Irregular at Magic High School 03",
#             "harga": 37500,
#             "penulis": "TSUTOMO SATO"
#         },
#         {
#             "index": 275,
#             "judul": "Pesta Dansa Alabaster kutukan ciuman terakhir",
#             "harga": 90000,
#             "penulis": "Beatrix Gurian"
#         },
#         {
#             "index": 276,
#             "judul": "Layla Majnun",
#             "harga": 49300,
#             "penulis": "Syekh Nizami"
#         },
#         {
#             "index": 277,
#             "judul": "KOLONI 5 Menit Sebelum Tayang Vol. 4",
#             "harga": 44000,
#             "penulis": "Ockto Barimbing"
#         },
#         {
#             "index": 278,
#             "judul": "Fate/Grand Order - Mortalis : Stella - 03",
#             "harga": 33750,
#             "penulis": "Shiramine, Type-Moon"
# ...
#             "index": 907,
#             "judul": "Komik Next G Petualangan Mengasuh Adik",
#             "harga": 30600,
#             "penulis": "Naura Janeeta, dkk"
#         },
#         {
#             "index": 908,
#             "judul": "Komik KKPK Little Youtuber Diary",
#             "harga": 33150,
#             "penulis": "Zara Nugroho"
#         },
#         {
#             "index": 909,
#             "judul": "Komik Next G Lovely Hikari RPL 2",
#             "harga": 30600,
#             "penulis": "Farhana Almira Adawiyah"
#         },
#         {
#             "index": 910,
#             "judul": "Terlalu Tampan ; Masih Diary Orang Ganteng",
#             "harga": 35000,
#             "penulis": "M. A. Avisiena Helvin & Savenia Melinda S"
#         },
#         {
#             "index": 911,
#             "judul": "Komik Next G Temanku Artis",
#             "harga": 36000,
#             "penulis": "Puri Mahayu"
#         },
#         {
#             "index": 912,
#             "judul": "#Beranibeda Juki Untuk Indonesia Satu",
#             "harga": 55000,
#             "penulis": "Faza Meonk, Yahya M & Tim Sukses Juki"
#         },
#         {
#             "index": 913,
#             "judul": "Doraemon 05",
#             "harga": 16800,
#             "penulis": "Fujiko F. Fujio"
#         },
#         {
#             "index": 914,
#             "judul": "Doraemon 02 (Terbit Ulang)",
#             "harga": 21000,
#             "penulis": "Fujiko F. Fujio"
#         },
#         {
#             "index": 915,
#             "judul": "Educomics Belajar Matematika: Putiput Membangun Rumah Manki",
#             "harga": 63750,
#             "penulis": "Wafiq Sehat"
#         },
#         {
#             "index": 916,
#             "judul": "Penyelamatan Huruf Lota",
#             "harga": 33150,
#             "penulis": "Yoana Dianika"
#         },
#         {
#             "index": 917,
#             "judul": "Smile at the Runway 09",
#             "harga": 21000,
#             "penulis": "Kotoba Inoya"
#         },
#         {
#             "index": 918,
#             "judul": "Educomics Anak Tangguh Sayangi Hewan",
#             "harga": 73500,
#             "penulis": "Heo Ji young"
#         },
#         {
#             "index": 919,
#             "judul": "Komik Sahabat Anak Muslim  Edisi Revisi",
#             "harga": 108750,
#             "penulis": "Watiek Ideo & Riera Faaizah"
#         },
#         {
#             "index": 920,
#             "judul": "AKASHA : Trace, Recollections of A Forensic Researcher 01",
#             "harga": 25500,
#             "penulis": "Kei Koga"
#         },
#         {
#             "index": 921,
#             "judul": "Si Genius Sains #3 : Bertualang Ke Dunia Dinosaurus",
#             "harga": 115000,
#             "penulis": "Shin Tae  Hoon"
#         },
#         {
#             "index": 922,
#             "judul": "The Last Love In This World 06",
#             "harga": 25000,
#             "penulis": "Keiko Notoyama"
#         },
#         {
#             "index": 923,
#             "judul": "Noragami 19",
#             "harga": 25000,
#             "penulis": "Adachitoka"
#         },
#         {
#             "index": 924,
#             "judul": "Clean Freak! Aoyama kun 02",
#             "harga": 25000,
#             "penulis": "Taku Sakamoto"
#         },
#         {
#             "index": 925,
#             "judul": "Connect 2",
#             "harga": 30000,
#             "penulis": "Suzuki Manatsu"
#         },
#         {
#             "index": 926,
#             "judul": "Sweetness And Lightning 8",
#             "harga": 25000,
#             "penulis": "Gido Amagakure"
#         },
#         {
#             "index": 927,
#             "judul": "Shisho Series 06",
#             "harga": 25000,
#             "penulis": "Uni & Shu Katayama"
#         },
#         {
#             "index": 928,
#             "judul": "Silver Spoon 14",
#             "harga": 25000,
#             "penulis": "Hiromu Arakawa"
#         },
#         {
#             "index": 929,
#             "judul": "Why Emergency Treatment",
#             "harga": 33000,
#             "penulis": "Lee, Papyrus"
#         },
#         {
#             "index": 930,
#             "judul": "Republik Naga (The Dragon Republic)",
#             "harga": 141750,
#             "penulis": "R.F. Kuang"
#         },
#         {
#             "index": 931,
#             "judul": "Gemblongers Series : Diajeng - Camilan, Gembolan, dan Cinta yang Belingsatan",
#             "harga": 69000,
#             "penulis": "Netty Virgiantini"
#         },
#         {
#             "index": 932,
#             "judul": "Gemblongers Series : Mara - Ditaktor, Eksim, dan Cinta yang NayalNayal",
#             "harga": 69000,
#             "penulis": "Wiwien Wintarto"
#         },
#         {
#             "index": 933,
#             "judul": "Job? Akulah Ahlinya Kosmetik",
#             "harga": 75000,
#             "penulis": "Kugil Publishing"
#         },
#         {
#             "index": 934,
#             "judul": "Seraph Of The End 23",
#             "harga": 21000,
#             "penulis": "Yamamoto Yamato & Kagami Takaya"
#         },
#         {
#             "index": 935,
#             "judul": "A Springtime with Ninjas 3",
#             "harga": 21000,
#             "penulis": "NARUMI HASEGAKI"
#         },
#         {
#             "index": 936,
#             "judul": "Bonobono 03",
#             "harga": 30000,
#             "penulis": "Mikio Igarashi"
#         },
#         {
#             "index": 937,
#             "judul": "Battle Game In 5 Seconds 12",
#             "harga": 21000,
#             "penulis": "Saizou Harawata & Kashiwa Miyako"
#         },
#         {
#             "index": 938,
#             "judul": "3 Hours to Master: Cara Mengembangkan Kreativitasmu",
#             "harga": 75000,
#             "penulis": "Kadokawa Gempak Starz"
#         },
#         {
#             "index": 939,
#             "judul": "Why? Bacteria and Virus - Bakteri dan Virus",
#             "harga": 82500,
#             "penulis": "YeaRimDang"
#         },
#         {
#             "index": 940,
#             "judul": "Why? People - Elon Musk",
#             "harga": 82500,
#             "penulis": "Yearimdang"
#         },
#         {
#             "index": 941,
#             "judul": "X-Venture Dinosaur - Berkeliling di Era Paleozoikum",
#             "harga": 90000,
#             "penulis": "Kadokawa Gempak Starz"
#         },
#         {
#             "index": 942,
#             "judul": "Apa Itu Surga ?Apa Itu Neraka?",
#             "harga": 53550,
#             "penulis": "Aan Wulandari Dan Wawan Kungkang"
#         },
#         {
#             "index": 943,
#             "judul": "Komik Kecil-Kecil Punya Karya: No Plastic Bag",
#             "harga": 33150,
#             "penulis": "Naura Janeeta, dkk"
#         },
#         {
#             "index": 944,
#             "judul": "Lc: Black Torch 04",
#             "harga": 27000,
#             "penulis": "Tsuyoshi Takaki"
#         },
#         {
#             "index": 945,
#             "judul": "Lc: Black Torch 02",
#             "harga": 27000,
#             "penulis": "Tsuyoshi Takaki"
#         },
#         {
#             "index": 946,
#             "judul": "Lc: Karate Master Minoru 26",
#             "harga": 27000,
#             "penulis": "Baba Yasushi"
#         },
#         {
#             "index": 947,
#             "judul": "Yokai Watch 14",
#             "harga": 25000,
#             "penulis": "Konishi Noriyuki"
#         },
#         {
#             "index": 948,
#             "judul": "Castle Town Dandelion 2",
#             "harga": 22500,
#             "penulis": "Kasugu Ayumu"
#         },
#         {
#             "index": 949,
#             "judul": "Chopperman 3",
#             "harga": 25000,
#             "penulis": "Hirofumi Takei"
#         },
#         {
#             "index": 950,
#             "judul": "KOLONI ReON & Friends Vol. 1",
#             "harga": 56250,
#             "penulis": "Reon Comics Team"
#         },
#         {
#             "index": 951,
#             "judul": "AKASHA : The Secret Garden",
#             "harga": 45000,
#             "penulis": "Nana Shiiba"
#         },
#         {
#             "index": 952,
#             "judul": "Anohana - The Flower We Saw That Day 03 - tamat",
#             "harga": 48000,
#             "penulis": "MITSU IZUMI / CHO-HEIWA BUSTERS"
#         },
#         {
#             "index": 953,
#             "judul": "AKASHA : Wavering Love",
#             "harga": 45000,
#             "penulis": "Hikaru Asagi"
#         },
#         {
#             "index": 954,
#             "judul": "Aku Bisa Kaya : Jalan-Jalan Keliling Dunia",
#             "harga": 95000,
#             "penulis": "Papyrus"
#         },
#         {
#             "index": 955,
#             "judul": "Artemis Fowl#3: The Eternity Code (Sandi Abadi)",
#             "harga": 41500,
#             "penulis": "Eoin Colfer"
#         },
#         {
#             "index": 956,
#             "judul": "Regarding Reincarnated as Slime 2",
#             "harga": 25000,
#             "penulis": "Taiki Kawakami"
#         },
#         {
#             "index": 957,
#             "judul": "Korean Dictionary Workbook + Cd",
#             "harga": 144800,
#             "penulis": "Kang Hyoun Hwa"
#         },
#         {
#             "index": 958,
#             "judul": "50 Kisah Akhlak Mulia Rasulullah Saw",
#             "harga": 55250,
#             "penulis": "Mulasih Tary & Devi Ardiyanti"
#         },
#         {
#             "index": 959,
#             "judul": "I Want To Eat Your Pancreas 02 - Tamat",
#             "harga": 24000,
#             "penulis": "YORU SUMINO / IDUMI KIRIHARA"
#         },
#         {
#             "index": 960,
#             "judul": "Kuroko's Basketball 20",
#             "harga": 25000,
#             "penulis": "Tadatoshi Fujimaki"
#         },
#         {
#             "index": 961,
#             "judul": "Pod:New Legenda Naga 10",
#             "harga": 68000,
#             "penulis": "Kodansha - Yoshito Yamahara"
#         },
#         {
#             "index": 962,
#             "judul": "Pod:Salesman Idola Dalam Komik",
#             "harga": 66000,
#             "penulis": "David Kadisihe & Angel Oematan"
#         },
#         {
#             "index": 963,
#             "judul": "Pod:Top Notch #4",
#             "harga": 66000,
#             "penulis": "Yoko Maki / Aki Mochida"
#         },
#         {
#             "index": 964,
#             "judul": "Pod:My Girlfriend Is A Bodyguard",
#             "harga": 70000,
#             "penulis": "Rie Takada"
#         },
#         {
#             "index": 965,
#             "judul": "Pod:Old Man`S Love",
#             "harga": 63000,
#             "penulis": "Kakeru Tsutsumi"
#         },
#         {
#             "index": 966,
#             "judul": "Pod:The Warmth Of Your Fingertips",
#             "harga": 66000,
#             "penulis": "Yuka Kitagawa"
#         },
#         {
#             "index": 967,
#             "judul": "Pod:Android Odette #2",
#             "harga": 70000,
#             "penulis": "Julietta Suzuki"
#         },
#         {
#             "index": 968,
#             "judul": "Pod:Niina`S First Love Story #4",
#             "harga": 70000,
#             "penulis": "Koyomi Minamori"
#         },
#         {
#             "index": 969,
#             "judul": "Pod:Train Of First Love",
#             "harga": 64000,
#             "penulis": "Yuka Kitagawa"
#         },
#         {
#             "index": 970,
#             "judul": "Pod:For Justice And Love",
#             "harga": 70000,
#             "penulis": "Mitsubachi Miyuki"
#         },
#         {
#             "index": 971,
#             "judul": "Pod:Niina`S First Love Story #2",
#             "harga": 70000,
#             "penulis": "Koyomi Minamori"
#         },
#         {
#             "index": 972,
#             "judul": "Pod:Android Odette #1 (Karakuri Odette)",
#             "harga": 70000,
#             "penulis": "Julietta Suzuki"
#         },
#         {
#             "index": 973,
#             "judul": "Pod:600 Pages Mystery",
#             "harga": 70000,
#             "penulis": "Alto Yukimura"
#         },
#         {
#             "index": 974,
#             "judul": "Pod:Goodbye Chocolate",
#             "harga": 68000,
#             "penulis": "Hisamu Oto"
#         },
#         {
#             "index": 975,
#             "judul": "Pod:Petualangan Naif Dan Mesin Waktu Naif 3: Menjelajah Dime",
#             "harga": 56000,
#             "penulis": "Franki Indrasmoro"
#         },
#         {
#             "index": 976,
#             "judul": "Pod:Honey And The Butterfly (Hachimitsu No Butterfly)",
#             "harga": 70000,
#             "penulis": "Alto Yukimura"
#         },
#         {
#             "index": 977,
#             "judul": "Pod:Real Masjid 2",
#             "harga": 56000,
#             "penulis": "Tony Hernanto, Faza Meonk"
#         },
#         {
#             "index": 978,
#             "judul": "Nan Nan\u2019s Daily Life 2",
#             "harga": 68000,
#             "penulis": "Ananda"
#         },
#         {
#             "index": 979,
#             "judul": "Pod:Kornchonx Chaos",
#             "harga": 50000,
#             "penulis": "Iwank"
#         },
#         {
#             "index": 980,
#             "judul": "Pod:Pamali!",
#             "harga": 53000,
#             "penulis": "Norvan Pecandupagi"
#         },
#         {
#             "index": 981,
#             "judul": "Battle Game In 5 Seconds 7",
#             "harga": 28000,
#             "penulis": "Saizou Harawata & Kashiwa Miyako"
#         },
#         {
#             "index": 982,
#             "judul": "Lc: Btoom 17",
#             "harga": 27000,
#             "penulis": "Junya Inoue"
#         },
#         {
#             "index": 983,
#             "judul": "2.5 D Boyfriend 2",
#             "harga": 25000,
#             "penulis": "Mitsu Aoi"
#         },
#         {
#             "index": 984,
#             "judul": "Lc: Mujirushi The Sign Of Dreams",
#             "harga": 39000,
#             "penulis": "NAOKI URASAWA"
#         },
#         {
#             "index": 985,
#             "judul": "Cerita Spesial Doraemon - Nilai Nol & Pergi Dari Rumah",
#             "harga": 26250,
#             "penulis": "Fujiko F. Fujio"
#         },
#         {
#             "index": 986,
#             "judul": "AKASHA : The Birds of Death 03 - tamat",
#             "harga": 25500,
#             "penulis": ""
#         },
#         {
#             "index": 987,
#             "judul": "Kkpk Reg: My Twin, My Best Friend",
#             "harga": 33150,
#             "penulis": "DIEZA KAYLA ZIVANKA"
#         },
#         {
#             "index": 988,
#             "judul": "Komik Next G: Youtuber Al-Quran",
#             "harga": 39000,
#             "penulis": "Adiva Lubna Khairunnisa Dkk"
#         },
#         {
#             "index": 989,
#             "judul": "Gaul Anti Galau",
#             "harga": 33575,
#             "penulis": "Fajar Istiqlal"
#         },
#         {
#             "index": 990,
#             "judul": "C.M.B 40",
#             "harga": 16800,
#             "penulis": "Motohiro Katou"
#         },
#         {
#             "index": 991,
#             "judul": "SC: The Gravelord with Ribbon",
#             "harga": 18000,
#             "penulis": "Chitose Azuya"
#         },
#         {
#             "index": 992,
#             "judul": "Re-Creators One More",
#             "harga": 25000,
#             "penulis": "Hiroe Rei"
#         },
#         {
#             "index": 993,
#             "judul": "Fullmetal Alchemist (Premium) 13",
#             "harga": 57000,
#             "penulis": "Hiromu Arakawa"
#         },
#         {
#             "index": 994,
#             "judul": "Inuyasha Premium 24",
#             "harga": 37500,
#             "penulis": "Takahashi Rumiko"
#         },
#         {
#             "index": 995,
#             "judul": "Dragon Ball Vol. 39",
#             "harga": 25000,
#             "penulis": "Akita Toriyama"
#         },
#         {
#             "index": 996,
#             "judul": "Yamada and the 7 Witches Vol. 24",
#             "harga": 25000,
#             "penulis": "Miki Yoshikawa"
#         },
#         {
#             "index": 997,
#             "judul": "Battle Game In 5 Seconds 06",
#             "harga": 25000,
#             "penulis": "Saizou Harawata & Kashiwa Miyako"
#         },
#         {
#             "index": 998,
#             "judul": "The Sluggish Tanaka 10",
#             "harga": 25000,
#             "penulis": "Nozomi Uda"
#         },
#         {
#             "index": 999,
#             "judul": "LC: Giant Killing 45",
#             "harga": 27000,
#             "penulis": "Tsujitomo, Masaya Tsunamoto"
#         }
#     ]
# }
